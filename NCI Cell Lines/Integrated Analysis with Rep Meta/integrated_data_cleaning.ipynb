# %%
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %%
genomics = pd.read_excel('/Users/neil/Downloads/NCI_genomics.xlsx')
genomics.head(20)
# Out:
#                                            Unnamed: 0  Unnamed: 1 Unnamed: 2
# 0                                          Footnotes:         NaN        NaN  \
# 1   a "Cell lines" are described at the Cell Line ...         NaN        NaN
# 2   b "Gene names" as defined by the  UCSC Table B...         NaN        NaN
# 3                                                 NaN         NaN        NaN
# 4                                                 NaN         NaN        NaN
# 5   Supplemental Table 1: Gene composite transcrip...         NaN        NaN
# 6                                                 NaN         NaN        NaN
# 7                                                 NaN         NaN        BR:
# 8                                        Gene names c         NaN       MCF7
# 9                                                A1BG         NaN    1.91821
# 10                                           A1BG-AS1         NaN    2.89241
# ...

# %%
genomics = genomics.iloc[8:, ]
genomics
# Out:
#          Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5
# 8      Gene names c         NaN       MCF7  MDA_MB_231     HS578T     BT_549  \
# 9              A1BG         NaN    1.91821    0.492422    3.36955    6.00088
# 10         A1BG-AS1         NaN    2.89241     0.11608    1.16519    1.91839
# 11             A1CF         NaN   0.032253     0.01633   0.040926          0
# 12              A2M         NaN   0.034049    0.023638   0.038013          0
# ...             ...         ...        ...         ...        ...        ...
# 23830        ZYG11A         NaN    0.97117    0.548165   0.135277   0.493042
# 23831        ZYG11B         NaN   0.939902     1.57895    1.42039    1.21729
# 23832           ZYX         NaN    6.98823      8.1464    103.529    36.0483
# 23833         ZZEF1         NaN    2.51748    0.448507    1.27063    2.49718
# 23834          ZZZ3         NaN    3.04858      18.574    1.64715    2.30652
#
# ...

# %%
genomics.drop(columns = ['Unnamed: 1'], inplace=True)
genomics.head()
# Out:
#       Unnamed: 0 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 8   Gene names c       MCF7  MDA_MB_231     HS578T     BT_549       T47D  \
# 9           A1BG    1.91821    0.492422    3.36955    6.00088    3.72562
# 10      A1BG-AS1    2.89241     0.11608    1.16519    1.91839    1.64736
# 11          A1CF   0.032253     0.01633   0.040926          0   0.010251
# 12           A2M   0.034049    0.023638   0.038013          0    0.01428
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 52 Unnamed: 53
# 8      SF_268     SF_295     SF_539      SNB_19  ...        PC_3      DU_145  \
# 9     2.74292    2.12943     1.8069     1.78819  ...     0.15359      1.8176
# 10   0.168513    2.08635    1.73184    0.209847  ...    0.111959    0.305528
# 11          0   0.014853   0.013028    0.043841  ...    0.168796    0.099566
# 12   0.046827   0.020656   0.233577     0.39835  ...    0.053483    0.122403
#
# ...

# %%
genomics.reset_index(inplace=True, drop=True)
genomics.head(2)
# Out:
#      Unnamed: 0 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0  Gene names c       MCF7  MDA_MB_231     HS578T     BT_549       T47D  \
# 1          A1BG    1.91821    0.492422    3.36955    6.00088    3.72562
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 52 Unnamed: 53
# 0     SF_268     SF_295     SF_539      SNB_19  ...        PC_3      DU_145  \
# 1    2.74292    2.12943     1.8069     1.78819  ...     0.15359      1.8176
#
#   Unnamed: 54 Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58 Unnamed: 59
# 0       786_0        A498        ACHN      CAKI_1     RXF_393       SN12C  \
# 1    0.284454    0.356813     0.49115    0.843544    0.487173     1.89534
#
#   Unnamed: 60 Unnamed: 61
# 0       TK_10       UO_31
# 1    0.054503    0.267792
#
# [2 rows x 61 columns]

# %%
genomics.columns = genomics.iloc[0]
genomics = genomics.iloc[1:, ]
genomics.reset_index(inplace=True, drop=True)
genomics.head(5)
# Out:
# 0 Gene names c      MCF7 MDA_MB_231    HS578T   BT_549      T47D    SF_268
# 0         A1BG   1.91821   0.492422   3.36955  6.00088   3.72562   2.74292  \
# 1     A1BG-AS1   2.89241    0.11608   1.16519  1.91839   1.64736  0.168513
# 2         A1CF  0.032253    0.01633  0.040926        0  0.010251         0
# 3          A2M  0.034049   0.023638  0.038013        0   0.01428  0.046827
# 4      A2M-AS1  0.206964          0         0        0  0.059689         0
#
# 0    SF_295    SF_539    SNB_19  ...      PC_3    DU_145     786_0      A498
# 0   2.12943    1.8069   1.78819  ...   0.15359    1.8176  0.284454  0.356813  \
# 1   2.08635   1.73184  0.209847  ...  0.111959  0.305528         0  0.047968
# 2  0.014853  0.013028  0.043841  ...  0.168796  0.099566   0.02098  0.055965
# 3  0.020656  0.233577   0.39835  ...  0.053483  0.122403    0.0397  0.027149
# 4         0  0.344345  0.111546  ...  0.179583  0.814983         0  0.059639
#
# ...

# %%
gen = genomics.T
gen.head()
# Out:
#                  0         1         2         3         4         5
# 0
# Gene names c      A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1  \
# MCF7           1.91821   2.89241  0.032253  0.034049  0.206964         0
# MDA_MB_231    0.492422   0.11608   0.01633  0.023638         0  0.014518
# HS578T         3.36955   1.16519  0.040926  0.038013         0  0.088387
# BT_549         6.00088   1.91839         0         0         0         0
#
#               6         7         8         9      ...    23816    23817
# 0                                                  ...
# Gene names c  A2MP1   A3GALT2    A4GALT     A4GNT  ...   ZWILCH    ZWINT  \
# MCF7              0         0   2.45916         0  ...  8.52237  22.4779
# MDA_MB_231        0  0.066887  0.215325         0  ...  16.7579  27.5575
# HS578T            0         0  0.354048  0.296847  ...  1.96807  3.22352
# BT_549            0         0   5.52491         0  ...  1.93205  3.74886
#
# ...

# %%
gen.index.name = 'hello'
gen.reset_index(inplace=True)

# %%
gen
# Out:
#            hello         0         1         2         3         4         5
# 0   Gene names c      A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1  \
# 1           MCF7   1.91821   2.89241  0.032253  0.034049  0.206964         0
# 2     MDA_MB_231  0.492422   0.11608   0.01633  0.023638         0  0.014518
# 3         HS578T   3.36955   1.16519  0.040926  0.038013         0  0.088387
# 4         BT_549   6.00088   1.91839         0         0         0         0
# ..           ...       ...       ...       ...       ...       ...       ...
# 56        CAKI_1  0.843544  0.420918         0  0.025376         0         0
# 57       RXF_393  0.487173  0.966634  0.013433   0.01425  0.107474  0.015877
# 58         SN12C   1.89534  0.580316  0.017469  0.025225         0         0
# 59         TK_10  0.054503         0         0         0         0         0
# 60         UO_31  0.267792  0.386497         0         0  0.171099         0
#
# ...

# %%
gen.columns = gen.iloc[0]
gen = gen.iloc[1:]

# %%
gen.reset_index(inplace=True, drop=True)

# %%
gen.head()
# Out:
# 0 Gene names c      A1BG A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1
# 0         MCF7   1.91821  2.89241  0.032253  0.034049  0.206964         0  \
# 1   MDA_MB_231  0.492422  0.11608   0.01633  0.023638         0  0.014518
# 2       HS578T   3.36955  1.16519  0.040926  0.038013         0  0.088387
# 3       BT_549   6.00088  1.91839         0         0         0         0
# 4         T47D   3.72562  1.64736  0.010251   0.01428  0.059689         0
#
# 0 A2MP1   A3GALT2    A4GALT  ...   ZWILCH    ZWINT      ZXDA      ZXDB
# 0     0         0   2.45916  ...  8.52237  22.4779  0.438814   1.50591  \
# 1     0  0.066887  0.215325  ...  16.7579  27.5575  0.319327   3.43411
# 2     0         0  0.354048  ...  1.96807  3.22352   0.15762  0.343406
# 3     0         0   5.52491  ...  1.93205  3.74886  0.452336  0.940899
# 4     0  0.152862  0.711732  ...   4.0222  25.6328  0.552313   1.84686
#
# 0     ZXDC    ZYG11A    ZYG11B      ZYX     ZZEF1     ZZZ3
# ...

# %%
gen.shape
# Out:
# (60, 23827)

# %%
type(gen.iloc[1][gen.columns[1]])
# Out:
# float

# %%
gen.replace(0, np.nan, inplace=True)

# %%
gen = gen.fillna(gen.iloc[:, 1:].mean())

# %%
cell_lines = [''.join(y) for y in [x.split('_') for x in list(gen[f'{gen.columns[0]}'])]]

# %%
cell_lines
# Out:
# ['MCF7',
#  'MDAMB231',
#  'HS578T',
#  'BT549',
#  'T47D',
#  'SF268',
#  'SF295',
#  'SF539',
#  'SNB19',
#  'SNB75',
#  'U251',
#  'COLO205',
#  'HCC2998',
#  'HCT116',
#  'HCT15',
#  'HT29',
#  'KM12',
#  'SW620',
#  'CCRFCEM',
#  'HL60',
#  'K562',
#  'MOLT4',
#  'RPMI8226',
#  'SR',
#  'LOXIMVI',
#  'MALME3M',
#  'M14',
#  'SKMEL2',
#  'SKMEL28',
#  'SKMEL5',
#  'UACC257',
#  'UACC62',
#  'MDAMB435',
#  'MDAN',
#  'A549',
#  'EKVX',
#  'HOP62',
#  'HOP92',
#  'NCIH226',
#  'NCIH23',
#  'NCIH322M',
#  'NCIH460',
#  'NCIH522',
#  'IGROV1',
#  'OVCAR3',
#  'OVCAR4',
#  'OVCAR5',
#  'OVCAR8',
#  'SKOV3',
#  'NCIADRRES',
#  'PC3',
#  'DU145',
#  '7860',
#  'A498',
#  'ACHN',
#  'CAKI1',
#  'RXF393',
#  'SN12C',
#  'TK10',
#  'UO31']

# %%
carbo = pd.read_csv('/Users/neil/Desktop/NCI Cell Lines/Tolylquinone_metabolic_NCI.csv')
carbo.head()
# Out:
#          Cell Line  Acetone ; Propanal ; acetone
# 0     Breast_BT549                      0.021811  \
# 1    Breast_HS578T                      0.010611
# 2  Breast_MDAMB231                      0.030946
# 3      Breast_T47D                      0.008574
# 4        CNS_SF268                      0.012726
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea
# 0                        0.006137  1.801231  0.178675  \
# 1                        0.006815  0.884542  0.093390
# 2                        0.006278  3.830076  0.384303
# 3                        0.005661  0.296663  0.035179
# 4                        0.003326       NaN       NaN
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate
# 0                            0.031762                          0.143416  \
# 1                            0.016027                          0.037372
# 2                            0.027088                          0.065463
# ...

# %%
carbo_cells = list(carbo[f'{carbo.columns[-3]}'])
count, missing = 0, []
for i in cell_lines:
    if i not in carbo_cells:
        count+=1
        missing.append(i)
count
# Out:
# 9

# %%
gen['cells'] = cell_lines
gen
# Out:
# 0  Gene names c      A1BG  A1BG-AS1      A1CF         A2M   A2M-AS1     A2ML1
# 0          MCF7  1.918210  2.892410  0.032253    0.034049  0.206964  0.198256  \
# 1    MDA_MB_231  0.492422  0.116080  0.016330    0.023638  0.399509  0.014518
# 2        HS578T  3.369550  1.165190  0.040926    0.038013  0.399509  0.088387
# 3        BT_549  6.000880  1.918390  0.100568    4.136850  0.399509  0.198256
# 4          T47D  3.725620  1.647360  0.010251    0.014280  0.059689  0.198256
# 5        SF_268  2.742920  0.168513  0.100568    0.046827  0.399509  0.198256
# 6        SF_295  2.129430  2.086350  0.014853    0.020656  0.399509  0.198256
# 7        SF_539  1.806900  1.731840  0.013028    0.233577  0.344345  0.198256
# 8        SNB_19  1.788190  0.209847  0.043841    0.398350  0.111546  0.054729
# 9        SNB_75  0.513985  0.188132  0.007015  124.649000  5.739220  0.019200
# 10         U251  0.556983  0.391261  0.028943    0.022973  0.046481  0.198256
# ...

# %%
carbo
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
carbo.merge(gen, on = 'cells')
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
temp = carbo.merge(gen, on = 'cells')
x = list(temp['Cell Line'])
missing = []
for i in list(carbo['Cell Line']):
    if i not in x:
        missing.append(i)

# %%
missing
# Out:
# ['Renal_786O']

# %%
renal = pd.DataFrame(carbo.loc[51])
renal
# Out:
#                                                             51
# Cell Line                                           Renal_786O
# Acetone ; Propanal ; acetone                           0.01716
# Acetaldehyde oxime ; HMDB01122                        0.004693
# acetate                                               1.180282
# Urea                                                   0.11918
# ...                                                        ...
# Lacto-N-difucohexaose ; Lacto-N-difucopentaose II     0.028029
# Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosyl...    0.032236
# cells                                                     786O
# Cell names                                                 NaN
# tolylquinone                                          4.713333
#
# [2185 rows x 1 columns]

# %%
renal.reset_index(inplace=True)

# %%
renal
# Out:
#                                                   index          51
# 0                                             Cell Line  Renal_786O
# 1                          Acetone ; Propanal ; acetone     0.01716
# 2                        Acetaldehyde oxime ; HMDB01122    0.004693
# 3                                               acetate    1.180282
# 4                                                  Urea     0.11918
# ...                                                 ...         ...
# 2180  Lacto-N-difucohexaose ; Lacto-N-difucopentaose II    0.028029
# 2181  Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosy...    0.032236
# 2182                                              cells        786O
# 2183                                         Cell names         NaN
# 2184                                       tolylquinone    4.713333
#
# [2185 rows x 2 columns]

# %%
renal = renal.T

# %%
renal.reset_index(inplace=True, drop=True)
renal
# Out:
#          0                             1                               2
# 0   Cell Line  Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122  \
# 1  Renal_786O                       0.01716                        0.004693
#
#        3        4                                   5
# 0   acetate     Urea  Isopropyl alcohol ; Propyl alcohol  \
# 1  1.180282  0.11918                            0.011487
#
#                                6                7             8
# 0  Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 1                          0.040903         0.002219      0.005098
#
#             9     ...                                               2175
# 0  1-pyrrolinium  ...  O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-...  \
# 1       0.002055  ...                                           0.028265
#
#                                                 2176
# 0  LS tetrasaccharide d ; Sialyllacto-N-neotetrao...  \
# ...

# %%
renal.columns = renal.loc[0]

# %%
renal
# Out:
# 0   Cell Line  Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122
# 0   Cell Line  Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122  \
# 1  Renal_786O                       0.01716                        0.004693
#
# 0   acetate     Urea  Isopropyl alcohol ; Propyl alcohol
# 0   acetate     Urea  Isopropyl alcohol ; Propyl alcohol  \
# 1  1.180282  0.11918                            0.011487
#
# 0  Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al
# 0  Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 1                          0.040903         0.002219      0.005098
#
# 0  1-pyrrolinium  ...
# 0  1-pyrrolinium  ...  \
# 1       0.002055  ...
#
# 0 O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose
# ...

# %%
renal = renal.loc[1:, ]

# %%
renal
# Out:
# 0   Cell Line Acetone ; Propanal ; acetone Acetaldehyde oxime ; HMDB01122
# 1  Renal_786O                      0.01716                       0.004693  \
#
# 0   acetate     Urea Isopropyl alcohol ; Propyl alcohol
# 1  1.180282  0.11918                           0.011487  \
#
# 0 Bicarbonate ; Hydrogen carbonate Dimethylsulfide 3-Butyn-1-al 1-pyrrolinium
# 1                         0.040903        0.002219     0.005098      0.002055  \
#
# 0  ...
# 1  ...  \
#
# 0 O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose
# 1                                           0.028265                                                                                                                                                       \
#
# ...

# %%
gen['cells']
# Out:
# 0          MCF7
# 1      MDAMB231
# 2        HS578T
# 3         BT549
# 4          T47D
# 5         SF268
# 6         SF295
# 7         SF539
# 8         SNB19
# 9         SNB75
# 10         U251
# 11      COLO205
# 12      HCC2998
# 13       HCT116
# 14        HCT15
# 15         HT29
# 16         KM12
# 17        SW620
# 18      CCRFCEM
# 19         HL60
# 20         K562
# 21        MOLT4
# 22     RPMI8226
# 23           SR
# 24      LOXIMVI
# 25      MALME3M
# 26          M14
# 27       SKMEL2
# 28      SKMEL28
# 29       SKMEL5
# 30      UACC257
# 31       UACC62
# 32     MDAMB435
# 33         MDAN
# 34         A549
# 35         EKVX
# 36        HOP62
# 37        HOP92
# 38      NCIH226
# 39       NCIH23
# 40     NCIH322M
# 41      NCIH460
# 42      NCIH522
# 43       IGROV1
# 44       OVCAR3
# 45       OVCAR4
# 46       OVCAR5
# 47       OVCAR8
# 48        SKOV3
# 49    NCIADRRES
# 50          PC3
# 51        DU145
# 52         7860
# 53         A498
# 54         ACHN
# ...

# %%
renal_gen = pd.DataFrame(gen.loc[52])
renal_gen.index.name = 'hello'
renal_gen.reset_index(inplace=True)

# %%
renal_gen
# Out:
#               hello        52
# 0      Gene names c     786_0
# 1              A1BG  0.284454
# 2          A1BG-AS1  1.030275
# 3              A1CF   0.02098
# 4               A2M    0.0397
# ...             ...       ...
# 23823        ZYG11B   1.37297
# 23824           ZYX    105.33
# 23825         ZZEF1   1.76548
# 23826          ZZZ3   2.39199
# 23827         cells      7860
#
# [23828 rows x 2 columns]

# %%
renal_gen.columns = renal_gen.loc[0]
renal_gen
# Out:
# 0      Gene names c     786_0
# 0      Gene names c     786_0
# 1              A1BG  0.284454
# 2          A1BG-AS1  1.030275
# 3              A1CF   0.02098
# 4               A2M    0.0397
# ...             ...       ...
# 23823        ZYG11B   1.37297
# 23824           ZYX    105.33
# 23825         ZZEF1   1.76548
# 23826          ZZZ3   2.39199
# 23827         cells      7860
#
# [23828 rows x 2 columns]

# %%
renal_gen = renal_gen.iloc[1:, ].reset_index(drop=True)

# %%
renal_gen
# Out:
# 0     Gene names c     786_0
# 0             A1BG  0.284454
# 1         A1BG-AS1  1.030275
# 2             A1CF   0.02098
# 3              A2M    0.0397
# 4          A2M-AS1  0.399509
# ...            ...       ...
# 23822       ZYG11B   1.37297
# 23823          ZYX    105.33
# 23824        ZZEF1   1.76548
# 23825         ZZZ3   2.39199
# 23826        cells      7860
#
# [23827 rows x 2 columns]

# %%
ren_gen = renal_gen.T
ren_gen.index.name = 'hello'
ren_gen
# Out:
#                  0         1        2       3         4         5
# hello
# Gene names c      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1  \
# 786_0         0.284454  1.030275  0.02098  0.0397  0.399509  0.011258
#
#                  6         7       8         9      ...    23817     23818
# hello                                               ...
# Gene names c     A2MP1   A3GALT2  A4GALT     A4GNT  ...    ZWINT      ZXDA  \
# 786_0         0.036298  0.332738  3.0191  0.098351  ...  17.3171  0.292016
#
#                  23819   23820     23821    23822   23823    23824    23825
# hello
# Gene names c      ZXDB    ZXDC    ZYG11A   ZYG11B     ZYX    ZZEF1     ZZZ3  \
# 786_0         0.580213  2.7838  0.030789  1.37297  105.33  1.76548  2.39199
#
#               23826
# hello
# Gene names c  cells
# 786_0          7860
#
# [2 rows x 23827 columns]

# %%
ren_gen.reset_index(inplace=True)
ren_gen.columns = ren_gen.loc[0]
ren_gen
# Out:
# 0  Gene names c      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1
# 0  Gene names c      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1  \
# 1         786_0  0.284454  1.030275  0.02098  0.0397  0.399509  0.011258
#
# 0     A2MP1   A3GALT2  A4GALT  ...    ZWINT      ZXDA      ZXDB    ZXDC
# 0     A2MP1   A3GALT2  A4GALT  ...    ZWINT      ZXDA      ZXDB    ZXDC  \
# 1  0.036298  0.332738  3.0191  ...  17.3171  0.292016  0.580213  2.7838
#
# 0    ZYG11A   ZYG11B     ZYX    ZZEF1     ZZZ3  cells
# 0    ZYG11A   ZYG11B     ZYX    ZZEF1     ZZZ3  cells
# 1  0.030789  1.37297  105.33  1.76548  2.39199   7860
#
# [2 rows x 23828 columns]

# %%
ren_gen = ren_gen.iloc[1:, ]
ren_gen
# Out:
# 0 Gene names c      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1
# 1        786_0  0.284454  1.030275  0.02098  0.0397  0.399509  0.011258  \
#
# 0     A2MP1   A3GALT2  A4GALT  ...    ZWINT      ZXDA      ZXDB    ZXDC
# 1  0.036298  0.332738  3.0191  ...  17.3171  0.292016  0.580213  2.7838  \
#
# 0    ZYG11A   ZYG11B     ZYX    ZZEF1     ZZZ3 cells
# 1  0.030789  1.37297  105.33  1.76548  2.39199  7860
#
# [1 rows x 23828 columns]

# %%
ren_gen.rename(columns = {f'{ren_gen.columns[0]}': f'{renal.columns[0]}'}, inplace=True)

# %%
ren_gen.reset_index(inplace=True, drop=True)

# %%
ren_gen[f'{ren_gen.columns[0]}'] = ren_gen[f'{ren_gen.columns[0]}'].replace(ren_gen.loc[0][f'{ren_gen.columns[0]}'], 'Renal_786O')

# %%
ren_gen
# Out:
# 0   Cell Line      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1
# 0  Renal_786O  0.284454  1.030275  0.02098  0.0397  0.399509  0.011258  \
#
# 0     A2MP1   A3GALT2  A4GALT  ...    ZWINT      ZXDA      ZXDB    ZXDC
# 0  0.036298  0.332738  3.0191  ...  17.3171  0.292016  0.580213  2.7838  \
#
# 0    ZYG11A   ZYG11B     ZYX    ZZEF1     ZZZ3 cells
# 0  0.030789  1.37297  105.33  1.76548  2.39199  7860
#
# [1 rows x 23828 columns]

# %%
ren_comb = pd.concat([ren_gen, renal], axis=0)

# %%
ren_comb
# Out:
# 0   Cell Line      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1
# 0  Renal_786O  0.284454  1.030275  0.02098  0.0397  0.399509  0.011258  \
# 1  Renal_786O       NaN       NaN      NaN     NaN       NaN       NaN
#
# 0     A2MP1   A3GALT2  A4GALT  ...
# 0  0.036298  0.332738  3.0191  ...  \
# 1       NaN       NaN     NaN  ...
#
# 0 2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa
# 0                                                NaN                                                                                                                          \
# 1                                           0.020844
#
# 0 O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose
# ...

# %%
ren_comb.replace(np.nan, 0.0, inplace=True)
rc = ren_comb.groupby(f'{ren_comb.columns[0]}').sum().reset_index()

# %%
rc
# Out:
# 0   Cell Line      A1BG  A1BG-AS1     A1CF     A2M   A2M-AS1     A2ML1
# 0  Renal_786O  0.284454  1.030275  0.02098  0.0397  0.399509  0.011258  \
#
# 0     A2MP1   A3GALT2  A4GALT  ...
# 0  0.036298  0.332738  3.0191  ...  \
#
# 0  2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa
# 0                                           0.020844                                                                                                                           \
#
# 0  O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose
# 0                                           0.028265                                                                                                                                                        \
# ...

# %%
temp
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
final = pd.concat([temp, rc], ignore_index=True)

# %%
final.shape
# Out:
# (52, 26012)

# %%
ren_gen.isna().values.any()
# Out:
# False

# %%
rc.isna().values.any()
# Out:
# False

# %%
final
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
write = final.sort_values(by=f'{final.columns[0]}').reset_index(drop=True)

# %%
write
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
write.to_csv(f'{carbo.columns[-1]}_integrated.csv', index=False, sep=',')

# %%
pd.read_csv(f'{carbo.columns[-1]}_integrated.csv')
# Out:
#             Cell Line  Acetone ; Propanal ; acetone
# 0        Breast_BT549                      0.021811  \
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...
