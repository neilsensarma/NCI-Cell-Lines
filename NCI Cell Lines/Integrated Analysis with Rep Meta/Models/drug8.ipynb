# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
np.random.seed(42)

# %%
#store the path of the drug-metabolite file
path = 'C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\Datasets\\citrinin_integrated.csv'

# %%
#extract the name of the drug

dr = path.split('\\')[-1]
drug_name = dr.split('_')[0]
drug_name
# Out:
# 'citrinin'

# %%
#read the input drug-metabolite integrated data
data = pd.read_csv(path)

# %%
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...   ZWILCH    ZWINT  \
# 0         0.004437      0.001118       0.002353  ...  1.93205  3.74886
# 1              NaN      0.005778       0.003199  ...  1.96807  3.22352
#
#        ZXDA      ZXDB     ZXDC    ZYG11A   ZYG11B       ZYX    ZZEF1     ZZZ3
# 0  0.452336  0.940899  2.78817  0.493042  1.21729   36.0483  2.49718  2.30652
# 1  0.157620  0.343406  2.11181  0.135277  1.42039  103.5290  1.27063  1.64715
#
# [2 rows x 26012 columns]

# %%
#drop the target drug column
drug = data.pop(f'{drug_name}')

# %%
#read the representative set of metabolites

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()
    
#read the genes

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\list_of_genes.txt', 'r+') as f:
     rep_genes = f.read().strip().splitlines()   
     
rep_genes.extend(rep_meta)

# %%
#read the representative set of metabolites

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()
    
#read the genes

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\list_of_genes.txt', 'r+') as f:
     rep_genes = f.read().strip().splitlines()   
     
rep_genes.extend(rep_meta)

# %%
len(rep_meta), len(rep_genes)
# Out:
# (197, 24023)

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#select only the representative metabolites and the gene expression profiles
X = X[rep_genes]

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
X.shape
# Out:
# (52, 24023)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((52, 24023), (52,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    35
# 1    17
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#        A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0  4.252086  1.037334 -0.004297  0.032270 -0.014117  0.019787  0.060087
# 1  1.949560  0.208509 -0.239529 -0.235953 -0.014117 -0.210482  0.060087
#
#     A3GALT2    A4GALT     A4GNT  ...  Theaflavin-3-gallate  \
# 0 -0.104252  2.403968  0.071395  ...             -1.091052
# 1 -0.104252 -1.021326  5.042785  ...             -0.682554
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -0.981083
# 1                                          -0.095040
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.394950
# 1                                          -1.151304
#
#    beta-casomorphin (1-6)  \
# 0               -1.187590
# 1                0.019664
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.907110
# 1                                          -0.929615
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.107392            -0.322921             0.338147    -0.650807
# 1 -0.960551            -1.033955            -2.165956    -1.575279
#
#    dynorphin A 1-8
# 0         0.946799
# 1         0.576646
#
# [2 rows x 24023 columns]

# %%
X.shape, y.shape
# Out:
# ((70, 24023), (70,))

# %%
y.value_counts()
# Out:
# 1    35
# 0    35
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.head(2)
# Out:
#        A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0  4.252086  1.037334 -0.004297  0.032270 -0.014117  0.019787  0.060087
# 1  1.949560  0.208509 -0.239529 -0.235953 -0.014117 -0.210482  0.060087
#
#     A3GALT2    A4GALT     A4GNT  ...  Theaflavin-3-gallate  \
# 0 -0.104252  2.403968  0.071395  ...             -1.091052
# 1 -0.104252 -1.021326  5.042785  ...             -0.682554
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -0.981083
# 1                                          -0.095040
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.394950
# 1                                          -1.151304
#
#    beta-casomorphin (1-6)  \
# 0               -1.187590
# 1                0.019664
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.907110
# 1                                          -0.929615
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.107392            -0.322921             0.338147    -0.650807
# 1 -0.960551            -1.033955            -2.165956    -1.575279
#
#    dynorphin A 1-8
# 0         0.946799
# 1         0.576646
#
# [2 rows x 24023 columns]

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.20, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.shape, X_test.shape
# Out:
# ((56, 24023), (14, 24023))

# %%
y_train.value_counts(), y_test.value_counts()
# Out:
# (0    28
#  1    28
#  dtype: int64,
#  1    7
#  0    7
#  dtype: int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store the number of features being selected each run
num_features = []

#define the model
model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features.append(len(X_train.columns))
    
    #define the machine learning model and train it
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 629
# Number of features selected during iteration 1: 623
# Number of features selected during iteration 2: 617
# Number of features selected during iteration 3: 609
# Number of features selected during iteration 4: 610
# Number of features selected during iteration 5: 625
# Number of features selected during iteration 6: 637
# Number of features selected during iteration 7: 591
# Number of features selected during iteration 8: 617
# Number of features selected during iteration 9: 615
# Number of features selected during iteration 10: 617
# Number of features selected during iteration 11: 634
# Number of features selected during iteration 12: 631
# Number of features selected during iteration 13: 613
# Number of features selected during iteration 14: 617
# Number of features selected during iteration 15: 615
# Number of features selected during iteration 16: 618
# Number of features selected during iteration 17: 617
# Number of features selected during iteration 18: 634
# Number of features selected during iteration 19: 629
# Number of features selected during iteration 20: 621
# Number of features selected during iteration 21: 637
# Number of features selected during iteration 22: 600
# Number of features selected during iteration 23: 628
# Number of features selected during iteration 24: 623
# Number of features selected during iteration 25: 623
# Number of features selected during iteration 26: 609
# Number of features selected during iteration 27: 620
# Number of features selected during iteration 28: 605
# Number of features selected during iteration 29: 604
# Number of features selected during iteration 30: 620
# Number of features selected during iteration 31: 603
# Number of features selected during iteration 32: 607
# Number of features selected during iteration 33: 603
# Number of features selected during iteration 34: 598
# Number of features selected during iteration 35: 625
# Number of features selected during iteration 36: 630
# Number of features selected during iteration 37: 616
# Number of features selected during iteration 38: 619
# Number of features selected during iteration 39: 623
# Number of features selected during iteration 40: 622
# Number of features selected during iteration 41: 614
# Number of features selected during iteration 42: 616
# Number of features selected during iteration 43: 605
# Number of features selected during iteration 44: 624
# Number of features selected during iteration 45: 607
# Number of features selected during iteration 46: 616
# Number of features selected during iteration 47: 606
# Number of features selected during iteration 48: 618
# Number of features selected during iteration 49: 613
# Accuracy score: 0.9600000000000002, Standard deviation: 0.049815987926179126
# Recall score: 0.9399999999999998, Standard deviation: 0.0705083581671604
# Precision score: 0.9814285714285714, Standard deviation: 0.05248420559306099

# %%
features = list(X_train_new.columns)
count = 0
for i in features:
    if i in rep_meta:
        count+=1 #get the number of metabolites selected from the represented features
count, len(features) - count #count the number of genes
# Out:
# (6, 607)

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0   4.252086  1.037334 -0.004297  0.032270 -0.014117  0.019787  0.060087
# 1   1.949560  0.208509 -0.239529 -0.235953 -0.014117 -0.210482  0.060087
# 2  -0.568050 -0.945937 -0.336543 -0.236893 -0.014117 -0.365302  0.060087
# 3   2.261136  0.739091 -0.360518 -0.237506 -0.515343  0.019787  0.060087
# 4   1.401232 -0.888240 -0.004297 -0.235376 -0.014117  0.019787  0.060087
# ..       ...       ...       ...       ...       ...       ...       ...
# 65 -0.870261 -0.538599  0.042742 -0.126029 -0.206288  0.019787  0.060087
# 66 -0.360755  0.402967  0.008203 -0.233592 -0.029185 -0.331478  0.060087
# 67  1.699662  0.922986 -0.004297 -0.131206 -0.014117  0.019787  0.060087
# 68 -0.769558 -0.112271 -0.218785 -0.235689 -0.069432 -0.305302  0.060087
# 69 -0.825268 -0.928356  0.247296 -0.235060 -0.317401  0.019787  0.060087
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 0  -0.104252  2.403968  0.071395  ...
# 1  -0.104252 -1.021326  5.042785  ...
# 2  -0.569995 -1.113219  0.071395  ...
# 3  -0.419376 -0.784388  0.071395  ...
# 4  -0.346046 -1.035701 -0.091191  ...
# ..       ...       ...       ...  ...
# 65 -0.104252 -0.589406  0.071395  ...
# 66 -0.104252 -0.177705  0.071395  ...
# 67 -0.104252  1.237181  0.071395  ...
# 68 -0.104252  0.464264  0.071395  ...
# 69 -0.130908 -0.755885  0.071395  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.394950
# 1                                           -1.151304
# 2                                            0.059571
# 3                                           -0.117330
# 4                                           -1.242534
# ..                                                ...
# 65                                           2.308057
# 66                                           0.105721
# 67                                          -0.174184
# 68                                          -0.083421
# 69                                           2.139467
#
#     beta-casomorphin (1-6)  \
# 0                -1.187590
# 1                 0.019664
# 2                -1.041614
# 3                -0.288185
# 4                 0.281905
# ..                     ...
# 65                1.119535
# 66                0.045525
# 67               -1.137156
# 68               -0.096854
# 69                0.819176
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.907110
# 1                                           -0.929615
# 2                                           -0.108831
# 3                                            0.393971
# 4                                           -1.685964
# ..                                                ...
# 65                                           1.245847
# 66                                           0.163276
# 67                                           0.134886
# 68                                          -0.284078
# 69                                           1.467670
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.107392            -0.322921             0.338147    -0.650807
# 1  -0.960551            -1.033955            -2.165956    -1.575279
# 2  -0.987658            -0.177096            -0.547006    -0.530402
# 3   0.389097            -0.269967            -0.828767     0.687513
# 4   1.353960            -1.984796            -0.663144    -1.073144
# ..       ...                  ...                  ...          ...
# 65 -0.057174             0.474466             1.542349     1.608172
# 66 -0.172301             1.364920             0.224841    -0.333241
# 67 -1.008295            -0.261082             0.070419    -0.502206
# 68 -0.479752            -0.580953             0.348071    -0.015766
# 69 -0.437261            -0.247287             1.725151     1.190334
#
#     dynorphin A 1-8  test_proba  target
# 0          0.946799         NaN     NaN
# 1          0.576646         NaN     NaN
# 2         -0.372065         NaN     NaN
# 3         -0.954890         NaN     NaN
# 4         -0.223805         NaN     NaN
# ..              ...         ...     ...
# 65        -0.517307         NaN     NaN
# 66         0.291746         NaN     NaN
# 67         0.735418         NaN     NaN
# 68         0.007402         NaN     NaN
# 69        -0.304289         NaN     NaN
#
# [70 rows x 24025 columns]

# %%
df1_main = df1.iloc[:51, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (3, 24025)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([42, 43, 45], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store the number of features selected in each iteration
num_features2 = []

#define a list to store accuracy, precision and recall 
model2 = SVC(C=1, gamma=1, probability=True)
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = RandomForestClassifier(n_estimators=150, class_weight='balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.feature_importances_
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train-test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features2.append(len(X_train_new.columns))

    #define the SVM model and train it
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 619
# Features selected during iteration 1: 595
# Features selected during iteration 2: 622
# Features selected during iteration 3: 627
# Features selected during iteration 4: 617
# Features selected during iteration 5: 620
# Features selected during iteration 6: 646
# Features selected during iteration 7: 622
# Features selected during iteration 8: 637
# Features selected during iteration 9: 619
# Features selected during iteration 10: 644
# Features selected during iteration 11: 623
# Features selected during iteration 12: 627
# Features selected during iteration 13: 627
# Features selected during iteration 14: 595
# Features selected during iteration 15: 604
# Features selected during iteration 16: 622
# Features selected during iteration 17: 620
# Features selected during iteration 18: 592
# Features selected during iteration 19: 606
# Features selected during iteration 20: 616
# Features selected during iteration 21: 606
# Features selected during iteration 22: 607
# Features selected during iteration 23: 637
# Features selected during iteration 24: 619
# Features selected during iteration 25: 603
# Features selected during iteration 26: 644
# Features selected during iteration 27: 621
# Features selected during iteration 28: 621
# Features selected during iteration 29: 637
# Features selected during iteration 30: 624
# Features selected during iteration 31: 621
# Features selected during iteration 32: 631
# Features selected during iteration 33: 631
# Features selected during iteration 34: 614
# Features selected during iteration 35: 605
# Features selected during iteration 36: 630
# Features selected during iteration 37: 607
# Features selected during iteration 38: 597
# Features selected during iteration 39: 619
# Features selected during iteration 40: 628
# Features selected during iteration 41: 614
# Features selected during iteration 42: 622
# Features selected during iteration 43: 603
# Features selected during iteration 44: 616
# Features selected during iteration 45: 627
# Features selected during iteration 46: 605
# Features selected during iteration 47: 626
# Features selected during iteration 48: 621
# Features selected during iteration 49: 598
# Accuracy score: 0.5714285714285714, Standard deviation: 0.0
# Recall score: 0.14285714285714285, Standard deviation: 0.0
# Precision score: 1.0, Standard deviation: 0.0

# %%
print(f'Average number of features being selected: {np.mean(num_features2)}')
# Out:
# Average number of features being selected: 618.68

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:51, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2MP1, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AATK-AS1, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD11-AS1, ABHD12, ABHD12B, ABHD13, ...]
# Index: []
#
# [0 rows x 24025 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store the number of features being selected in each iteration
num_features3 = []

#define the XGBoost model
model3 = XGBClassifier()

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier()
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features3.append(len(X_train_new.columns))

    #define XGBoost model and train it
    model3.fit(X_train_new, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test_new)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test_new))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 32
# Features selected during iteration 1: 32
# Features selected during iteration 2: 32
# Features selected during iteration 3: 32
# Features selected during iteration 4: 32
# Features selected during iteration 5: 32
# Features selected during iteration 6: 32
# Features selected during iteration 7: 32
# Features selected during iteration 8: 32
# Features selected during iteration 9: 32
# Features selected during iteration 10: 32
# Features selected during iteration 11: 32
# Features selected during iteration 12: 32
# Features selected during iteration 13: 32
# Features selected during iteration 14: 32
# Features selected during iteration 15: 32
# Features selected during iteration 16: 32
# Features selected during iteration 17: 32
# Features selected during iteration 18: 32
# Features selected during iteration 19: 32
# Features selected during iteration 20: 32
# Features selected during iteration 21: 32
# Features selected during iteration 22: 32
# Features selected during iteration 23: 32
# Features selected during iteration 24: 32
# Features selected during iteration 25: 32
# Features selected during iteration 26: 32
# Features selected during iteration 27: 32
# Features selected during iteration 28: 32
# Features selected during iteration 29: 32
# Features selected during iteration 30: 32
# Features selected during iteration 31: 32
# Features selected during iteration 32: 32
# Features selected during iteration 33: 32
# Features selected during iteration 34: 32
# Features selected during iteration 35: 32
# Features selected during iteration 36: 32
# Features selected during iteration 37: 32
# Features selected during iteration 38: 32
# Features selected during iteration 39: 32
# Features selected during iteration 40: 32
# Features selected during iteration 41: 32
# Features selected during iteration 42: 32
# Features selected during iteration 43: 32
# Features selected during iteration 44: 32
# Features selected during iteration 45: 32
# Features selected during iteration 46: 32
# Features selected during iteration 47: 32
# Features selected during iteration 48: 32
# Features selected during iteration 49: 32
# Accuracy score: 0.857142857142857, Standard deviation: 1.1102230246251565e-16
# Recall score: 0.857142857142857, Standard deviation: 1.1102230246251565e-16
# Precision score: 0.857142857142857, Standard deviation: 1.1102230246251565e-16

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0   4.252086  1.037334 -0.004297  0.032270 -0.014117  0.019787  0.060087
# 1   1.949560  0.208509 -0.239529 -0.235953 -0.014117 -0.210482  0.060087
# 2  -0.568050 -0.945937 -0.336543 -0.236893 -0.014117 -0.365302  0.060087
# 3   2.261136  0.739091 -0.360518 -0.237506 -0.515343  0.019787  0.060087
# 4   1.401232 -0.888240 -0.004297 -0.235376 -0.014117  0.019787  0.060087
# ..       ...       ...       ...       ...       ...       ...       ...
# 65 -0.870261 -0.538599  0.042742 -0.126029 -0.206288  0.019787  0.060087
# 66 -0.360755  0.402967  0.008203 -0.233592 -0.029185 -0.331478  0.060087
# 67  1.699662  0.922986 -0.004297 -0.131206 -0.014117  0.019787  0.060087
# 68 -0.769558 -0.112271 -0.218785 -0.235689 -0.069432 -0.305302  0.060087
# 69 -0.825268 -0.928356  0.247296 -0.235060 -0.317401  0.019787  0.060087
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 0  -0.104252  2.403968  0.071395  ...
# 1  -0.104252 -1.021326  5.042785  ...
# 2  -0.569995 -1.113219  0.071395  ...
# 3  -0.419376 -0.784388  0.071395  ...
# 4  -0.346046 -1.035701 -0.091191  ...
# ..       ...       ...       ...  ...
# 65 -0.104252 -0.589406  0.071395  ...
# 66 -0.104252 -0.177705  0.071395  ...
# 67 -0.104252  1.237181  0.071395  ...
# 68 -0.104252  0.464264  0.071395  ...
# 69 -0.130908 -0.755885  0.071395  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.394950
# 1                                           -1.151304
# 2                                            0.059571
# 3                                           -0.117330
# 4                                           -1.242534
# ..                                                ...
# 65                                           2.308057
# 66                                           0.105721
# 67                                          -0.174184
# 68                                          -0.083421
# 69                                           2.139467
#
#     beta-casomorphin (1-6)  \
# 0                -1.187590
# 1                 0.019664
# 2                -1.041614
# 3                -0.288185
# 4                 0.281905
# ..                     ...
# 65                1.119535
# 66                0.045525
# 67               -1.137156
# 68               -0.096854
# 69                0.819176
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.907110
# 1                                           -0.929615
# 2                                           -0.108831
# 3                                            0.393971
# 4                                           -1.685964
# ..                                                ...
# 65                                           1.245847
# 66                                           0.163276
# 67                                           0.134886
# 68                                          -0.284078
# 69                                           1.467670
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.107392            -0.322921             0.338147    -0.650807
# 1  -0.960551            -1.033955            -2.165956    -1.575279
# 2  -0.987658            -0.177096            -0.547006    -0.530402
# 3   0.389097            -0.269967            -0.828767     0.687513
# 4   1.353960            -1.984796            -0.663144    -1.073144
# ..       ...                  ...                  ...          ...
# 65 -0.057174             0.474466             1.542349     1.608172
# 66 -0.172301             1.364920             0.224841    -0.333241
# 67 -1.008295            -0.261082             0.070419    -0.502206
# 68 -0.479752            -0.580953             0.348071    -0.015766
# 69 -0.437261            -0.247287             1.725151     1.190334
#
#     dynorphin A 1-8  test_proba  target
# 0          0.946799         NaN     NaN
# 1          0.576646         NaN     NaN
# 2         -0.372065         NaN     NaN
# 3         -0.954890         NaN     NaN
# 4         -0.223805         NaN     NaN
# ..              ...         ...     ...
# 65        -0.517307         NaN     NaN
# 66         0.291746         NaN     NaN
# 67         0.735418         NaN     NaN
# 68         0.007402         NaN     NaN
# 69        -0.304289         NaN     NaN
#
# [70 rows x 24025 columns]

# %%
df3_main = df3.iloc[:51, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#         A1BG  A1BG-AS1      A1CF      A2M   A2M-AS1     A2ML1     A2MP1  \
# 42  0.591537 -0.737468 -0.008250 -0.23043  0.598698 -0.127399  0.060087
# 43 -0.864542 -0.950472  0.264801 -0.23494 -0.338503  0.019787  0.060087
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 42  4.932882 -0.184314  0.015462  ...
# 43 -0.104252 -0.896759  0.071395  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 42                                          -0.946014
# 43                                           2.308433
#
#     beta-casomorphin (1-6)  \
# 42                0.077703
# 43                0.576402
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 42                                          -1.440134
# 43                                           1.533664
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 42 -0.040575            -2.096860            -1.021575    -1.701823
# 43 -0.424263            -0.307266             1.898789     1.308358
#
#     dynorphin A 1-8  test_proba  target
# 42         0.525505    0.854435     1.0
# 43        -0.363661    0.956273     1.0
#
# [2 rows x 24025 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {42, 43, 45}

# %%
df1_total = df1.loc[:51, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 42  0.591537 -0.737468 -0.008250 -0.230430  0.598698 -0.127399  0.060087
# 43 -0.864542 -0.950472  0.264801 -0.234940 -0.338503  0.019787  0.060087
# 45 -0.686714 -1.020888 -0.180217 -0.236664 -0.515417 -0.340597  0.060087
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 42  4.932882 -0.184314  0.015462  ...
# 43 -0.104252 -0.896759  0.071395  ...
# 45 -0.294945 -0.140548 -1.649035  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 42                                          -0.946014
# 43                                           2.308433
# 45                                           1.752439
#
#     beta-casomorphin (1-6)  \
# 42                0.077703
# 43                0.576402
# 45               -0.966908
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 42                                          -1.440134
# 43                                           1.533664
# 45                                           1.856774
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 42 -0.040575            -2.096860            -1.021575    -1.701823
# 43 -0.424263            -0.307266             1.898789     1.308358
# 45  0.217827             0.750810             1.075815     1.539978
#
#     dynorphin A 1-8  test_proba  target
# 42         0.525505    0.659600     1.0
# 43        -0.363661    0.796267     1.0
# 45         1.460293    0.508400     1.0
#
# [3 rows x 24025 columns]

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\outputs\\master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\outputs\\total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
