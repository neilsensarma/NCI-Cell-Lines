# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
np.random.seed(42)

# %%
#store the path of the drug-metabolite file
path = 'C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\Datasets\\6-MERCAPTOPURINE_integrated.csv'

# %%
#extract the name of the drug

dr = path.split('\\')[-1]
drug_name = dr.split('_')[0]
drug_name
# Out:
# '6-MERCAPTOPURINE'

# %%
#read the input drug-metabolite integrated data
data = pd.read_csv(path)

# %%
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...   ZWILCH    ZWINT  \
# 0         0.004437      0.001118       0.002353  ...  1.93205  3.74886
# 1              NaN      0.005778       0.003199  ...  1.96807  3.22352
#
#        ZXDA      ZXDB     ZXDC    ZYG11A   ZYG11B       ZYX    ZZEF1     ZZZ3
# 0  0.452336  0.940899  2.78817  0.493042  1.21729   36.0483  2.49718  2.30652
# 1  0.157620  0.343406  2.11181  0.135277  1.42039  103.5290  1.27063  1.64715
#
# [2 rows x 26012 columns]

# %%
#drop the target drug column
drug = data.pop(f'{drug_name}')

# %%
#read the representative set of metabolites

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()
    
#read the genes

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\list_of_genes.txt', 'r+') as f:
     rep_genes = f.read().strip().splitlines()   
     
rep_genes.extend(rep_meta)

# %%
#read the representative set of metabolites

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()
    
#read the genes

with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\list_of_genes.txt', 'r+') as f:
     rep_genes = f.read().strip().splitlines()   
     
rep_genes.extend(rep_meta)

# %%
len(rep_meta), len(rep_genes)
# Out:
# (197, 24023)

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#select only the representative metabolites and the gene expression profiles
X = X[rep_genes]

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
X.shape
# Out:
# (52, 24023)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((52, 24023), (52,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    34
# 1    18
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#        A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0  3.873158  1.044298  0.005217  0.014949  0.020484  0.003521  0.060968
# 1  1.733266  0.210688 -0.226687 -0.249697  0.020484 -0.220790  0.060968
#
#     A3GALT2    A4GALT     A4GNT  ...  Theaflavin-3-gallate  \
# 0  0.033854  1.962531 -0.028401  ...             -1.079555
# 1  0.033854 -0.969799  3.893775  ...             -0.665344
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -0.980276
# 1                                          -0.096181
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.285279
# 1                                          -1.025687
#
#    beta-casomorphin (1-6)  \
# 0               -1.093155
# 1                0.113480
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.953779
# 1                                          -0.832646
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.155724            -0.285507             0.433843    -0.596163
# 1 -1.017651            -0.983345            -2.048186    -1.513650
#
#    dynorphin A 1-8
# 0         1.197337
# 1         0.813311
#
# [2 rows x 24023 columns]

# %%
X.shape, y.shape
# Out:
# ((68, 24023), (68,))

# %%
y.value_counts()
# Out:
# 1    34
# 0    34
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.head(2)
# Out:
#        A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0  3.873158  1.044298  0.005217  0.014949  0.020484  0.003521  0.060968
# 1  1.733266  0.210688 -0.226687 -0.249697  0.020484 -0.220790  0.060968
#
#     A3GALT2    A4GALT     A4GNT  ...  Theaflavin-3-gallate  \
# 0  0.033854  1.962531 -0.028401  ...             -1.079555
# 1  0.033854 -0.969799  3.893775  ...             -0.665344
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -0.980276
# 1                                          -0.096181
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.285279
# 1                                          -1.025687
#
#    beta-casomorphin (1-6)  \
# 0               -1.093155
# 1                0.113480
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.953779
# 1                                          -0.832646
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.155724            -0.285507             0.433843    -0.596163
# 1 -1.017651            -0.983345            -2.048186    -1.513650
#
#    dynorphin A 1-8
# 0         1.197337
# 1         0.813311
#
# [2 rows x 24023 columns]

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.20, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.shape, X_test.shape
# Out:
# ((54, 24023), (14, 24023))

# %%
y_train.value_counts(), y_test.value_counts()
# Out:
# (0    27
#  1    27
#  dtype: int64,
#  0    7
#  1    7
#  dtype: int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store the number of features being selected each run
num_features = []

#define the model
model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features.append(len(X_train.columns))
    
    #define the machine learning model and train it
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 635
# Number of features selected during iteration 1: 641
# Number of features selected during iteration 2: 645
# Number of features selected during iteration 3: 623
# Number of features selected during iteration 4: 648
# Number of features selected during iteration 5: 625
# Number of features selected during iteration 6: 642
# Number of features selected during iteration 7: 632
# Number of features selected during iteration 8: 626
# Number of features selected during iteration 9: 626
# Number of features selected during iteration 10: 628
# Number of features selected during iteration 11: 624
# Number of features selected during iteration 12: 623
# Number of features selected during iteration 13: 639
# Number of features selected during iteration 14: 633
# Number of features selected during iteration 15: 612
# Number of features selected during iteration 16: 636
# Number of features selected during iteration 17: 640
# Number of features selected during iteration 18: 649
# Number of features selected during iteration 19: 621
# Number of features selected during iteration 20: 627
# Number of features selected during iteration 21: 628
# Number of features selected during iteration 22: 643
# Number of features selected during iteration 23: 639
# Number of features selected during iteration 24: 624
# Number of features selected during iteration 25: 637
# Number of features selected during iteration 26: 624
# Number of features selected during iteration 27: 618
# Number of features selected during iteration 28: 636
# Number of features selected during iteration 29: 617
# Number of features selected during iteration 30: 636
# Number of features selected during iteration 31: 636
# Number of features selected during iteration 32: 637
# Number of features selected during iteration 33: 626
# Number of features selected during iteration 34: 622
# Number of features selected during iteration 35: 619
# Number of features selected during iteration 36: 634
# Number of features selected during iteration 37: 639
# Number of features selected during iteration 38: 648
# Number of features selected during iteration 39: 631
# Number of features selected during iteration 40: 615
# Number of features selected during iteration 41: 620
# Number of features selected during iteration 42: 645
# Number of features selected during iteration 43: 625
# Number of features selected during iteration 44: 647
# Number of features selected during iteration 45: 633
# Number of features selected during iteration 46: 624
# Number of features selected during iteration 47: 660
# Number of features selected during iteration 48: 630
# Number of features selected during iteration 49: 623
# Accuracy score: 0.8242857142857142, Standard deviation: 0.08232588305270803
# Recall score: 0.8028571428571428, Standard deviation: 0.08985248682009363
# Precision score: 0.8470238095238095, Standard deviation: 0.10265225680745843

# %%
features = list(X_train_new.columns)
count = 0
for i in features:
    if i in rep_meta:
        count+=1 #get the number of metabolites selected from the represented features
count, len(features) - count #count the number of genes
# Out:
# (7, 616)

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0   3.873158  1.044298  0.005217  0.014949  0.020484  0.003521  0.060968
# 1   1.733266  0.210688 -0.226687 -0.249697  0.020484 -0.220790  0.060968
# 2  -0.606517 -0.950423 -0.322327 -0.250625  0.020484 -0.371605  0.060968
# 3   2.022835  0.744334 -0.345962 -0.251230 -0.473670  0.003521  0.060968
# 4   1.223668 -0.892392  0.005217 -0.249128  0.020484  0.003521  0.060968
# ..       ...       ...       ...       ...       ...       ...       ...
# 63  2.230412  0.658386 -0.118909 -0.082570 -0.135098 -0.132894  0.060968
# 64  1.033762 -0.364427 -0.220522 -0.237042 -0.207284 -0.258168  0.060968
# 65 -0.449549 -0.479406  0.005217 -0.180465 -0.340233  1.055227  0.060968
# 66  3.189094  0.666726 -0.038825 -0.033249 -0.063128 -0.054989  0.060968
# 67 -0.279406  0.834000 -0.159363  0.215041  0.003749 -0.177354  0.060968
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 0   0.033854  1.962531 -0.028401  ...
# 1   0.033854 -0.969799  3.893775  ...
# 2  -0.585520 -1.048467 -0.028401  ...
# 3  -0.385217 -0.766961 -0.028401  ...
# 4  -0.287699 -0.982105 -0.156673  ...
# ..       ...       ...       ...  ...
# 63  0.033854  1.638026 -0.250067  ...
# 64 -0.253588  0.175896  3.208198  ...
# 65 -0.060913  2.277294 -0.028401  ...
# 66 -0.071664  1.797600  0.503083  ...
# 67  0.033854  0.177782 -0.322312  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.285279
# 1                                           -1.025687
# 2                                            0.159660
# 3                                           -0.013512
# 4                                           -1.114994
# ..                                                ...
# 63                                          -0.228060
# 64                                          -1.529600
# 65                                          -0.116374
# 66                                          -0.618103
# 67                                          -0.237193
#
#     beta-casomorphin (1-6)  \
# 0                -1.093155
# 1                 0.113480
# 2                -0.947253
# 3                -0.194211
# 4                 0.375587
# ..                     ...
# 63               -1.053284
# 64               -0.324278
# 65               -0.173768
# 66               -1.012920
# 67               -0.956657
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.953779
# 1                                           -0.832646
# 2                                           -0.034340
# 3                                            0.454692
# 4                                           -1.568281
# ..                                                ...
# 63                                           0.498190
# 64                                          -1.488043
# 65                                           0.253328
# 66                                           0.356484
# 67                                          -0.600312
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.155724            -0.285507             0.433843    -0.596163
# 1  -1.017651            -0.983345            -2.048186    -1.513650
# 2  -1.043139            -0.142389            -0.443507    -0.476668
# 3   0.251417            -0.233535            -0.722785     0.732045
# 4   1.158672            -1.916540            -0.558622    -1.015310
# ..       ...                  ...                  ...          ...
# 63 -1.221772            -0.402260             0.253506    -0.571340
# 64 -0.008327            -1.262678            -1.576543    -1.194670
# 65  2.437213             0.569948             0.239045     0.547359
# 66 -0.757638            -0.527389             0.111385    -0.662265
# 67 -0.924611            -0.466917            -0.491227    -0.724019
#
#     dynorphin A 1-8  test_proba  target
# 0          1.197337         NaN     NaN
# 1          0.813311         NaN     NaN
# 2         -0.170957         NaN     NaN
# 3         -0.775627         NaN     NaN
# 4         -0.017141         NaN     NaN
# ..              ...         ...     ...
# 63         0.665726         NaN     NaN
# 64        -0.392664         NaN     NaN
# 65         0.810787         NaN     NaN
# 66         0.677950    0.890933     1.0
# 67        -0.820857         NaN     NaN
#
# [68 rows x 24025 columns]

# %%
df1_main = df1.iloc[:51, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (1, 24025)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([18], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store the number of features selected in each iteration
num_features2 = []

#define a list to store accuracy, precision and recall 
model2 = SVC(C=1, gamma=1, probability=True)
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = RandomForestClassifier(n_estimators=150, class_weight='balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.feature_importances_
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train-test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features2.append(len(X_train_new.columns))

    #define the SVM model and train it
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 623
# Features selected during iteration 1: 628
# Features selected during iteration 2: 632
# Features selected during iteration 3: 631
# Features selected during iteration 4: 641
# Features selected during iteration 5: 647
# Features selected during iteration 6: 624
# Features selected during iteration 7: 631
# Features selected during iteration 8: 626
# Features selected during iteration 9: 649
# Features selected during iteration 10: 629
# Features selected during iteration 11: 633
# Features selected during iteration 12: 617
# Features selected during iteration 13: 636
# Features selected during iteration 14: 645
# Features selected during iteration 15: 635
# Features selected during iteration 16: 625
# Features selected during iteration 17: 630
# Features selected during iteration 18: 659
# Features selected during iteration 19: 638
# Features selected during iteration 20: 642
# Features selected during iteration 21: 632
# Features selected during iteration 22: 632
# Features selected during iteration 23: 639
# Features selected during iteration 24: 643
# Features selected during iteration 25: 637
# Features selected during iteration 26: 645
# Features selected during iteration 27: 642
# Features selected during iteration 28: 628
# Features selected during iteration 29: 624
# Features selected during iteration 30: 644
# Features selected during iteration 31: 625
# Features selected during iteration 32: 640
# Features selected during iteration 33: 631
# Features selected during iteration 34: 644
# Features selected during iteration 35: 637
# Features selected during iteration 36: 632
# Features selected during iteration 37: 650
# Features selected during iteration 38: 638
# Features selected during iteration 39: 635
# Features selected during iteration 40: 627
# Features selected during iteration 41: 633
# Features selected during iteration 42: 610
# Features selected during iteration 43: 619
# Features selected during iteration 44: 617
# Features selected during iteration 45: 622
# Features selected during iteration 46: 629
# Features selected during iteration 47: 636
# Features selected during iteration 48: 628
# Features selected during iteration 49: 640
# Accuracy score: 0.5714285714285714, Standard deviation: 0.0
# Recall score: 0.14285714285714285, Standard deviation: 0.0
# Precision score: 1.0, Standard deviation: 0.0

# %%
print(f'Average number of features being selected: {np.mean(num_features2)}')
# Out:
# Average number of features being selected: 633.6

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:51, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2MP1, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AATK-AS1, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD11-AS1, ABHD12, ABHD12B, ABHD13, ...]
# Index: []
#
# [0 rows x 24025 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store the number of features being selected in each iteration
num_features3 = []

#define the XGBoost model
model3 = XGBClassifier()

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier()
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features3.append(len(X_train_new.columns))

    #define XGBoost model and train it
    model3.fit(X_train_new, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test_new)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test_new))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 36
# Features selected during iteration 1: 36
# Features selected during iteration 2: 36
# Features selected during iteration 3: 36
# Features selected during iteration 4: 36
# Features selected during iteration 5: 36
# Features selected during iteration 6: 36
# Features selected during iteration 7: 36
# Features selected during iteration 8: 36
# Features selected during iteration 9: 36
# Features selected during iteration 10: 36
# Features selected during iteration 11: 36
# Features selected during iteration 12: 36
# Features selected during iteration 13: 36
# Features selected during iteration 14: 36
# Features selected during iteration 15: 36
# Features selected during iteration 16: 36
# Features selected during iteration 17: 36
# Features selected during iteration 18: 36
# Features selected during iteration 19: 36
# Features selected during iteration 20: 36
# Features selected during iteration 21: 36
# Features selected during iteration 22: 36
# Features selected during iteration 23: 36
# Features selected during iteration 24: 36
# Features selected during iteration 25: 36
# Features selected during iteration 26: 36
# Features selected during iteration 27: 36
# Features selected during iteration 28: 36
# Features selected during iteration 29: 36
# Features selected during iteration 30: 36
# Features selected during iteration 31: 36
# Features selected during iteration 32: 36
# Features selected during iteration 33: 36
# Features selected during iteration 34: 36
# Features selected during iteration 35: 36
# Features selected during iteration 36: 36
# Features selected during iteration 37: 36
# Features selected during iteration 38: 36
# Features selected during iteration 39: 36
# Features selected during iteration 40: 36
# Features selected during iteration 41: 36
# Features selected during iteration 42: 36
# Features selected during iteration 43: 36
# Features selected during iteration 44: 36
# Features selected during iteration 45: 36
# Features selected during iteration 46: 36
# Features selected during iteration 47: 36
# Features selected during iteration 48: 36
# Features selected during iteration 49: 36
# Accuracy score: 0.7142857142857143, Standard deviation: 0.0
# Recall score: 0.857142857142857, Standard deviation: 1.1102230246251565e-16
# Precision score: 0.6666666666666665, Standard deviation: 1.1102230246251565e-16

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 0   3.873158  1.044298  0.005217  0.014949  0.020484  0.003521  0.060968
# 1   1.733266  0.210688 -0.226687 -0.249697  0.020484 -0.220790  0.060968
# 2  -0.606517 -0.950423 -0.322327 -0.250625  0.020484 -0.371605  0.060968
# 3   2.022835  0.744334 -0.345962 -0.251230 -0.473670  0.003521  0.060968
# 4   1.223668 -0.892392  0.005217 -0.249128  0.020484  0.003521  0.060968
# ..       ...       ...       ...       ...       ...       ...       ...
# 63  2.230412  0.658386 -0.118909 -0.082570 -0.135098 -0.132894  0.060968
# 64  1.033762 -0.364427 -0.220522 -0.237042 -0.207284 -0.258168  0.060968
# 65 -0.449549 -0.479406  0.005217 -0.180465 -0.340233  1.055227  0.060968
# 66  3.189094  0.666726 -0.038825 -0.033249 -0.063128 -0.054989  0.060968
# 67 -0.279406  0.834000 -0.159363  0.215041  0.003749 -0.177354  0.060968
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 0   0.033854  1.962531 -0.028401  ...
# 1   0.033854 -0.969799  3.893775  ...
# 2  -0.585520 -1.048467 -0.028401  ...
# 3  -0.385217 -0.766961 -0.028401  ...
# 4  -0.287699 -0.982105 -0.156673  ...
# ..       ...       ...       ...  ...
# 63  0.033854  1.638026 -0.250067  ...
# 64 -0.253588  0.175896  3.208198  ...
# 65 -0.060913  2.277294 -0.028401  ...
# 66 -0.071664  1.797600  0.503083  ...
# 67  0.033854  0.177782 -0.322312  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.285279
# 1                                           -1.025687
# 2                                            0.159660
# 3                                           -0.013512
# 4                                           -1.114994
# ..                                                ...
# 63                                          -0.228060
# 64                                          -1.529600
# 65                                          -0.116374
# 66                                          -0.618103
# 67                                          -0.237193
#
#     beta-casomorphin (1-6)  \
# 0                -1.093155
# 1                 0.113480
# 2                -0.947253
# 3                -0.194211
# 4                 0.375587
# ..                     ...
# 63               -1.053284
# 64               -0.324278
# 65               -0.173768
# 66               -1.012920
# 67               -0.956657
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.953779
# 1                                           -0.832646
# 2                                           -0.034340
# 3                                            0.454692
# 4                                           -1.568281
# ..                                                ...
# 63                                           0.498190
# 64                                          -1.488043
# 65                                           0.253328
# 66                                           0.356484
# 67                                          -0.600312
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.155724            -0.285507             0.433843    -0.596163
# 1  -1.017651            -0.983345            -2.048186    -1.513650
# 2  -1.043139            -0.142389            -0.443507    -0.476668
# 3   0.251417            -0.233535            -0.722785     0.732045
# 4   1.158672            -1.916540            -0.558622    -1.015310
# ..       ...                  ...                  ...          ...
# 63 -1.221772            -0.402260             0.253506    -0.571340
# 64 -0.008327            -1.262678            -1.576543    -1.194670
# 65  2.437213             0.569948             0.239045     0.547359
# 66 -0.757638            -0.527389             0.111385    -0.662265
# 67 -0.924611            -0.466917            -0.491227    -0.724019
#
#     dynorphin A 1-8  test_proba  target
# 0          1.197337         NaN     NaN
# 1          0.813311         NaN     NaN
# 2         -0.170957         NaN     NaN
# 3         -0.775627         NaN     NaN
# 4         -0.017141         NaN     NaN
# ..              ...         ...     ...
# 63         0.665726         NaN     NaN
# 64        -0.392664         NaN     NaN
# 65         0.810787         NaN     NaN
# 66         0.677950    0.973262     1.0
# 67        -0.820857         NaN     NaN
#
# [68 rows x 24025 columns]

# %%
df3_main = df3.iloc[:51, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
# Empty DataFrame
# Columns: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2MP1, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AATK-AS1, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA17P, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC6P1, ABCC6P2, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD11-AS1, ABHD12, ABHD12B, ABHD13, ...]
# Index: []
#
# [0 rows x 24025 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {18}

# %%
df1_total = df1.loc[:51, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1     A2MP1  \
# 18 -0.571868 -0.489631 -0.305499 -0.211334  0.485153  0.003521  0.060968
# 31  0.033628  1.630393  0.005217  0.655499  0.389096  0.003521  0.060968
#
#      A3GALT2    A4GALT     A4GNT  ...  \
# 18 -0.462708 -0.091170 -0.028401  ...
# 31  0.033854 -0.671446 -0.028401  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 18                                          -0.874802
# 31                                          -0.339304
#
#     beta-casomorphin (1-6)  \
# 18                0.113480
# 31               -0.930522
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 18                                          -0.282286
# 31                                          -0.893661
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 18 -2.251987            -1.953906            -1.295089     -0.44493
# 31 -0.535994            -0.337245            -0.900097     -0.90880
#
#     dynorphin A 1-8  test_proba  target
# 18        -0.623165    0.504800     1.0
# 31        -1.356599    0.442267     1.0
#
# [2 rows x 24025 columns]

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\outputs\\master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\Integrated Analysis with Rep Meta\\outputs\\total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
