# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\NCI Cell Lines\\Gemcitabine_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  Gemcitabine
# 0   BT549   BR:BT-549        4.794
# 1  HS578T  BR:HS 578T        5.600
#
# [2 rows x 2185 columns]

# %%
#drop the target drug column
drug = data.pop('Gemcitabine')

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((49, 2181), (49,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    25
# 1    24
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                      0.147681                       -0.472795  0.146997
# 1                     -1.046385                       -0.310348 -0.895159
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0  0.152383                            1.385570
# 1 -0.789869                           -0.331035
#
#    Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                          2.337640         1.785216     -1.442720
# 1                         -0.763937        -0.007370     -0.827146
#
#    1-pyrrolinium  Acrylamide  ...  \
# 0      -0.606304   -0.585202  ...
# 1      -0.260490   -0.815770  ...
#
#    PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 0                                           0.381929
# 1                                          -0.725901
#
#    TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                          -0.122761
# 1                                          -0.414051
#
#    2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                           0.450116
# 1                                          -0.687365
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                           0.189559
# 1                                          -1.047578
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.113457
# 1                                          -1.723256
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.790328
# 1                          -1.034993
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                           0.402249
# 1                                          -0.425881
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                          -0.432085
# 1                                          -1.682030
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.092134
# 1                                          -1.444638
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))
# 0                                            0.13854
# 1                                           -0.28083
#
# [2 rows x 2181 columns]

# %%
X.shape, y.shape
# Out:
# ((50, 2181), (50,))

# %%
y.value_counts()
# Out:
# 1    25
# 0    25
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.shape
# Out:
# (50, 2181)

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.33, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = i)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the machine learning model and train it
    model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = i)
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 411
# Number of features selected during iteration 1: 411
# Number of features selected during iteration 2: 404
# Number of features selected during iteration 3: 404
# Number of features selected during iteration 4: 397
# Number of features selected during iteration 5: 406
# Number of features selected during iteration 6: 398
# Number of features selected during iteration 7: 409
# Number of features selected during iteration 8: 391
# Number of features selected during iteration 9: 402
# Number of features selected during iteration 10: 394
# Number of features selected during iteration 11: 429
# Number of features selected during iteration 12: 392
# Number of features selected during iteration 13: 409
# Number of features selected during iteration 14: 406
# Number of features selected during iteration 15: 405
# Number of features selected during iteration 16: 405
# Number of features selected during iteration 17: 398
# Number of features selected during iteration 18: 395
# Number of features selected during iteration 19: 394
# Number of features selected during iteration 20: 417
# Number of features selected during iteration 21: 384
# Number of features selected during iteration 22: 394
# Number of features selected during iteration 23: 403
# Number of features selected during iteration 24: 397
# Number of features selected during iteration 25: 395
# Number of features selected during iteration 26: 409
# Number of features selected during iteration 27: 402
# Number of features selected during iteration 28: 428
# Number of features selected during iteration 29: 399
# Number of features selected during iteration 30: 405
# Number of features selected during iteration 31: 392
# Number of features selected during iteration 32: 392
# Number of features selected during iteration 33: 403
# Number of features selected during iteration 34: 398
# Number of features selected during iteration 35: 412
# Number of features selected during iteration 36: 382
# Number of features selected during iteration 37: 415
# Number of features selected during iteration 38: 407
# Number of features selected during iteration 39: 418
# Number of features selected during iteration 40: 402
# Number of features selected during iteration 41: 411
# Number of features selected during iteration 42: 396
# Number of features selected during iteration 43: 390
# Number of features selected during iteration 44: 395
# Number of features selected during iteration 45: 400
# Number of features selected during iteration 46: 415
# Number of features selected during iteration 47: 410
# Number of features selected during iteration 48: 415
# Number of features selected during iteration 49: 395
# Accuracy score: 0.5776470588235295, Standard deviation: 0.041909442660133835
# Recall score: 0.405, Standard deviation: 0.05894913061275798
# Precision score: 0.5746666666666667, Standard deviation: 0.059441390558806956

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.147681                       -0.472795  0.146997
# 1                      -1.046385                       -0.310348 -0.895159
# 2                       1.121655                       -0.438879  2.453527
# 3                      -1.263569                       -0.586936 -1.563500
# 4                      -0.820902                       -1.146635 -0.044138
# 5                      -0.989880                        0.449420 -1.151302
# 6                      -1.581938                       -0.830805 -0.349159
# 7                      -0.019049                        0.598528 -1.493826
# 8                      -0.083793                       -1.069850  0.257447
# 9                       0.805129                       -0.359426  1.349650
# 10                      0.080299                       -1.022497 -0.460243
# 11                     -1.028122                        0.496246 -1.414677
# 12                      1.446642                       -0.287820 -0.047539
# 13                      1.396407                        0.265786 -0.696165
# 14                      0.054482                       -0.503766  0.557838
# 15                     -1.348723                       -0.371376 -0.105682
# 16                      0.470103                       -0.053085 -0.039373
# 17                      0.652303                       -0.594859 -0.243403
# 18                     -0.019049                       -0.599938  1.275700
# 19                     -0.297124                       -1.516128  0.889631
# 20                      0.255817                        0.232394  2.484557
# 21                     -0.019049                        0.740075 -0.044138
# 22                     -1.251707                        1.179336  0.823920
# 23                     -0.061582                        0.844572 -0.128962
# 24                     -1.212728                       -0.994299  0.057904
# 25                     -0.493177                       -0.979433 -0.675132
# 26                      0.853238                        1.802787 -0.218862
# 27                     -1.394158                       -1.157452 -0.411956
# 28                      0.874206                        0.190930 -0.089182
# 29                     -0.019049                        1.667113 -0.044138
# 30                     -1.649524                       -0.132916 -0.205606
# 31                     -1.401932                        3.744747 -1.748789
# 32                      1.906988                       -0.302895 -0.184147
# 33                     -2.028350                        0.729644 -0.044138
# 34                      1.336346                        1.564716 -0.635569
# 35                     -0.045335                        0.422683 -0.325378
# 36                      1.088285                       -1.125549  0.989243
# 37                     -0.019049                       -0.395921 -1.843302
# 38                      0.580081                        0.109823  0.044057
# 39                     -0.019049                       -0.294067 -0.044138
# 40                     -0.255143                        1.762879 -1.070642
# 41                      0.293508                       -0.146954  0.894511
# 42                      1.323460                       -0.658709  0.692319
# 43                      0.282487                        0.309437 -1.723179
# 44                     -0.313786                       -0.252847  1.441572
# 45                     -0.770829                       -1.247384  0.004456
# 46                      2.478535                       -0.121344  1.368280
# 47                      1.150765                        1.924038 -0.107492
# 48                     -0.078843                       -0.632523  0.154541
# 49                      0.933409                       -0.427719  2.162769
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.152383                            1.385570
# 1  -0.789869                           -0.331035
# 2   2.424205                            0.875640
# 3  -1.432993                           -1.471278
# 4  -0.043778                           -1.495411
# 5  -1.102112                           -0.175446
# 6  -0.325078                           -0.015732
# 7  -1.489185                           -2.066555
# 8   0.277627                           -0.891574
# 9   1.360123                            2.381146
# 10 -0.439314                           -0.427411
# 11 -1.307617                           -0.263111
# 12 -0.034161                           -0.162727
# 13 -0.614555                           -0.466607
# 14  0.572075                            0.387016
# 15 -0.083457                           -0.192811
# 16 -0.024090                           -0.231859
# 17 -0.235841                            1.657612
# 18  1.292817                           -0.806219
# 19  0.898380                            1.467604
# 20  2.454621                            1.943373
# 21 -1.812025                           -0.933772
# 22  0.825892                            0.289806
# 23 -0.114362                            0.549747
# 24  0.074285                           -0.794737
# 25 -0.602101                           -0.167648
# 26 -0.069436                            1.762618
# 27 -0.380903                           -0.949714
# 28 -0.007135                            1.306082
# 29 -0.043778                           -0.015732
# 30 -0.159997                           -1.022536
# 31 -1.683937                            1.385571
# 32 -0.164354                           -0.558701
# 33 -0.043778                           -0.984572
# 34 -0.540269                           -0.801646
# 35 -0.270019                           -0.081325
# 36  1.003049                            1.630447
# 37 -1.689060                           -0.015732
# 38  0.137340                           -0.576657
# 39 -0.043778                           -1.715286
# 40 -1.033207                           -0.621273
# 41  0.894020                            0.167130
# 42  0.730273                            0.899693
# 43 -1.578818                           -0.201621
# 44  1.300567                           -0.048002
# 45  0.044455                           -0.767735
# 46  1.386492                            0.820600
# 47 -0.005622                            0.171103
# 48  0.190890                           -0.597160
# 49  2.145135                            0.770867
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.337640         1.785216     -1.442720
# 1                          -0.763937        -0.007370     -0.827146
# 2                           0.057675         0.396150     -0.339200
# 3                          -1.087169        -0.849050      1.066233
# 4                          -0.751618        -0.110263      0.200435
# 5                          -0.363052         0.072239      0.001939
# 6                           0.000279        -0.007370     -0.305254
# 7                           0.000279        -0.007370      0.264948
# 8                          -0.282164         0.034251     -1.181269
# 9                           2.046723         1.509978     -0.999484
# 10                         -0.616648        -0.160234      1.393191
# 11                         -0.697699        -1.470528      1.544583
# 12                          0.570154         0.744695     -0.524149
# 13                         -0.899976        -1.124157     -0.830758
# 14                         -0.245765        -1.066907      0.352224
# 15                          0.217677        -0.119506     -0.350173
# 16                         -0.025189        -0.391949      2.055236
# 17                          2.144220         1.325364     -0.440417
# 18                         -0.426003        -0.723446     -0.907467
# 19                          1.643959         2.103060     -1.169022
# 20                          1.006233         0.633863     -0.748363
# 21                         -1.235482         0.039989      0.394083
# 22                          0.797704         0.483508     -0.429888
# 23                          0.795816         0.261373      0.257853
# 24                         -0.533207        -0.509832     -1.100618
# 25                         -0.369338         0.244217     -0.248752
# 26                          0.053070        -0.474402      0.578517
# 27                         -0.922769        -0.996685     -0.822296
# 28                         -0.050907         0.049679      1.282392
# 29                         -1.333872        -0.007370      2.721207
# 30                         -1.073073        -0.617788     -1.401967
# 31                         -1.299817        -0.224414      1.406872
# 32                          0.049146        -0.973074      0.658186
# 33                         -0.865030        -1.297754      2.245794
# 34                         -0.648716         0.414953     -1.477633
# 35                          1.485811         1.507165      0.747225
# 36                          2.598029         2.923275     -0.823859
# 37                          0.000279        -1.749259      1.120690
# 38                          0.573093         0.543947     -0.544813
# 39                          0.000279        -1.842442      0.660358
# 40                         -0.994393        -0.567992      0.280974
# 41                          0.166073         0.010015     -0.352406
# 42                          1.561689         1.904617     -0.529181
# 43                         -0.338835        -0.216179     -0.065994
# 44                         -0.664368        -0.604150      1.353553
# 45                         -0.541359        -0.695680     -0.982697
# 46                          0.143378         1.058027     -0.647398
# 47                          0.620871        -0.017946     -0.398010
# 48                         -1.826024        -1.573577     -0.313991
# 49                         -0.013664         0.361113     -0.381568
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.606304   -0.585202  ...
# 1       -0.260490   -0.815770  ...
# 2       -0.610087   -0.851581  ...
# 3        0.011467   -0.251250  ...
# 4       -0.177743   -0.566735  ...
# 5       -0.184282    1.450063  ...
# 6        0.350545   -0.396767  ...
# 7       -0.000451   -0.756779  ...
# 8       -0.661174   -1.155184  ...
# 9        0.398901   -0.052522  ...
# 10       0.175428    0.686998  ...
# 11       4.759550    1.901680  ...
# 12       0.287322    1.526188  ...
# 13       1.823535    1.606712  ...
# 14       0.341637    0.804410  ...
# 15       0.771359    0.992802  ...
# 16       1.546608    3.068772  ...
# 17      -0.744147   -0.855621  ...
# 18      -0.239017   -0.765150  ...
# 19      -1.024911   -1.135899  ...
# 20      -1.016283   -0.299578  ...
# 21      -0.929544   -0.074691  ...
# 22       0.900618    0.025959  ...
# 23       0.869952    1.470307  ...
# 24      -0.838616   -1.335875  ...
# 25      -0.308777    0.064690  ...
# 26      -0.633969    1.361506  ...
# 27      -0.954674   -0.610729  ...
# 28       0.403815   -0.446679  ...
# 29       0.287171    0.296495  ...
# 30      -0.754670   -1.108424  ...
# 31       1.588790    1.464156  ...
# 32       0.195805    0.107738  ...
# 33      -0.163671   -0.559776  ...
# 34      -1.194859   -0.182272  ...
# 35      -0.254254    0.579274  ...
# 36      -0.785576   -0.021050  ...
# 37      -0.271963   -1.375957  ...
# 38      -0.201178    0.415768  ...
# 39       0.215624   -0.756585  ...
# 40       1.092661   -0.665926  ...
# 41      -0.473823    0.871158  ...
# 42      -0.475738   -1.088930  ...
# 43       1.487553    1.481909  ...
# 44      -0.656761   -0.456209  ...
# 45      -0.771881   -1.397265  ...
# 46      -0.802694    0.024185  ...
# 47      -0.479772   -0.298815  ...
# 48      -0.451299   -0.485077  ...
# 49      -0.579733   -0.848471  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.450116
# 1                                           -0.687365
# 2                                           -0.004119
# 3                                            0.897226
# 4                                            0.198035
# 5                                           -0.205814
# 6                                           -0.360138
# 7                                            1.460399
# 8                                           -0.342493
# 9                                            0.893656
# 10                                          -0.162200
# 11                                          -0.073231
# 12                                           2.450288
# 13                                          -0.816144
# 14                                           0.993435
# 15                                          -0.157323
# 16                                           2.734155
# 17                                          -0.036535
# 18                                          -1.105596
# 19                                           0.166531
# 20                                          -0.678802
# 21                                          -0.582803
# 22                                           0.335868
# 23                                           1.364292
# 24                                          -0.640156
# 25                                          -0.130083
# 26                                          -0.330050
# 27                                          -0.864601
# 28                                          -0.741685
# 29                                          -2.190999
# 30                                          -1.259988
# 31                                          -1.328285
# 32                                          -0.637044
# 33                                          -2.322672
# 34                                           1.134239
# 35                                           0.451086
# 36                                           1.223901
# 37                                          -0.422175
# 38                                           0.514490
# 39                                          -0.925650
# 40                                          -1.225977
# 41                                           1.550942
# 42                                          -0.017212
# 43                                           0.730292
# 44                                          -0.096643
# 45                                          -0.661320
# 46                                           0.254142
# 47                                           0.309306
# 48                                           0.958147
# 49                                          -0.063444
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.189559
# 1                                           -1.047578
# 2                                           -0.503795
# 3                                           -0.048363
# 4                                           -1.710916
# 5                                           -1.013665
# 6                                           -0.494538
# 7                                           -1.490578
# 8                                            0.141091
# 9                                            0.243800
# 10                                          -0.143370
# 11                                          -0.088929
# 12                                           2.763189
# 13                                          -0.337967
# 14                                           0.834884
# 15                                           0.584525
# 16                                           1.098938
# 17                                          -0.113113
# 18                                          -0.342043
# 19                                          -0.120201
# 20                                           0.315538
# 21                                          -0.794320
# 22                                           0.250863
# 23                                           1.853119
# 24                                          -0.515310
# 25                                          -0.109396
# 26                                           0.081984
# 27                                          -0.035309
# 28                                           0.118924
# 29                                          -1.096797
# 30                                          -0.195684
# 31                                           1.108155
# 32                                           0.478994
# 33                                          -0.283490
# 34                                           0.848149
# 35                                           1.814704
# 36                                           2.172173
# 37                                          -1.781545
# 38                                           0.333527
# 39                                          -2.654178
# 40                                          -1.130820
# 41                                           1.172092
# 42                                           1.349250
# 43                                          -0.214925
# 44                                          -0.342267
# 45                                          -0.065978
# 46                                           0.355609
# 47                                          -0.680305
# 48                                          -0.202678
# 49                                          -0.551011
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.113457
# 1                                           -1.723256
# 2                                            0.117699
# 3                                           -0.433627
# 4                                           -1.345044
# 5                                           -0.403669
# 6                                           -0.644963
# 7                                           -1.698442
# 8                                            0.468911
# 9                                            0.515714
# 10                                           0.274470
# 11                                           0.097147
# 12                                           3.116735
# 13                                          -0.012472
# 14                                           0.538391
# 15                                           0.548712
# 16                                           1.133936
# 17                                           0.126633
# 18                                          -1.224360
# 19                                           0.559324
# 20                                           0.658854
# 21                                          -1.372282
# 22                                           0.605419
# 23                                           2.038211
# 24                                          -0.037808
# 25                                           0.594210
# 26                                           0.227717
# 27                                          -0.049893
# 28                                          -0.010613
# 29                                           0.149012
# 30                                          -0.431545
# 31                                          -0.938156
# 32                                          -0.788970
# 33                                          -0.869398
# 34                                           0.333355
# 35                                           1.313825
# 36                                           1.613235
# 37                                          -1.753985
# 38                                           0.569334
# 39                                          -2.458030
# 40                                          -0.992510
# 41                                           0.847418
# 42                                           1.252509
# 43                                           0.246886
# 44                                          -0.504014
# 45                                           0.023919
# 46                                           0.325451
# 47                                          -0.467761
# 48                                          -0.207539
# 49                                          -0.042147
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.790328
# 1                           -1.034993
# 2                           -1.106224
# 3                            1.204390
# 4                           -0.785383
# 5                           -0.633538
# 6                            0.894570
# 7                           -1.778267
# 8                           -0.346978
# 9                            0.187947
# 10                          -0.291341
# 11                           0.359523
# 12                           1.986672
# 13                          -0.359695
# 14                           1.520106
# 15                           0.470935
# 16                           0.678771
# 17                          -0.197326
# 18                           0.618861
# 19                          -0.311853
# 20                          -0.121595
# 21                          -0.231194
# 22                           1.347505
# 23                           1.121386
# 24                          -0.750517
# 25                          -1.023947
# 26                          -0.360784
# 27                          -1.254016
# 28                           0.161499
# 29                          -1.078941
# 30                          -1.063959
# 31                           0.250969
# 32                           2.007058
# 33                          -0.132069
# 34                           0.880696
# 35                           1.359422
# 36                           1.388891
# 37                          -1.044043
# 38                          -1.210208
# 39                          -1.751585
# 40                          -1.201468
# 41                          -0.524696
# 42                           1.619004
# 43                          -0.115638
# 44                           1.175923
# 45                          -0.902290
# 46                          -0.503319
# 47                          -0.076936
# 48                           1.268389
# 49                          -1.100039
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.402249
# 1                                           -0.425881
# 2                                            0.593649
# 3                                           -0.414569
# 4                                           -1.208411
# 5                                           -0.220940
# 6                                            0.463706
# 7                                           -1.953135
# 8                                            0.499978
# 9                                            0.707123
# 10                                           0.017075
# 11                                          -0.118687
# 12                                           2.550171
# 13                                          -0.331349
# 14                                           0.136022
# 15                                           0.640343
# 16                                           1.465486
# 17                                           0.161203
# 18                                          -0.937429
# 19                                          -0.155362
# 20                                           0.326693
# 21                                          -0.789996
# 22                                          -0.440526
# 23                                           1.101020
# 24                                          -0.903203
# 25                                           1.364797
# 26                                          -0.022500
# 27                                          -0.406976
# 28                                          -0.840167
# 29                                          -2.051774
# 30                                          -0.407160
# 31                                          -0.215038
# 32                                          -0.899160
# 33                                          -1.184059
# 34                                           0.688626
# 35                                           1.474644
# 36                                           0.636834
# ...
# 21                                          -1.359059
# 22                                          -0.092510
# 23                                           2.035263
# 24                                          -0.053001
# 25                                           1.649516
# 26                                           0.028106
# 27                                           0.176687
# 28                                           0.212494
# 29                                          -0.727403
# 30                                          -0.351132
# 31                                           0.416479
# 32                                          -0.448949
# 33                                          -1.355201
# 34                                           0.268776
# 35                                           0.363709
# 36                                           0.537145
# 37                                          -1.233682
# 38                                           0.475173
# 39                                          -1.242201
# 40                                          -1.188712
# 41                                           0.614996
# 42                                           0.272437
# 43                                           0.485977
# 44                                          -0.536230
# 45                                          -0.185565
# 46                                           0.542293
# 47                                           0.249117
# 48                                          -0.464495
# 49                                          -0.126285
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                            0.092134
# 1                                           -1.444638
# 2                                           -0.105389
# 3                                            0.114242
# 4                                           -1.597141
# 5                                           -1.109680
# 6                                           -0.470613
# 7                                           -1.630139
# 8                                            0.344774
# 9                                            0.085089
# 10                                           0.039583
# 11                                          -0.224654
# 12                                           3.307203
# 13                                          -0.177049
# 14                                           1.296662
# 15                                           0.403859
# 16                                           1.037701
# 17                                          -0.006864
# 18                                          -0.314043
# 19                                           0.106674
# 20                                           0.300848
# 21                                          -1.056692
# 22                                          -0.053294
# 23                                           1.793460
# 24                                          -0.306979
# 25                                           0.531185
# 26                                           0.644406
# 27                                           0.210041
# 28                                           0.421608
# 29                                          -1.359893
# 30                                          -0.299272
# 31                                          -0.511080
# 32                                          -0.213085
# 33                                          -1.146894
# 34                                           0.352785
# 35                                           1.373494
# 36                                           1.674145
# 37                                          -1.704616
# 38                                           0.813647
# 39                                          -2.206925
# 40                                          -1.006588
# 41                                           1.068900
# 42                                           1.530028
# 43                                          -0.120781
# 44                                          -0.376573
# 45                                           0.090200
# 46                                           0.168582
# 47                                          -0.209682
# 48                                           0.072987
# 49                                          -0.221673
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.138540
# 1                                           -0.280830
# 2                                            0.223628
# 3                                            0.276029
# 4                                           -0.337236
# 5                                           -0.611069
# 6                                            1.059462
# 7                                           -1.949821
# 8                                            0.817413
# 9                                            0.898810
# 10                                          -0.515317
# 11                                          -0.757250
# 12                                           1.883750
# 13                                          -0.192344
# 14                                           0.238108
# 15                                           0.380923
# 16                                           1.358816
# 17                                           0.083293
# 18                                          -0.867051
# 19                                           0.155274
# 20                                           0.353444
# 21                                          -0.544537
# 22                                          -0.578409
# 23                                           0.578586
# 24                                          -0.476726
# 25                                           1.807698
# 26                                          -0.339666
# 27                                          -0.901175
# 28                                          -0.890669
# 29                                          -1.080782
# 30                                          -0.790764
# 31                                          -0.873649
# 32                                          -0.933205
# 33                                          -1.546610
# 34                                          -1.129036
# 35                                           2.975608
# 36                                           0.266528
# 37                                          -0.991720
# 38                                           2.310487
# 39                                          -1.058216
# 40                                          -1.161160
# 41                                           1.083635
# 42                                           0.424908
# 43                                           0.424219
# 44                                          -0.993477
# 45                                           0.218417
# 46                                           0.444371
# 47                                           1.307519
# 48                                          -0.088575
# 49                                           0.179827
#
#     test_proba  target
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3     0.484533     0.0
# 4          NaN     NaN
# 5     0.166400     0.0
# 6     0.398000     0.0
# 7          NaN     NaN
# 8     0.839467     0.0
# 9          NaN     NaN
# 10         NaN     NaN
# 11         NaN     NaN
# 12         NaN     NaN
# 13    0.458400     1.0
# 14    0.445867     1.0
# 15         NaN     NaN
# 16         NaN     NaN
# 17         NaN     NaN
# 18    0.289200     0.0
# 19    0.852133     1.0
# 20    0.680533     0.0
# 21         NaN     NaN
# 22         NaN     NaN
# 23         NaN     NaN
# 24         NaN     NaN
# 25         NaN     NaN
# 26    0.300400     0.0
# 27         NaN     NaN
# 28    0.336800     0.0
# 29    0.281733     1.0
# 30         NaN     NaN
# 31         NaN     NaN
# 32         NaN     NaN
# 33         NaN     NaN
# 34         NaN     NaN
# 35         NaN     NaN
# 36    0.771333     1.0
# 37    0.386533     1.0
# 38         NaN     NaN
# 39    0.187067     0.0
# 40         NaN     NaN
# 41         NaN     NaN
# 42         NaN     NaN
# 43         NaN     NaN
# 44    0.361067     1.0
# 45    0.794800     1.0
# 46         NaN     NaN
# 47         NaN     NaN
# 48         NaN     NaN
# 49         NaN     NaN
#
# [50 rows x 2183 columns]

# %%
df1_main = df1.iloc[:49, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (1, 2183)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([19], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store accuracy, precision and recall 
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = SVC(kernel = 'linear', C=1, gamma=1, probability = True, random_state = i)
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.coef_.ravel()
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the SVM model and train it
    model2 = SVC(C=1, gamma=1, probability=True, random_state = i)
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 2181
# Features selected during iteration 1: 2181
# Features selected during iteration 2: 2181
# Features selected during iteration 3: 2181
# Features selected during iteration 4: 2181
# Features selected during iteration 5: 2181
# Features selected during iteration 6: 2181
# Features selected during iteration 7: 2181
# Features selected during iteration 8: 2181
# Features selected during iteration 9: 2181
# Features selected during iteration 10: 2181
# Features selected during iteration 11: 2181
# Features selected during iteration 12: 2181
# Features selected during iteration 13: 2181
# Features selected during iteration 14: 2181
# Features selected during iteration 15: 2181
# Features selected during iteration 16: 2181
# Features selected during iteration 17: 2181
# Features selected during iteration 18: 2181
# Features selected during iteration 19: 2181
# Features selected during iteration 20: 2181
# Features selected during iteration 21: 2181
# Features selected during iteration 22: 2181
# Features selected during iteration 23: 2181
# Features selected during iteration 24: 2181
# Features selected during iteration 25: 2181
# Features selected during iteration 26: 2181
# Features selected during iteration 27: 2181
# Features selected during iteration 28: 2181
# Features selected during iteration 29: 2181
# Features selected during iteration 30: 2181
# Features selected during iteration 31: 2181
# Features selected during iteration 32: 2181
# Features selected during iteration 33: 2181
# Features selected during iteration 34: 2181
# Features selected during iteration 35: 2181
# Features selected during iteration 36: 2181
# Features selected during iteration 37: 2181
# Features selected during iteration 38: 2181
# Features selected during iteration 39: 2181
# Features selected during iteration 40: 2181
# Features selected during iteration 41: 2181
# Features selected during iteration 42: 2181
# Features selected during iteration 43: 2181
# Features selected during iteration 44: 2181
# Features selected during iteration 45: 2181
# Features selected during iteration 46: 2181
# Features selected during iteration 47: 2181
# Features selected during iteration 48: 2181
# Features selected during iteration 49: 2181
# Accuracy score: 0.4705882352941176, Standard deviation: 5.551115123125783e-17
# Recall score: 1.0, Standard deviation: 0.0
# Precision score: 0.4705882352941176, Standard deviation: 5.551115123125783e-17

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:49, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [Acetone ; Propanal ; acetone, Acetaldehyde oxime ; HMDB01122, acetate, Urea, Isopropyl alcohol ; Propyl alcohol, Bicarbonate ; Hydrogen carbonate, Dimethylsulfide, 3-Butyn-1-al, 1-pyrrolinium, Acrylamide, Malondialdehyde ; Pyruvaldehyde ; acrylate ; malonic dialdehyde ; methylglyoxal, 3-Aminopropionaldehyde ; Aminoacetone ; HMDB01888 ; ammonioacetone ; beta-Aminopropion aldehyde, glyoxylate, propionate, Glycine, Glycolic acid ; glycolate, Imidazolone, 2-Pyrrolidinone, But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one, 2-Aminoacrylic acid ; 2-aminoacrylic acid, 3-oxopropanoate ; Malonic semialdehyde ; Pyruvic acid ; pyruvate, Beta-Alanine ; D-Alanine ; D-alanine ; L-Alanine ; L-alanine ; Sarcosine ; beta-alanine, (R)-lactate ; (S)-lactate ; 3-hydroxypropionate ; D-Glyceraldehyde ; D-Lactic acid ; Dihydroxyacetone ; Glyceraldehyde ; Hydroxypropionic acid ; L-Lactic acid ; glycerone, 2,3-Butanediol, cyanosulfurous acid anion, Glycerol, Aniline, Dimethyl sulfone, (R)-b-aminoisobutyric acid ; (S)-2-Aminobutanoate ; (S)-3-aminoisobutyric acid ; (S)-b-aminoisobutyric acid ; 2-Aminoisobutyric acid ; 3-Aminoisobutanoic acid ; 4-Aminobutanoate ; D-3-Amino-isobutanoate ; D-Alpha-aminobutyric acid ; Dimethylglycine ; Gamma-Aminobutyric acid ; L-Alpha-aminobutyric acid ; N,N-dimethylglycine, Choline, D-Serine ; D-serine ; L-Serine ; L-serine, Benzyl alcohol ; m-Cresol ; o-Cresol ; p-Cresol, Histamine ; histamium, 2-Furoic acid ; 3-Furoic acid, Uracil ; uracil, 1-Pyrroline-2-carboxylic acid ; 1-Pyrroline-5-carboxylate ; 1-Pyrroline-5-carboxylic acid ; 1-pyrroline-2-carboxylate, 5,6-dihydrouracil ; Dihydrouracil ; HMDB03646 ; L-3-Cyanoalanine, 3-Amino-2-piperidone, D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal, Fumarate ; Fumaric acid ; Maleic acid, Homocysteine thiolactone ; homocysteine thiolactone, Acetylglycine ; L-2-Amino-3-oxobutanoic acid ; L-2-amino-3-oxobutanoic acid ; L-Aspartate-semialdehyde, 5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine, Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone, Aminomalonic acid, L-Allothreonine ; L-Homoserine ; L-Threonine ; L-homoserine ; L-threonine, D-Cysteine ; L-Cysteine ; L-cysteine, 1-Phenylethylamine ; HMDB01020 ; Phenylethylamine, 3-Mercaptolactate ; 3-Mercaptolactic acid, 5,6-dihydrothymine ; Dihydrothymine, naphthalene, Octanal, 1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid, 3-Methylene-indolenine, 4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid, 4-trimethylammoniobutanal, Citraconic acid ; Glutaconic acid ; Itaconic acid ; Mesaconate ; Mesaconic acid ; itaconate(2-), 2-Ketohexanoic acid ; 2-Methyl-3-ketovaleric acid ; 3-Methyl-2-oxovaleric acid ; 3-Oxohexanoic acid ; Ketoleucine ; Mevalonolactone, Octanol, Iminoaspartic acid, 3-Hydroxy-L-proline ; 4-Hydroxy&#8203 ; 5-Amino-2-oxopentanoic acid ; 5-Amino-4-oxopentanoate ; 5-Aminolevulinic acid ; 5-amino-2-oxopentanoic acid ; HMDB00766 ; Hydroxyproline ; L-Glutamate 5-semialdehyde ; L-Glutamic-gamma-semialdehyde ; N-acetyl-L-alanine ; Propionylglycine ; trans-4-hydroxy-L-proline, Creatine ; creatine, 3-Methylindole, Aminocaproic acid ; Beta-Leucine ; L-Alloisoleucine ; L-Isoleucine ; L-Leucine ; L-Norleucine ; L-isoleucine ; L-leucine, HMDB11634, Oxalacetic acid ; Oxaloacetate, (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid, Glycyl-glycine ; HMDB12265 ; L-Asparagine ; L-asparagine ; N-carbamoyl-beta-alaninate ; Ureidopropionic acid, Cinnamaldehyde, (5R)-5-Hydroxyhexanoic acid ; (R)-2-hydroxy-4-methylpentanoate ; (R)-3-Hydroxyhexanoic acid ; 2-Ethyl-2-Hydroxybutyric acid ; 2-Hydroxy-3-methylpentanoic acid ; 2 ...
# Index: []
#
# [0 rows x 2183 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier(seed = i)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define XGBoost model and train it
    model3 = XGBClassifier(seed = i)
    model3.fit(X_train, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 17
# Features selected during iteration 1: 17
# Features selected during iteration 2: 17
# Features selected during iteration 3: 17
# Features selected during iteration 4: 17
# Features selected during iteration 5: 17
# Features selected during iteration 6: 17
# Features selected during iteration 7: 17
# Features selected during iteration 8: 17
# Features selected during iteration 9: 17
# Features selected during iteration 10: 17
# Features selected during iteration 11: 17
# Features selected during iteration 12: 17
# Features selected during iteration 13: 17
# Features selected during iteration 14: 17
# Features selected during iteration 15: 17
# Features selected during iteration 16: 17
# Features selected during iteration 17: 17
# Features selected during iteration 18: 17
# Features selected during iteration 19: 17
# Features selected during iteration 20: 17
# Features selected during iteration 21: 17
# Features selected during iteration 22: 17
# Features selected during iteration 23: 17
# Features selected during iteration 24: 17
# Features selected during iteration 25: 17
# Features selected during iteration 26: 17
# Features selected during iteration 27: 17
# Features selected during iteration 28: 17
# Features selected during iteration 29: 17
# Features selected during iteration 30: 17
# Features selected during iteration 31: 17
# Features selected during iteration 32: 17
# Features selected during iteration 33: 17
# Features selected during iteration 34: 17
# Features selected during iteration 35: 17
# Features selected during iteration 36: 17
# Features selected during iteration 37: 17
# Features selected during iteration 38: 17
# Features selected during iteration 39: 17
# Features selected during iteration 40: 17
# Features selected during iteration 41: 17
# Features selected during iteration 42: 17
# Features selected during iteration 43: 17
# Features selected during iteration 44: 17
# Features selected during iteration 45: 17
# Features selected during iteration 46: 17
# Features selected during iteration 47: 17
# Features selected during iteration 48: 17
# Features selected during iteration 49: 17
# Accuracy score: 0.5882352941176472, Standard deviation: 1.1102230246251565e-16
# Recall score: 0.5, Standard deviation: 0.0
# Precision score: 0.5714285714285714, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.147681                       -0.472795  0.146997
# 1                      -1.046385                       -0.310348 -0.895159
# 2                       1.121655                       -0.438879  2.453527
# 3                      -1.263569                       -0.586936 -1.563500
# 4                      -0.820902                       -1.146635 -0.044138
# 5                      -0.989880                        0.449420 -1.151302
# 6                      -1.581938                       -0.830805 -0.349159
# 7                      -0.019049                        0.598528 -1.493826
# 8                      -0.083793                       -1.069850  0.257447
# 9                       0.805129                       -0.359426  1.349650
# 10                      0.080299                       -1.022497 -0.460243
# 11                     -1.028122                        0.496246 -1.414677
# 12                      1.446642                       -0.287820 -0.047539
# 13                      1.396407                        0.265786 -0.696165
# 14                      0.054482                       -0.503766  0.557838
# 15                     -1.348723                       -0.371376 -0.105682
# 16                      0.470103                       -0.053085 -0.039373
# 17                      0.652303                       -0.594859 -0.243403
# 18                     -0.019049                       -0.599938  1.275700
# 19                     -0.297124                       -1.516128  0.889631
# 20                      0.255817                        0.232394  2.484557
# 21                     -0.019049                        0.740075 -0.044138
# 22                     -1.251707                        1.179336  0.823920
# 23                     -0.061582                        0.844572 -0.128962
# 24                     -1.212728                       -0.994299  0.057904
# 25                     -0.493177                       -0.979433 -0.675132
# 26                      0.853238                        1.802787 -0.218862
# 27                     -1.394158                       -1.157452 -0.411956
# 28                      0.874206                        0.190930 -0.089182
# 29                     -0.019049                        1.667113 -0.044138
# 30                     -1.649524                       -0.132916 -0.205606
# 31                     -1.401932                        3.744747 -1.748789
# 32                      1.906988                       -0.302895 -0.184147
# 33                     -2.028350                        0.729644 -0.044138
# 34                      1.336346                        1.564716 -0.635569
# 35                     -0.045335                        0.422683 -0.325378
# 36                      1.088285                       -1.125549  0.989243
# 37                     -0.019049                       -0.395921 -1.843302
# 38                      0.580081                        0.109823  0.044057
# 39                     -0.019049                       -0.294067 -0.044138
# 40                     -0.255143                        1.762879 -1.070642
# 41                      0.293508                       -0.146954  0.894511
# 42                      1.323460                       -0.658709  0.692319
# 43                      0.282487                        0.309437 -1.723179
# 44                     -0.313786                       -0.252847  1.441572
# 45                     -0.770829                       -1.247384  0.004456
# 46                      2.478535                       -0.121344  1.368280
# 47                      1.150765                        1.924038 -0.107492
# 48                     -0.078843                       -0.632523  0.154541
# 49                      0.933409                       -0.427719  2.162769
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.152383                            1.385570
# 1  -0.789869                           -0.331035
# 2   2.424205                            0.875640
# 3  -1.432993                           -1.471278
# 4  -0.043778                           -1.495411
# 5  -1.102112                           -0.175446
# 6  -0.325078                           -0.015732
# 7  -1.489185                           -2.066555
# 8   0.277627                           -0.891574
# 9   1.360123                            2.381146
# 10 -0.439314                           -0.427411
# 11 -1.307617                           -0.263111
# 12 -0.034161                           -0.162727
# 13 -0.614555                           -0.466607
# 14  0.572075                            0.387016
# 15 -0.083457                           -0.192811
# 16 -0.024090                           -0.231859
# 17 -0.235841                            1.657612
# 18  1.292817                           -0.806219
# 19  0.898380                            1.467604
# 20  2.454621                            1.943373
# 21 -1.812025                           -0.933772
# 22  0.825892                            0.289806
# 23 -0.114362                            0.549747
# 24  0.074285                           -0.794737
# 25 -0.602101                           -0.167648
# 26 -0.069436                            1.762618
# 27 -0.380903                           -0.949714
# 28 -0.007135                            1.306082
# 29 -0.043778                           -0.015732
# 30 -0.159997                           -1.022536
# 31 -1.683937                            1.385571
# 32 -0.164354                           -0.558701
# 33 -0.043778                           -0.984572
# 34 -0.540269                           -0.801646
# 35 -0.270019                           -0.081325
# 36  1.003049                            1.630447
# 37 -1.689060                           -0.015732
# 38  0.137340                           -0.576657
# 39 -0.043778                           -1.715286
# 40 -1.033207                           -0.621273
# 41  0.894020                            0.167130
# 42  0.730273                            0.899693
# 43 -1.578818                           -0.201621
# 44  1.300567                           -0.048002
# 45  0.044455                           -0.767735
# 46  1.386492                            0.820600
# 47 -0.005622                            0.171103
# 48  0.190890                           -0.597160
# 49  2.145135                            0.770867
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.337640         1.785216     -1.442720
# 1                          -0.763937        -0.007370     -0.827146
# 2                           0.057675         0.396150     -0.339200
# 3                          -1.087169        -0.849050      1.066233
# 4                          -0.751618        -0.110263      0.200435
# 5                          -0.363052         0.072239      0.001939
# 6                           0.000279        -0.007370     -0.305254
# 7                           0.000279        -0.007370      0.264948
# 8                          -0.282164         0.034251     -1.181269
# 9                           2.046723         1.509978     -0.999484
# 10                         -0.616648        -0.160234      1.393191
# 11                         -0.697699        -1.470528      1.544583
# 12                          0.570154         0.744695     -0.524149
# 13                         -0.899976        -1.124157     -0.830758
# 14                         -0.245765        -1.066907      0.352224
# 15                          0.217677        -0.119506     -0.350173
# 16                         -0.025189        -0.391949      2.055236
# 17                          2.144220         1.325364     -0.440417
# 18                         -0.426003        -0.723446     -0.907467
# 19                          1.643959         2.103060     -1.169022
# 20                          1.006233         0.633863     -0.748363
# 21                         -1.235482         0.039989      0.394083
# 22                          0.797704         0.483508     -0.429888
# 23                          0.795816         0.261373      0.257853
# 24                         -0.533207        -0.509832     -1.100618
# 25                         -0.369338         0.244217     -0.248752
# 26                          0.053070        -0.474402      0.578517
# 27                         -0.922769        -0.996685     -0.822296
# 28                         -0.050907         0.049679      1.282392
# 29                         -1.333872        -0.007370      2.721207
# 30                         -1.073073        -0.617788     -1.401967
# 31                         -1.299817        -0.224414      1.406872
# 32                          0.049146        -0.973074      0.658186
# 33                         -0.865030        -1.297754      2.245794
# 34                         -0.648716         0.414953     -1.477633
# 35                          1.485811         1.507165      0.747225
# 36                          2.598029         2.923275     -0.823859
# 37                          0.000279        -1.749259      1.120690
# 38                          0.573093         0.543947     -0.544813
# 39                          0.000279        -1.842442      0.660358
# 40                         -0.994393        -0.567992      0.280974
# 41                          0.166073         0.010015     -0.352406
# 42                          1.561689         1.904617     -0.529181
# 43                         -0.338835        -0.216179     -0.065994
# 44                         -0.664368        -0.604150      1.353553
# 45                         -0.541359        -0.695680     -0.982697
# 46                          0.143378         1.058027     -0.647398
# 47                          0.620871        -0.017946     -0.398010
# 48                         -1.826024        -1.573577     -0.313991
# 49                         -0.013664         0.361113     -0.381568
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.606304   -0.585202  ...
# 1       -0.260490   -0.815770  ...
# 2       -0.610087   -0.851581  ...
# 3        0.011467   -0.251250  ...
# 4       -0.177743   -0.566735  ...
# 5       -0.184282    1.450063  ...
# 6        0.350545   -0.396767  ...
# 7       -0.000451   -0.756779  ...
# 8       -0.661174   -1.155184  ...
# 9        0.398901   -0.052522  ...
# 10       0.175428    0.686998  ...
# 11       4.759550    1.901680  ...
# 12       0.287322    1.526188  ...
# 13       1.823535    1.606712  ...
# 14       0.341637    0.804410  ...
# 15       0.771359    0.992802  ...
# 16       1.546608    3.068772  ...
# 17      -0.744147   -0.855621  ...
# 18      -0.239017   -0.765150  ...
# 19      -1.024911   -1.135899  ...
# 20      -1.016283   -0.299578  ...
# 21      -0.929544   -0.074691  ...
# 22       0.900618    0.025959  ...
# 23       0.869952    1.470307  ...
# 24      -0.838616   -1.335875  ...
# 25      -0.308777    0.064690  ...
# 26      -0.633969    1.361506  ...
# 27      -0.954674   -0.610729  ...
# 28       0.403815   -0.446679  ...
# 29       0.287171    0.296495  ...
# 30      -0.754670   -1.108424  ...
# 31       1.588790    1.464156  ...
# 32       0.195805    0.107738  ...
# 33      -0.163671   -0.559776  ...
# 34      -1.194859   -0.182272  ...
# 35      -0.254254    0.579274  ...
# 36      -0.785576   -0.021050  ...
# 37      -0.271963   -1.375957  ...
# 38      -0.201178    0.415768  ...
# 39       0.215624   -0.756585  ...
# 40       1.092661   -0.665926  ...
# 41      -0.473823    0.871158  ...
# 42      -0.475738   -1.088930  ...
# 43       1.487553    1.481909  ...
# 44      -0.656761   -0.456209  ...
# 45      -0.771881   -1.397265  ...
# 46      -0.802694    0.024185  ...
# 47      -0.479772   -0.298815  ...
# 48      -0.451299   -0.485077  ...
# 49      -0.579733   -0.848471  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.450116
# 1                                           -0.687365
# 2                                           -0.004119
# 3                                            0.897226
# 4                                            0.198035
# 5                                           -0.205814
# 6                                           -0.360138
# 7                                            1.460399
# 8                                           -0.342493
# 9                                            0.893656
# 10                                          -0.162200
# 11                                          -0.073231
# 12                                           2.450288
# 13                                          -0.816144
# 14                                           0.993435
# 15                                          -0.157323
# 16                                           2.734155
# 17                                          -0.036535
# 18                                          -1.105596
# 19                                           0.166531
# 20                                          -0.678802
# 21                                          -0.582803
# 22                                           0.335868
# 23                                           1.364292
# 24                                          -0.640156
# 25                                          -0.130083
# 26                                          -0.330050
# 27                                          -0.864601
# 28                                          -0.741685
# 29                                          -2.190999
# 30                                          -1.259988
# 31                                          -1.328285
# 32                                          -0.637044
# 33                                          -2.322672
# 34                                           1.134239
# 35                                           0.451086
# 36                                           1.223901
# 37                                          -0.422175
# 38                                           0.514490
# 39                                          -0.925650
# 40                                          -1.225977
# 41                                           1.550942
# 42                                          -0.017212
# 43                                           0.730292
# 44                                          -0.096643
# 45                                          -0.661320
# 46                                           0.254142
# 47                                           0.309306
# 48                                           0.958147
# 49                                          -0.063444
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.189559
# 1                                           -1.047578
# 2                                           -0.503795
# 3                                           -0.048363
# 4                                           -1.710916
# 5                                           -1.013665
# 6                                           -0.494538
# 7                                           -1.490578
# 8                                            0.141091
# 9                                            0.243800
# 10                                          -0.143370
# 11                                          -0.088929
# 12                                           2.763189
# 13                                          -0.337967
# 14                                           0.834884
# 15                                           0.584525
# 16                                           1.098938
# 17                                          -0.113113
# 18                                          -0.342043
# 19                                          -0.120201
# 20                                           0.315538
# 21                                          -0.794320
# 22                                           0.250863
# 23                                           1.853119
# 24                                          -0.515310
# 25                                          -0.109396
# 26                                           0.081984
# 27                                          -0.035309
# 28                                           0.118924
# 29                                          -1.096797
# 30                                          -0.195684
# 31                                           1.108155
# 32                                           0.478994
# 33                                          -0.283490
# 34                                           0.848149
# 35                                           1.814704
# 36                                           2.172173
# 37                                          -1.781545
# 38                                           0.333527
# 39                                          -2.654178
# 40                                          -1.130820
# 41                                           1.172092
# 42                                           1.349250
# 43                                          -0.214925
# 44                                          -0.342267
# 45                                          -0.065978
# 46                                           0.355609
# 47                                          -0.680305
# 48                                          -0.202678
# 49                                          -0.551011
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.113457
# 1                                           -1.723256
# 2                                            0.117699
# 3                                           -0.433627
# 4                                           -1.345044
# 5                                           -0.403669
# 6                                           -0.644963
# 7                                           -1.698442
# 8                                            0.468911
# 9                                            0.515714
# 10                                           0.274470
# 11                                           0.097147
# 12                                           3.116735
# 13                                          -0.012472
# 14                                           0.538391
# 15                                           0.548712
# 16                                           1.133936
# 17                                           0.126633
# 18                                          -1.224360
# 19                                           0.559324
# 20                                           0.658854
# 21                                          -1.372282
# 22                                           0.605419
# 23                                           2.038211
# 24                                          -0.037808
# 25                                           0.594210
# 26                                           0.227717
# 27                                          -0.049893
# 28                                          -0.010613
# 29                                           0.149012
# 30                                          -0.431545
# 31                                          -0.938156
# 32                                          -0.788970
# 33                                          -0.869398
# 34                                           0.333355
# 35                                           1.313825
# 36                                           1.613235
# 37                                          -1.753985
# 38                                           0.569334
# 39                                          -2.458030
# 40                                          -0.992510
# 41                                           0.847418
# 42                                           1.252509
# 43                                           0.246886
# 44                                          -0.504014
# 45                                           0.023919
# 46                                           0.325451
# 47                                          -0.467761
# 48                                          -0.207539
# 49                                          -0.042147
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.790328
# 1                           -1.034993
# 2                           -1.106224
# 3                            1.204390
# 4                           -0.785383
# 5                           -0.633538
# 6                            0.894570
# 7                           -1.778267
# 8                           -0.346978
# 9                            0.187947
# 10                          -0.291341
# 11                           0.359523
# 12                           1.986672
# 13                          -0.359695
# 14                           1.520106
# 15                           0.470935
# 16                           0.678771
# 17                          -0.197326
# 18                           0.618861
# 19                          -0.311853
# 20                          -0.121595
# 21                          -0.231194
# 22                           1.347505
# 23                           1.121386
# 24                          -0.750517
# 25                          -1.023947
# 26                          -0.360784
# 27                          -1.254016
# 28                           0.161499
# 29                          -1.078941
# 30                          -1.063959
# 31                           0.250969
# 32                           2.007058
# 33                          -0.132069
# 34                           0.880696
# 35                           1.359422
# 36                           1.388891
# 37                          -1.044043
# 38                          -1.210208
# 39                          -1.751585
# 40                          -1.201468
# 41                          -0.524696
# 42                           1.619004
# 43                          -0.115638
# 44                           1.175923
# 45                          -0.902290
# 46                          -0.503319
# 47                          -0.076936
# 48                           1.268389
# 49                          -1.100039
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.402249
# 1                                           -0.425881
# 2                                            0.593649
# 3                                           -0.414569
# 4                                           -1.208411
# 5                                           -0.220940
# 6                                            0.463706
# 7                                           -1.953135
# 8                                            0.499978
# 9                                            0.707123
# 10                                           0.017075
# 11                                          -0.118687
# 12                                           2.550171
# 13                                          -0.331349
# 14                                           0.136022
# 15                                           0.640343
# 16                                           1.465486
# 17                                           0.161203
# 18                                          -0.937429
# 19                                          -0.155362
# 20                                           0.326693
# 21                                          -0.789996
# 22                                          -0.440526
# 23                                           1.101020
# 24                                          -0.903203
# 25                                           1.364797
# 26                                          -0.022500
# 27                                          -0.406976
# 28                                          -0.840167
# 29                                          -2.051774
# 30                                          -0.407160
# 31                                          -0.215038
# 32                                          -0.899160
# 33                                          -1.184059
# 34                                           0.688626
# 35                                           1.474644
# 36                                           0.636834
# ...
# 21                                          -1.359059
# 22                                          -0.092510
# 23                                           2.035263
# 24                                          -0.053001
# 25                                           1.649516
# 26                                           0.028106
# 27                                           0.176687
# 28                                           0.212494
# 29                                          -0.727403
# 30                                          -0.351132
# 31                                           0.416479
# 32                                          -0.448949
# 33                                          -1.355201
# 34                                           0.268776
# 35                                           0.363709
# 36                                           0.537145
# 37                                          -1.233682
# 38                                           0.475173
# 39                                          -1.242201
# 40                                          -1.188712
# 41                                           0.614996
# 42                                           0.272437
# 43                                           0.485977
# 44                                          -0.536230
# 45                                          -0.185565
# 46                                           0.542293
# 47                                           0.249117
# 48                                          -0.464495
# 49                                          -0.126285
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                            0.092134
# 1                                           -1.444638
# 2                                           -0.105389
# 3                                            0.114242
# 4                                           -1.597141
# 5                                           -1.109680
# 6                                           -0.470613
# 7                                           -1.630139
# 8                                            0.344774
# 9                                            0.085089
# 10                                           0.039583
# 11                                          -0.224654
# 12                                           3.307203
# 13                                          -0.177049
# 14                                           1.296662
# 15                                           0.403859
# 16                                           1.037701
# 17                                          -0.006864
# 18                                          -0.314043
# 19                                           0.106674
# 20                                           0.300848
# 21                                          -1.056692
# 22                                          -0.053294
# 23                                           1.793460
# 24                                          -0.306979
# 25                                           0.531185
# 26                                           0.644406
# 27                                           0.210041
# 28                                           0.421608
# 29                                          -1.359893
# 30                                          -0.299272
# 31                                          -0.511080
# 32                                          -0.213085
# 33                                          -1.146894
# 34                                           0.352785
# 35                                           1.373494
# 36                                           1.674145
# 37                                          -1.704616
# 38                                           0.813647
# 39                                          -2.206925
# 40                                          -1.006588
# 41                                           1.068900
# 42                                           1.530028
# 43                                          -0.120781
# 44                                          -0.376573
# 45                                           0.090200
# 46                                           0.168582
# 47                                          -0.209682
# 48                                           0.072987
# 49                                          -0.221673
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.138540
# 1                                           -0.280830
# 2                                            0.223628
# 3                                            0.276029
# 4                                           -0.337236
# 5                                           -0.611069
# 6                                            1.059462
# 7                                           -1.949821
# 8                                            0.817413
# 9                                            0.898810
# 10                                          -0.515317
# 11                                          -0.757250
# 12                                           1.883750
# 13                                          -0.192344
# 14                                           0.238108
# 15                                           0.380923
# 16                                           1.358816
# 17                                           0.083293
# 18                                          -0.867051
# 19                                           0.155274
# 20                                           0.353444
# 21                                          -0.544537
# 22                                          -0.578409
# 23                                           0.578586
# 24                                          -0.476726
# 25                                           1.807698
# 26                                          -0.339666
# 27                                          -0.901175
# 28                                          -0.890669
# 29                                          -1.080782
# 30                                          -0.790764
# 31                                          -0.873649
# 32                                          -0.933205
# 33                                          -1.546610
# 34                                          -1.129036
# 35                                           2.975608
# 36                                           0.266528
# 37                                          -0.991720
# 38                                           2.310487
# 39                                          -1.058216
# 40                                          -1.161160
# 41                                           1.083635
# 42                                           0.424908
# 43                                           0.424219
# 44                                          -0.993477
# 45                                           0.218417
# 46                                           0.444371
# 47                                           1.307519
# 48                                          -0.088575
# 49                                           0.179827
#
#     test_proba  target
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3     0.563563     0.0
# 4          NaN     NaN
# 5     0.047683     0.0
# 6     0.100131     0.0
# 7          NaN     NaN
# 8     0.959045     0.0
# 9          NaN     NaN
# 10         NaN     NaN
# 11         NaN     NaN
# 12         NaN     NaN
# 13    0.469853     1.0
# 14    0.326693     1.0
# 15         NaN     NaN
# 16         NaN     NaN
# 17         NaN     NaN
# 18    0.056501     0.0
# 19    0.971942     1.0
# 20    0.678862     0.0
# 21         NaN     NaN
# 22         NaN     NaN
# 23         NaN     NaN
# 24         NaN     NaN
# 25         NaN     NaN
# 26    0.035145     0.0
# 27         NaN     NaN
# 28    0.407317     0.0
# 29    0.052986     1.0
# 30         NaN     NaN
# 31         NaN     NaN
# 32         NaN     NaN
# 33         NaN     NaN
# 34         NaN     NaN
# 35         NaN     NaN
# 36    0.914302     1.0
# 37    0.085415     1.0
# 38         NaN     NaN
# 39    0.056501     0.0
# 40         NaN     NaN
# 41         NaN     NaN
# 42         NaN     NaN
# 43         NaN     NaN
# 44    0.842698     1.0
# 45    0.923611     1.0
# 46         NaN     NaN
# 47         NaN     NaN
# 48         NaN     NaN
# 49         NaN     NaN
#
# [50 rows x 2183 columns]

# %%
df3_main = df3.iloc[:49, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 19                     -0.297124                       -1.516128  0.889631
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 19  0.89838                            1.467604
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 19                          1.643959          2.10306     -1.169022
#
#     1-pyrrolinium  Acrylamide  ...  \
# 19      -1.024911   -1.135899  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 19                                           0.166531
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 19                                          -0.120201
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 19                                           0.559324
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 19                          -0.311853
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 19                                          -0.155362
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 19                                           -0.40441
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 19                                           0.106674
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 19                                           0.155274
#
#     test_proba  target
# 19    0.971942     1.0
#
# [1 rows x 2183 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {19}

# %%
df1_total = df1.loc[:49, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 13                      1.396407                        0.265786 -0.696165
# 14                      0.054482                       -0.503766  0.557838
# 19                     -0.297124                       -1.516128  0.889631
# 29                     -0.019049                        1.667113 -0.044138
# 36                      1.088285                       -1.125549  0.989243
# 37                     -0.019049                       -0.395921 -1.843302
# 44                     -0.313786                       -0.252847  1.441572
# 45                     -0.770829                       -1.247384  0.004456
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 13 -0.614555                           -0.466607
# 14  0.572075                            0.387016
# 19  0.898380                            1.467604
# 29 -0.043778                           -0.015732
# 36  1.003049                            1.630447
# 37 -1.689060                           -0.015732
# 44  1.300567                           -0.048002
# 45  0.044455                           -0.767735
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 13                         -0.899976        -1.124157     -0.830758
# 14                         -0.245765        -1.066907      0.352224
# 19                          1.643959         2.103060     -1.169022
# 29                         -1.333872        -0.007370      2.721207
# 36                          2.598029         2.923275     -0.823859
# 37                          0.000279        -1.749259      1.120690
# 44                         -0.664368        -0.604150      1.353553
# 45                         -0.541359        -0.695680     -0.982697
#
#     1-pyrrolinium  Acrylamide  ...  \
# 13       1.823535    1.606712  ...
# 14       0.341637    0.804410  ...
# 19      -1.024911   -1.135899  ...
# 29       0.287171    0.296495  ...
# 36      -0.785576   -0.021050  ...
# 37      -0.271963   -1.375957  ...
# 44      -0.656761   -0.456209  ...
# 45      -0.771881   -1.397265  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 13                                          -0.816144
# 14                                           0.993435
# 19                                           0.166531
# 29                                          -2.190999
# 36                                           1.223901
# 37                                          -0.422175
# 44                                          -0.096643
# 45                                          -0.661320
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 13                                          -0.337967
# 14                                           0.834884
# 19                                          -0.120201
# 29                                          -1.096797
# 36                                           2.172173
# 37                                          -1.781545
# 44                                          -0.342267
# 45                                          -0.065978
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 13                                          -0.012472
# 14                                           0.538391
# 19                                           0.559324
# 29                                           0.149012
# 36                                           1.613235
# 37                                          -1.753985
# 44                                          -0.504014
# 45                                           0.023919
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 13                          -0.359695
# 14                           1.520106
# 19                          -0.311853
# 29                          -1.078941
# 36                           1.388891
# 37                          -1.044043
# 44                           1.175923
# 45                          -0.902290
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 13                                          -0.331349
# 14                                           0.136022
# 19                                          -0.155362
# 29                                          -2.051774
# 36                                           0.636834
# 37                                          -1.451494
# 44                                          -1.167084
# 45                                          -0.257282
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 13                                           0.167279
# 14                                           1.947670
# 19                                          -0.404410
# 29                                          -0.727403
# 36                                           0.537145
# 37                                          -1.233682
# 44                                          -0.536230
# 45                                          -0.185565
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 13                                          -0.177049
# 14                                           1.296662
# 19                                           0.106674
# 29                                          -1.359893
# 36                                           1.674145
# 37                                          -1.704616
# 44                                          -0.376573
# 45                                           0.090200
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 13                                          -0.192344
# 14                                           0.238108
# 19                                           0.155274
# 29                                          -1.080782
# 36                                           0.266528
# 37                                          -0.991720
# 44                                          -0.993477
# 45                                           0.218417
#
#     test_proba  target
# 13    0.458400     1.0
# 14    0.445867     1.0
# 19    0.852133     1.0
# 29    0.281733     1.0
# 36    0.771333     1.0
# 37    0.386533     1.0
# 44    0.361067     1.0
# 45    0.794800     1.0
#
# [8 rows x 2183 columns]

# %%
with open('master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
