# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\NCI Cell Lines\\Cisplatin_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  Cisplatin
# 0   BT549   BR:BT-549    1.28259
# 1  HS578T  BR:HS 578T    1.57259
#
# [2 rows x 2185 columns]

# %%
#drop the target drug column
drug = data.pop('Cisplatin')

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((49, 2181), (49,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    36
# 1    13
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                      0.035090                       -0.565746  0.020684
# 1                     -1.278212                       -0.394287 -0.984873
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0  0.010146                            1.186667
# 1 -0.906224                           -0.551889
#
#    Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                          2.361560         1.801007     -1.510275
# 1                         -0.929051        -0.103841     -0.828443
#
#    1-pyrrolinium  Acrylamide  ...  \
# 0      -0.550535   -0.566932  ...
# 1      -0.168157   -0.812484  ...
#
#    PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 0                                           0.415243
# 1                                          -0.795405
#
#    TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                          -0.166448
# 1                                          -0.499636
#
#    2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                           0.540909
# 1                                          -0.735673
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                           0.152479
# 1                                          -1.231682
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.043283
# 1                                          -2.004296
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.85328
# 1                           -1.11291
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                           0.357250
# 1                                          -0.560482
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                          -0.476966
# 1                                          -1.919876
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                          -0.011057
# 1                                          -1.709043
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))
# 0                                           0.088009
# 1                                          -0.387667
#
# [2 rows x 2181 columns]

# %%
X.shape, y.shape
# Out:
# ((72, 2181), (72,))

# %%
y.value_counts()
# Out:
# 1    36
# 0    36
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.shape
# Out:
# (72, 2181)

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.33, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = i)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the machine learning model and train it
    model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = i)
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 461
# Number of features selected during iteration 1: 459
# Number of features selected during iteration 2: 438
# Number of features selected during iteration 3: 472
# Number of features selected during iteration 4: 449
# Number of features selected during iteration 5: 453
# Number of features selected during iteration 6: 433
# Number of features selected during iteration 7: 452
# Number of features selected during iteration 8: 453
# Number of features selected during iteration 9: 465
# Number of features selected during iteration 10: 449
# Number of features selected during iteration 11: 469
# Number of features selected during iteration 12: 461
# Number of features selected during iteration 13: 426
# Number of features selected during iteration 14: 442
# Number of features selected during iteration 15: 467
# Number of features selected during iteration 16: 477
# Number of features selected during iteration 17: 467
# Number of features selected during iteration 18: 437
# Number of features selected during iteration 19: 459
# Number of features selected during iteration 20: 461
# Number of features selected during iteration 21: 456
# Number of features selected during iteration 22: 459
# Number of features selected during iteration 23: 454
# Number of features selected during iteration 24: 449
# Number of features selected during iteration 25: 463
# Number of features selected during iteration 26: 449
# Number of features selected during iteration 27: 456
# Number of features selected during iteration 28: 453
# Number of features selected during iteration 29: 457
# Number of features selected during iteration 30: 459
# Number of features selected during iteration 31: 448
# Number of features selected during iteration 32: 465
# Number of features selected during iteration 33: 452
# Number of features selected during iteration 34: 457
# Number of features selected during iteration 35: 447
# Number of features selected during iteration 36: 460
# Number of features selected during iteration 37: 453
# Number of features selected during iteration 38: 463
# Number of features selected during iteration 39: 454
# Number of features selected during iteration 40: 466
# Number of features selected during iteration 41: 465
# Number of features selected during iteration 42: 457
# Number of features selected during iteration 43: 454
# Number of features selected during iteration 44: 458
# Number of features selected during iteration 45: 453
# Number of features selected during iteration 46: 459
# Number of features selected during iteration 47: 441
# Number of features selected during iteration 48: 451
# Number of features selected during iteration 49: 483
# Accuracy score: 0.9066666666666666, Standard deviation: 0.01779513042005217
# Recall score: 1.0, Standard deviation: 0.0
# Precision score: 0.8179487179487179, Standard deviation: 0.027377123723157204

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.035090                       -0.565746  0.020684
# 1                      -1.278212                       -0.394287 -0.984873
# 2                       1.106321                       -0.529949  2.246212
# 3                      -1.517083                       -0.686220 -1.629743
# 4                      -1.030213                       -1.276972 -0.163739
# ..                           ...                             ...       ...
# 67                      0.768653                        1.116355 -0.142586
# 68                      0.908381                       -0.698260  0.376008
# 69                      0.900473                       -0.376796  2.252684
# 70                      0.157113                        0.176092  2.271602
# 71                     -0.134501                       -1.038664  0.837518
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.010146                            1.186667
# 1  -0.906224                           -0.551889
# 2   2.219566                            0.670216
# 3  -1.531683                           -1.706712
# 4  -0.180627                           -1.731154
# ..       ...                                 ...
# 67 -0.092027                            0.368827
# 68  0.389676                            0.854358
# 69  2.225960                            0.903968
# 70  2.244734                            1.748821
# 71  0.839892                           -0.321977
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.361560         1.801007     -1.510275
# 1                          -0.929051        -0.103841     -0.828443
# 2                          -0.057363         0.324949     -0.287976
# 3                          -1.271983        -0.998233      1.268734
# 4                          -0.915980        -0.213179      0.309743
# ..                               ...              ...           ...
# 67                          1.150488         0.526978     -0.740866
# 68                          1.805623         1.886689     -0.826959
# 69                          0.160173         0.379551     -0.385941
# 70                          0.950557         0.581102     -0.740542
# 71                         -0.436230        -0.366686     -0.712875
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.550535   -0.566932  ...
# 1       -0.168157   -0.812484  ...
# 2       -0.554719   -0.850623  ...
# 3        0.132556   -0.211278  ...
# 4       -0.076660   -0.547265  ...
# ..            ...         ...  ...
# 67      -0.457507   -0.364135  ...
# 68      -0.453042   -0.929207  ...
# 69      -0.651806   -0.723548  ...
# 70      -1.002291   -0.264958  ...
# 71      -0.661367   -1.197063  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.540909
# 1                                           -0.735673
# 2                                            0.031125
# 3                                            1.042695
# 4                                            0.258001
# ..                                                ...
# 67                                           0.435833
# 68                                           0.186729
# 69                                          -0.132548
# 70                                          -0.724110
# 71                                          -0.408562
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.152479
# 1                                           -1.231682
# 2                                           -0.623275
# 3                                           -0.113718
# 4                                           -1.973852
# ..                                                ...
# 67                                          -0.494640
# 68                                           1.028689
# 69                                          -0.425120
# 70                                           0.296472
# 71                                          -0.331261
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.043283
# 1                                           -2.004296
# 2                                            0.048012
# 3                                           -0.566609
# 4                                           -1.582664
# ..                                                ...
# 67                                          -0.387543
# 68                                           0.900795
# 69                                           0.178418
# 70                                           0.653037
# 71                                          -0.014311
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.853280
# 1                           -1.112910
# 2                           -1.189638
# 3                            1.299297
# 4                           -0.844037
# ..                                ...
# 67                           0.232122
# 68                           1.456072
# 69                          -0.960376
# 70                          -0.124088
# 71                          -1.058685
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.357250
# 1                                           -0.560482
# 2                                            0.569360
# 3                                           -0.547946
# 4                                           -1.427679
# ..                                                ...
# 67                                           1.654942
# 68                                           0.486423
# 69                                           0.505411
# 70                                           0.274243
# 71                                           0.007209
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           -0.476966
# 1                                           -1.919876
# 2                                            0.046806
# 3                                           -0.536641
# 4                                           -1.801805
# ..                                                ...
# 67                                           0.045897
# 68                                           0.072246
# 69                                           0.018908
# 70                                          -0.081152
# 71                                          -0.095785
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           -0.011057
# 1                                           -1.709043
# 2                                           -0.229302
# 3                                            0.013370
# 4                                           -1.877545
# ..                                                ...
# 67                                          -0.232791
# 68                                           1.061816
# 69                                          -0.132278
# 70                                           0.223124
# 71                                          -0.100474
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.088009
# 1                                           -0.387667
# 2                                            0.184521
# 3                                            0.243958
# 4                                           -0.451647
# ..                                                ...
# 67                                           0.969636
# 68                                           0.307358
# 69                                           0.216350
# 70                                           0.331980
# 71                                           0.180998
#
#     test_proba  target
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ..         ...     ...
# 67    0.748667     1.0
# 68         NaN     NaN
# 69         NaN     NaN
# 70    0.936267     1.0
# 71         NaN     NaN
#
# [72 rows x 2183 columns]

# %%
df1_main = df1.iloc[:49, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (2, 2183)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([26, 43], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store accuracy, precision and recall 
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = SVC(kernel = 'linear', C=1, gamma=1, probability = True, random_state = i)
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.coef_.ravel()
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the SVM model and train it
    model2 = SVC(C=1, gamma=1, probability=True, random_state = i)
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 2181
# Features selected during iteration 1: 2181
# Features selected during iteration 2: 2181
# Features selected during iteration 3: 2181
# Features selected during iteration 4: 2181
# Features selected during iteration 5: 2181
# Features selected during iteration 6: 2181
# Features selected during iteration 7: 2181
# Features selected during iteration 8: 2181
# Features selected during iteration 9: 2181
# Features selected during iteration 10: 2181
# Features selected during iteration 11: 2181
# Features selected during iteration 12: 2181
# Features selected during iteration 13: 2181
# Features selected during iteration 14: 2181
# Features selected during iteration 15: 2181
# Features selected during iteration 16: 2181
# Features selected during iteration 17: 2181
# Features selected during iteration 18: 2181
# Features selected during iteration 19: 2181
# Features selected during iteration 20: 2181
# Features selected during iteration 21: 2181
# Features selected during iteration 22: 2181
# Features selected during iteration 23: 2181
# Features selected during iteration 24: 2181
# Features selected during iteration 25: 2181
# Features selected during iteration 26: 2181
# Features selected during iteration 27: 2181
# Features selected during iteration 28: 2181
# Features selected during iteration 29: 2181
# Features selected during iteration 30: 2181
# Features selected during iteration 31: 2181
# Features selected during iteration 32: 2181
# Features selected during iteration 33: 2181
# Features selected during iteration 34: 2181
# Features selected during iteration 35: 2181
# Features selected during iteration 36: 2181
# Features selected during iteration 37: 2181
# Features selected during iteration 38: 2181
# Features selected during iteration 39: 2181
# Features selected during iteration 40: 2181
# Features selected during iteration 41: 2181
# Features selected during iteration 42: 2181
# Features selected during iteration 43: 2181
# Features selected during iteration 44: 2181
# Features selected during iteration 45: 2181
# Features selected during iteration 46: 2181
# Features selected during iteration 47: 2181
# Features selected during iteration 48: 2181
# Features selected during iteration 49: 2181
# Accuracy score: 0.41666666666666674, Standard deviation: 5.551115123125783e-17
# Recall score: 1.0, Standard deviation: 0.0
# Precision score: 0.41666666666666674, Standard deviation: 5.551115123125783e-17

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:49, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [Acetone ; Propanal ; acetone, Acetaldehyde oxime ; HMDB01122, acetate, Urea, Isopropyl alcohol ; Propyl alcohol, Bicarbonate ; Hydrogen carbonate, Dimethylsulfide, 3-Butyn-1-al, 1-pyrrolinium, Acrylamide, Malondialdehyde ; Pyruvaldehyde ; acrylate ; malonic dialdehyde ; methylglyoxal, 3-Aminopropionaldehyde ; Aminoacetone ; HMDB01888 ; ammonioacetone ; beta-Aminopropion aldehyde, glyoxylate, propionate, Glycine, Glycolic acid ; glycolate, Imidazolone, 2-Pyrrolidinone, But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one, 2-Aminoacrylic acid ; 2-aminoacrylic acid, 3-oxopropanoate ; Malonic semialdehyde ; Pyruvic acid ; pyruvate, Beta-Alanine ; D-Alanine ; D-alanine ; L-Alanine ; L-alanine ; Sarcosine ; beta-alanine, (R)-lactate ; (S)-lactate ; 3-hydroxypropionate ; D-Glyceraldehyde ; D-Lactic acid ; Dihydroxyacetone ; Glyceraldehyde ; Hydroxypropionic acid ; L-Lactic acid ; glycerone, 2,3-Butanediol, cyanosulfurous acid anion, Glycerol, Aniline, Dimethyl sulfone, (R)-b-aminoisobutyric acid ; (S)-2-Aminobutanoate ; (S)-3-aminoisobutyric acid ; (S)-b-aminoisobutyric acid ; 2-Aminoisobutyric acid ; 3-Aminoisobutanoic acid ; 4-Aminobutanoate ; D-3-Amino-isobutanoate ; D-Alpha-aminobutyric acid ; Dimethylglycine ; Gamma-Aminobutyric acid ; L-Alpha-aminobutyric acid ; N,N-dimethylglycine, Choline, D-Serine ; D-serine ; L-Serine ; L-serine, Benzyl alcohol ; m-Cresol ; o-Cresol ; p-Cresol, Histamine ; histamium, 2-Furoic acid ; 3-Furoic acid, Uracil ; uracil, 1-Pyrroline-2-carboxylic acid ; 1-Pyrroline-5-carboxylate ; 1-Pyrroline-5-carboxylic acid ; 1-pyrroline-2-carboxylate, 5,6-dihydrouracil ; Dihydrouracil ; HMDB03646 ; L-3-Cyanoalanine, 3-Amino-2-piperidone, D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal, Fumarate ; Fumaric acid ; Maleic acid, Homocysteine thiolactone ; homocysteine thiolactone, Acetylglycine ; L-2-Amino-3-oxobutanoic acid ; L-2-amino-3-oxobutanoic acid ; L-Aspartate-semialdehyde, 5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine, Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone, Aminomalonic acid, L-Allothreonine ; L-Homoserine ; L-Threonine ; L-homoserine ; L-threonine, D-Cysteine ; L-Cysteine ; L-cysteine, 1-Phenylethylamine ; HMDB01020 ; Phenylethylamine, 3-Mercaptolactate ; 3-Mercaptolactic acid, 5,6-dihydrothymine ; Dihydrothymine, naphthalene, Octanal, 1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid, 3-Methylene-indolenine, 4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid, 4-trimethylammoniobutanal, Citraconic acid ; Glutaconic acid ; Itaconic acid ; Mesaconate ; Mesaconic acid ; itaconate(2-), 2-Ketohexanoic acid ; 2-Methyl-3-ketovaleric acid ; 3-Methyl-2-oxovaleric acid ; 3-Oxohexanoic acid ; Ketoleucine ; Mevalonolactone, Octanol, Iminoaspartic acid, 3-Hydroxy-L-proline ; 4-Hydroxy&#8203 ; 5-Amino-2-oxopentanoic acid ; 5-Amino-4-oxopentanoate ; 5-Aminolevulinic acid ; 5-amino-2-oxopentanoic acid ; HMDB00766 ; Hydroxyproline ; L-Glutamate 5-semialdehyde ; L-Glutamic-gamma-semialdehyde ; N-acetyl-L-alanine ; Propionylglycine ; trans-4-hydroxy-L-proline, Creatine ; creatine, 3-Methylindole, Aminocaproic acid ; Beta-Leucine ; L-Alloisoleucine ; L-Isoleucine ; L-Leucine ; L-Norleucine ; L-isoleucine ; L-leucine, HMDB11634, Oxalacetic acid ; Oxaloacetate, (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid, Glycyl-glycine ; HMDB12265 ; L-Asparagine ; L-asparagine ; N-carbamoyl-beta-alaninate ; Ureidopropionic acid, Cinnamaldehyde, (5R)-5-Hydroxyhexanoic acid ; (R)-2-hydroxy-4-methylpentanoate ; (R)-3-Hydroxyhexanoic acid ; 2-Ethyl-2-Hydroxybutyric acid ; 2-Hydroxy-3-methylpentanoic acid ; 2 ...
# Index: []
#
# [0 rows x 2183 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier(seed = i)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define XGBoost model and train it
    model3 = XGBClassifier(seed = i)
    model3.fit(X_train, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 24
# Features selected during iteration 1: 24
# Features selected during iteration 2: 24
# Features selected during iteration 3: 24
# Features selected during iteration 4: 24
# Features selected during iteration 5: 24
# Features selected during iteration 6: 24
# Features selected during iteration 7: 24
# Features selected during iteration 8: 24
# Features selected during iteration 9: 24
# Features selected during iteration 10: 24
# Features selected during iteration 11: 24
# Features selected during iteration 12: 24
# Features selected during iteration 13: 24
# Features selected during iteration 14: 24
# Features selected during iteration 15: 24
# Features selected during iteration 16: 24
# Features selected during iteration 17: 24
# Features selected during iteration 18: 24
# Features selected during iteration 19: 24
# Features selected during iteration 20: 24
# Features selected during iteration 21: 24
# Features selected during iteration 22: 24
# Features selected during iteration 23: 24
# Features selected during iteration 24: 24
# Features selected during iteration 25: 24
# Features selected during iteration 26: 24
# Features selected during iteration 27: 24
# Features selected during iteration 28: 24
# Features selected during iteration 29: 24
# Features selected during iteration 30: 24
# Features selected during iteration 31: 24
# Features selected during iteration 32: 24
# Features selected during iteration 33: 24
# Features selected during iteration 34: 24
# Features selected during iteration 35: 24
# Features selected during iteration 36: 24
# Features selected during iteration 37: 24
# Features selected during iteration 38: 24
# Features selected during iteration 39: 24
# Features selected during iteration 40: 24
# Features selected during iteration 41: 24
# Features selected during iteration 42: 24
# Features selected during iteration 43: 24
# Features selected during iteration 44: 24
# Features selected during iteration 45: 24
# Features selected during iteration 46: 24
# Features selected during iteration 47: 24
# Features selected during iteration 48: 24
# Features selected during iteration 49: 24
# Accuracy score: 0.875, Standard deviation: 0.0
# Recall score: 1.0, Standard deviation: 0.0
# Precision score: 0.7692307692307692, Standard deviation: 1.1102230246251565e-16

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.035090                       -0.565746  0.020684
# 1                      -1.278212                       -0.394287 -0.984873
# 2                       1.106321                       -0.529949  2.246212
# 3                      -1.517083                       -0.686220 -1.629743
# 4                      -1.030213                       -1.276972 -0.163739
# ..                           ...                             ...       ...
# 67                      0.768653                        1.116355 -0.142586
# 68                      0.908381                       -0.698260  0.376008
# 69                      0.900473                       -0.376796  2.252684
# 70                      0.157113                        0.176092  2.271602
# 71                     -0.134501                       -1.038664  0.837518
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.010146                            1.186667
# 1  -0.906224                           -0.551889
# 2   2.219566                            0.670216
# 3  -1.531683                           -1.706712
# 4  -0.180627                           -1.731154
# ..       ...                                 ...
# 67 -0.092027                            0.368827
# 68  0.389676                            0.854358
# 69  2.225960                            0.903968
# 70  2.244734                            1.748821
# 71  0.839892                           -0.321977
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.361560         1.801007     -1.510275
# 1                          -0.929051        -0.103841     -0.828443
# 2                          -0.057363         0.324949     -0.287976
# 3                          -1.271983        -0.998233      1.268734
# 4                          -0.915980        -0.213179      0.309743
# ..                               ...              ...           ...
# 67                          1.150488         0.526978     -0.740866
# 68                          1.805623         1.886689     -0.826959
# 69                          0.160173         0.379551     -0.385941
# 70                          0.950557         0.581102     -0.740542
# 71                         -0.436230        -0.366686     -0.712875
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.550535   -0.566932  ...
# 1       -0.168157   -0.812484  ...
# 2       -0.554719   -0.850623  ...
# 3        0.132556   -0.211278  ...
# 4       -0.076660   -0.547265  ...
# ..            ...         ...  ...
# 67      -0.457507   -0.364135  ...
# 68      -0.453042   -0.929207  ...
# 69      -0.651806   -0.723548  ...
# 70      -1.002291   -0.264958  ...
# 71      -0.661367   -1.197063  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.540909
# 1                                           -0.735673
# 2                                            0.031125
# 3                                            1.042695
# 4                                            0.258001
# ..                                                ...
# 67                                           0.435833
# 68                                           0.186729
# 69                                          -0.132548
# 70                                          -0.724110
# 71                                          -0.408562
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.152479
# 1                                           -1.231682
# 2                                           -0.623275
# 3                                           -0.113718
# 4                                           -1.973852
# ..                                                ...
# 67                                          -0.494640
# 68                                           1.028689
# 69                                          -0.425120
# 70                                           0.296472
# 71                                          -0.331261
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.043283
# 1                                           -2.004296
# 2                                            0.048012
# 3                                           -0.566609
# 4                                           -1.582664
# ..                                                ...
# 67                                          -0.387543
# 68                                           0.900795
# 69                                           0.178418
# 70                                           0.653037
# 71                                          -0.014311
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.853280
# 1                           -1.112910
# 2                           -1.189638
# 3                            1.299297
# 4                           -0.844037
# ..                                ...
# 67                           0.232122
# 68                           1.456072
# 69                          -0.960376
# 70                          -0.124088
# 71                          -1.058685
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.357250
# 1                                           -0.560482
# 2                                            0.569360
# 3                                           -0.547946
# 4                                           -1.427679
# ..                                                ...
# 67                                           1.654942
# 68                                           0.486423
# 69                                           0.505411
# 70                                           0.274243
# 71                                           0.007209
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           -0.476966
# 1                                           -1.919876
# 2                                            0.046806
# 3                                           -0.536641
# 4                                           -1.801805
# ..                                                ...
# 67                                           0.045897
# 68                                           0.072246
# 69                                           0.018908
# 70                                          -0.081152
# 71                                          -0.095785
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           -0.011057
# 1                                           -1.709043
# 2                                           -0.229302
# 3                                            0.013370
# 4                                           -1.877545
# ..                                                ...
# 67                                          -0.232791
# 68                                           1.061816
# 69                                          -0.132278
# 70                                           0.223124
# 71                                          -0.100474
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.088009
# 1                                           -0.387667
# 2                                            0.184521
# 3                                            0.243958
# 4                                           -0.451647
# ..                                                ...
# 67                                           0.969636
# 68                                           0.307358
# 69                                           0.216350
# 70                                           0.331980
# 71                                           0.180998
#
#     test_proba  target
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ..         ...     ...
# 67    0.969379     1.0
# 68         NaN     NaN
# 69         NaN     NaN
# 70    0.957589     1.0
# 71         NaN     NaN
#
# [72 rows x 2183 columns]

# %%
df3_main = df3.iloc[:49, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 26                      0.811101                        1.836086 -0.332327
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 26 -0.20558                            1.568536
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 26                         -0.062249        -0.600122      0.728521
#
#     1-pyrrolinium  Acrylamide  ...  \
# 26      -0.581126     1.50629  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 26                                          -0.334663
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 26                                            0.03212
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 26                                           0.170662
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 26                           -0.38667
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 26                                          -0.113455
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 26                                           0.054269
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 26                                            0.59915
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 26                                          -0.454403
#
#     test_proba  target
# 26     0.92921     1.0
#
# [1 rows x 2183 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {26, 43}

# %%
df1_total = df1.loc[:49, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 26                      0.811101                        1.836086 -0.332327
# 41                      0.195478                       -0.221828  0.741947
# 43                      0.183357                        0.259885 -1.783814
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 26 -0.205580                            1.568536
# 41  0.731412                           -0.047354
# 43 -1.673502                           -0.420820
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 26                         -0.062249        -0.600122      0.728521
# 41                          0.057641        -0.085368     -0.302604
# 43                         -0.478040        -0.325727      0.014637
#
#     1-pyrrolinium  Acrylamide  ...  \
# 26      -0.581126    1.506290  ...
# 41      -0.404047    0.984075  ...
# 43       1.764715    1.634518  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 26                                          -0.334663
# 41                                           1.776354
# 43                                           0.855347
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 26                                           0.032120
# 41                                           1.251777
# 43                                          -0.300074
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 26                                           0.170662
# 41                                           0.861508
# 43                                           0.192031
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 26                          -0.386670
# 41                          -0.563231
# 43                          -0.122604
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 26                                          -0.113455
# 41                                           0.827970
# 43                                           0.629990
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 26                                           0.054269
# 41                                           0.731762
# 43                                           0.582825
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 26                                           0.599150
# 41                                           1.068175
# 43                                          -0.246308
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 26                                          -0.454403
# 41                                           1.159996
# 43                                           0.412044
#
#     test_proba  target
# 26    0.858267     1.0
# 41    0.668267     1.0
# 43    0.758533     1.0
#
# [3 rows x 2183 columns]

# %%
with open('master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
