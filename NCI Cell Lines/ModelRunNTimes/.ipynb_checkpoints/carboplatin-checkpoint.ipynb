# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\NCI Cell Lines\\Carboplatin_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  Carboplatin
# 0   BT549   BR:BT-549     0.611724
# 1  HS578T  BR:HS 578T     0.705000
#
# [2 rows x 2185 columns]

# %%
#drop the target drug column
drug = data.pop('Carboplatin')

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((49, 2181), (49,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    38
# 1    11
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                      0.002751                       -0.664907  0.258086
# 1                     -1.278322                       -0.500447 -0.828299
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0  0.235637                            1.308159
# 1 -0.760549                           -0.486622
#
#    Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                          2.655817         2.018444     -1.674608
# 1                         -0.852301        -0.018201     -0.975432
#
#    1-pyrrolinium  Acrylamide  ...  \
# 0      -0.713295   -0.629040  ...
# 1      -0.324268   -0.876077  ...
#
#    PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 0                                           0.489360
# 1                                          -0.772273
#
#    TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                          -0.138351
# 1                                          -0.484222
#
#    2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                           0.542663
# 1                                          -0.759258
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                           0.296794
# 1                                          -1.131618
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.176412
# 1                                          -1.879450
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.950881
# 1                          -1.122391
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                           0.361180
# 1                                          -0.539032
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                          -0.438679
# 1                                          -1.864939
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.094164
# 1                                          -1.646009
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))
# 0                                           0.146738
# 1                                          -0.333320
#
# [2 rows x 2181 columns]

# %%
X.shape, y.shape
# Out:
# ((76, 2181), (76,))

# %%
y.value_counts()
# Out:
# 1    38
# 0    38
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.shape
# Out:
# (76, 2181)

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.33, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

#define the number of iterations for model training and testing
N = 10

#define a list to store the probabilities
prediction = []

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []

#run the feature selection and model training and evaluation N times
for i in range(N):
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = 43)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = None)
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the machine learning model and train it
    model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', random_state = 43)
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')


prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 402
# Number of features selected during iteration 1: 402
# Number of features selected during iteration 2: 402
# Number of features selected during iteration 3: 402
# Number of features selected during iteration 4: 402
# Number of features selected during iteration 5: 402
# Number of features selected during iteration 6: 402
# Number of features selected during iteration 7: 402
# Number of features selected during iteration 8: 402
# Number of features selected during iteration 9: 402
# Accuracy score: 0.8846153846153847, Standard deviation: 1.1102230246251565e-16
# Recall score: 0.7692307692307693, Standard deviation: 0.0
# Precision score: 1.0, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y_test
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1_main = df1.iloc[:49, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (2, 2183)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([40, 42], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 10

#define a list to store the probabilities
prediction2 = []

#define a list to store accuracy, precision and recall 
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = SVC(kernel = 'linear', C=1, gamma=1, probability = True, random_state = 42)
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.coef_.ravel()
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define the SVM model and train it
    model2 = SVC(C=1, gamma=1, probability=True, random_state = 42)
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 2162
# Features selected during iteration 1: 2162
# Features selected during iteration 2: 2162
# Features selected during iteration 3: 2162
# Features selected during iteration 4: 2162
# Features selected during iteration 5: 2162
# Features selected during iteration 6: 2162
# Features selected during iteration 7: 2162
# Features selected during iteration 8: 2162
# Features selected during iteration 9: 2162
# Accuracy score: 0.5384615384615384, Standard deviation: 0.0
# Recall score: 0.07692307692307691, Standard deviation: 1.3877787807814457e-17
# Precision score: 1.0, Standard deviation: 0.0

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:49, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [Acetone ; Propanal ; acetone, Acetaldehyde oxime ; HMDB01122, acetate, Urea, Isopropyl alcohol ; Propyl alcohol, Bicarbonate ; Hydrogen carbonate, Dimethylsulfide, 3-Butyn-1-al, 1-pyrrolinium, Acrylamide, Malondialdehyde ; Pyruvaldehyde ; acrylate ; malonic dialdehyde ; methylglyoxal, 3-Aminopropionaldehyde ; Aminoacetone ; HMDB01888 ; ammonioacetone ; beta-Aminopropion aldehyde, glyoxylate, propionate, Glycine, Glycolic acid ; glycolate, Imidazolone, 2-Pyrrolidinone, But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one, 2-Aminoacrylic acid ; 2-aminoacrylic acid, 3-oxopropanoate ; Malonic semialdehyde ; Pyruvic acid ; pyruvate, Beta-Alanine ; D-Alanine ; D-alanine ; L-Alanine ; L-alanine ; Sarcosine ; beta-alanine, (R)-lactate ; (S)-lactate ; 3-hydroxypropionate ; D-Glyceraldehyde ; D-Lactic acid ; Dihydroxyacetone ; Glyceraldehyde ; Hydroxypropionic acid ; L-Lactic acid ; glycerone, 2,3-Butanediol, cyanosulfurous acid anion, Glycerol, Aniline, Dimethyl sulfone, (R)-b-aminoisobutyric acid ; (S)-2-Aminobutanoate ; (S)-3-aminoisobutyric acid ; (S)-b-aminoisobutyric acid ; 2-Aminoisobutyric acid ; 3-Aminoisobutanoic acid ; 4-Aminobutanoate ; D-3-Amino-isobutanoate ; D-Alpha-aminobutyric acid ; Dimethylglycine ; Gamma-Aminobutyric acid ; L-Alpha-aminobutyric acid ; N,N-dimethylglycine, Choline, D-Serine ; D-serine ; L-Serine ; L-serine, Benzyl alcohol ; m-Cresol ; o-Cresol ; p-Cresol, Histamine ; histamium, 2-Furoic acid ; 3-Furoic acid, Uracil ; uracil, 1-Pyrroline-2-carboxylic acid ; 1-Pyrroline-5-carboxylate ; 1-Pyrroline-5-carboxylic acid ; 1-pyrroline-2-carboxylate, 5,6-dihydrouracil ; Dihydrouracil ; HMDB03646 ; L-3-Cyanoalanine, 3-Amino-2-piperidone, D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal, Fumarate ; Fumaric acid ; Maleic acid, Homocysteine thiolactone ; homocysteine thiolactone, Acetylglycine ; L-2-Amino-3-oxobutanoic acid ; L-2-amino-3-oxobutanoic acid ; L-Aspartate-semialdehyde, 5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine, Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone, Aminomalonic acid, L-Allothreonine ; L-Homoserine ; L-Threonine ; L-homoserine ; L-threonine, D-Cysteine ; L-Cysteine ; L-cysteine, 1-Phenylethylamine ; HMDB01020 ; Phenylethylamine, 3-Mercaptolactate ; 3-Mercaptolactic acid, 5,6-dihydrothymine ; Dihydrothymine, naphthalene, Octanal, 1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid, 3-Methylene-indolenine, 4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid, 4-trimethylammoniobutanal, Citraconic acid ; Glutaconic acid ; Itaconic acid ; Mesaconate ; Mesaconic acid ; itaconate(2-), 2-Ketohexanoic acid ; 2-Methyl-3-ketovaleric acid ; 3-Methyl-2-oxovaleric acid ; 3-Oxohexanoic acid ; Ketoleucine ; Mevalonolactone, Octanol, Iminoaspartic acid, 3-Hydroxy-L-proline ; 4-Hydroxy&#8203 ; 5-Amino-2-oxopentanoic acid ; 5-Amino-4-oxopentanoate ; 5-Aminolevulinic acid ; 5-amino-2-oxopentanoic acid ; HMDB00766 ; Hydroxyproline ; L-Glutamate 5-semialdehyde ; L-Glutamic-gamma-semialdehyde ; N-acetyl-L-alanine ; Propionylglycine ; trans-4-hydroxy-L-proline, Creatine ; creatine, 3-Methylindole, Aminocaproic acid ; Beta-Leucine ; L-Alloisoleucine ; L-Isoleucine ; L-Leucine ; L-Norleucine ; L-isoleucine ; L-leucine, HMDB11634, Oxalacetic acid ; Oxaloacetate, (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid, Glycyl-glycine ; HMDB12265 ; L-Asparagine ; L-asparagine ; N-carbamoyl-beta-alaninate ; Ureidopropionic acid, Cinnamaldehyde, (5R)-5-Hydroxyhexanoic acid ; (R)-2-hydroxy-4-methylpentanoate ; (R)-3-Hydroxyhexanoic acid ; 2-Ethyl-2-Hydroxybutyric acid ; 2-Hydroxy-3-methylpentanoic acid ; 2 ...
# Index: []
#
# [0 rows x 2183 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 10

#define a list to store the probabilities
prediction3 = []

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier(seed = 42)
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    
    #define XGBoost model and train it
    model3 = XGBClassifier(seed = 42)
    model3.fit(X_train, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 21
# Features selected during iteration 1: 21
# Features selected during iteration 2: 21
# Features selected during iteration 3: 21
# Features selected during iteration 4: 21
# Features selected during iteration 5: 21
# Features selected during iteration 6: 21
# Features selected during iteration 7: 21
# Features selected during iteration 8: 21
# Features selected during iteration 9: 21
# Accuracy score: 0.8076923076923077, Standard deviation: 0.0
# Recall score: 0.7692307692307693, Standard deviation: 0.0
# Precision score: 0.8333333333333334, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.002751                       -0.664907  0.258086
# 1                      -1.278322                       -0.500447 -0.828299
# 2                       1.047694                       -0.630571  2.662506
# 3                      -1.511331                       -0.780463 -1.525005
# 4                      -1.036409                       -1.347098  0.058839
# ..                           ...                             ...       ...
# 71                      0.829714                        1.087266  0.553814
# 72                     -0.161538                        1.627449 -0.832912
# 73                      0.732951                        1.572784 -0.191853
# 74                     -1.109133                       -0.509912 -0.574387
# 75                      0.238353                        0.351631 -1.458483
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.235637                            1.308159
# 1  -0.760549                           -0.486622
# 2   2.637498                            0.775006
# 3  -1.440486                           -1.678792
# 4   0.028248                           -1.704025
# ..       ...                                 ...
# 71  0.641916                            1.476972
# 72 -0.824868                           -0.642940
# 73 -0.068639                            1.612600
# 74 -0.513384                           -0.394854
# 75 -1.357577                           -0.046202
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.655817         2.018444     -1.674608
# 1                          -0.852301        -0.018201     -0.975432
# 2                           0.077004         0.440257     -0.421218
# 3                          -1.217901        -0.974476      1.175091
# 4                          -0.838367        -0.135104      0.191706
# ..                               ...              ...           ...
# 71                          0.073062        -0.308415      0.367783
# 72                         -0.788486        -0.544162      0.146216
# 73                          0.052418        -0.535994      0.589135
# 74                         -0.784706         0.015146     -0.935120
# 75                         -0.305623        -0.299026     -0.002149
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.713295   -0.629040  ...
# 1       -0.324268   -0.876077  ...
# 2       -0.717551   -0.914446  ...
# 3       -0.018327   -0.271235  ...
# 4       -0.231181   -0.609254  ...
# ..            ...         ...  ...
# 71      -0.737888    0.880384  ...
# 72       0.883807   -0.645673  ...
# 73      -0.640086    1.462355  ...
# 74      -0.352875   -0.878868  ...
# 75       1.287636    1.566553  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.542663
# 1                                           -0.759258
# 2                                            0.022761
# 3                                            1.054409
# 4                                            0.254140
# ..                                                ...
# 71                                          -0.259615
# 72                                          -1.063645
# 73                                          -0.297234
# 74                                          -0.702376
# 75                                           0.683037
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.296794
# 1                                           -1.131618
# 2                                           -0.503760
# 3                                            0.022087
# 4                                           -1.897515
# ..                                                ...
# 71                                           0.008195
# 72                                          -1.135345
# 73                                           0.157601
# 74                                          -1.085949
# 75                                          -0.119296
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.176412
# 1                                           -1.879450
# 2                                            0.181160
# 3                                           -0.435948
# 4                                           -1.456112
# ..                                                ...
# 71                                           0.274374
# 72                                          -0.957198
# 73                                           0.305243
# 74                                          -1.729566
# 75                                           0.322574
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.950881
# 1                           -1.122391
# 2                           -1.203299
# 3                            1.421189
# 4                           -0.838875
# ..                                ...
# 71                          -0.562396
# 72                          -1.084631
# 73                          -0.344426
# 74                          -1.128276
# 75                          -0.119519
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.361180
# 1                                           -0.539032
# 2                                            0.569241
# 3                                           -0.526736
# 4                                           -1.389676
# ..                                                ...
# 71                                           0.062256
# 72                                          -0.678261
# 73                                          -0.068660
# 74                                          -0.458419
# 75                                           0.520371
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           -0.438679
# 1                                           -1.864939
# 2                                            0.079048
# 3                                           -0.497665
# 4                                           -1.748231
# ..                                                ...
# 71                                           0.084632
# 72                                          -1.010651
# 73                                           0.109265
# 74                                          -1.723538
# 75                                           0.531262
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                            0.094164
# 1                                           -1.646009
# 2                                           -0.129503
# 3                                            0.119198
# 4                                           -1.818697
# ..                                                ...
# 71                                           0.513167
# 72                                          -0.989715
# 73                                           0.681654
# 74                                          -1.535702
# 75                                          -0.018204
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.146738
# 1                                           -0.333320
# 2                                            0.244139
# 3                                            0.304123
# 4                                           -0.397889
# ..                                                ...
# 71                                          -0.243944
# 72                                          -0.839152
# 73                                          -0.362445
# 74                                          -0.291317
# 75                                           0.343846
#
#     test_proba  target
# 0     0.115505     1.0
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ..         ...     ...
# 71    0.947362     1.0
# 72         NaN     NaN
# 73    0.948476     1.0
# 74         NaN     NaN
# 75    0.938021     1.0
#
# [76 rows x 2183 columns]

# %%
df3_main = df3.iloc[:49, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122  acetate  \
# 40                     -0.429425                        1.598472 -1.01123
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 40 -1.017816                           -0.790078
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 40                         -1.112964        -0.655152      0.283183
#
#     1-pyrrolinium  Acrylamide  ...  \
# 40       1.197973    -0.71553  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 40                                          -1.375734
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 40                                          -1.227729
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 40                                          -1.061515
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 40                          -1.311481
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 40                                          -1.316169
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 40                                          -1.302035
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 40                                          -1.149981
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 40                                          -1.341045
#
#     test_proba  target
# 40     0.79931     1.0
#
# [1 rows x 2183 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {40, 42}

# %%
df1_total = df1.loc[:49, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                       0.002751                       -0.664907  0.258086
# 40                     -0.429425                        1.598472 -1.011230
# 41                      0.159203                       -0.335029  1.037325
# 42                      1.264205                       -0.853125  0.826552
#
#         Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   0.235637                            1.308159
# 40 -1.017816                           -0.790078
# 41  1.019725                            0.034230
# 42  0.846605                            0.800154
#
#     Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                           2.655817         2.018444     -1.674608
# 40                         -1.112964        -0.655152      0.283183
# 41                          0.199610         0.001550     -0.436217
# 42                          1.778158         2.154101     -0.637000
#
#     1-pyrrolinium  Acrylamide  ...  \
# 0       -0.713295   -0.629040  ...
# 40       1.197973   -0.715530  ...
# 41      -0.564260    0.931344  ...
# 42      -0.566414   -1.168748  ...
#
#     2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                            0.542663
# 40                                          -1.375734
# 41                                           1.802630
# 42                                           0.007776
#
#     O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-_6-deoxy-a-L-galactopyranosyl-(1->4)_-O-b-D-galactopyranosyl-(1->4)-O-_6-deoxy-a-L-galactopyranosyl-(1->3)_-D-Glucose  \
# 0                                            0.296794
# 40                                          -1.227729
# 41                                           1.431237
# 42                                           1.635787
#
#     LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                            0.176412
# 40                                          -1.061515
# 41                                           0.997947
# 42                                           1.451371
#
#     PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                            0.950881
# 40                          -1.311481
# 41                          -0.542776
# 42                           1.892124
#
#     TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso6_ ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))_iso3_  \
# 0                                            0.361180
# 40                                          -1.316169
# 41                                           0.822914
# 42                                           0.548811
#
#     (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           -0.438679
# 40                                          -1.302035
# 41                                           0.756101
# 42                                           0.365221
#
#     Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                            0.094164
# 40                                          -1.149981
# 41                                           1.200211
# 42                                           1.722371
#
#     Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                            0.146738
# 40                                          -1.341045
# 41                                           1.228600
# 42                                           0.474547
#
#     test_proba  target
# 0     0.300000     1.0
# 40    0.566667     1.0
# 41    0.193333     1.0
# 42    0.493333     1.0
#
# [4 rows x 2183 columns]

# %%
with open('master_list_metabolomics.txt', 'w') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('total_metabolomics.txt', 'w') as f:
    for i in l:
        f.write(f'{i}\n')
