# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
np.random.seed(42)

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\data\\citrinin_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  citrinin
# 0   BT549   BR:BT-549   1.82875
# 1  HS578T  BR:HS 578T   0.57000
#
# [2 rows x 2185 columns]

# %%
#drop the target drug response variable
drug = data.pop(data.columns[-1])

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#select only the representative metabolites
X = X[rep_meta]

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
X.shape
# Out:
# (52, 197)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    35
# 1    17
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Isopropyl alcohol ; Propyl alcohol  \
# 0                            1.335069
# 1                           -0.418394
#
#    But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                          -0.175246
# 1                                           0.552460
#
#    2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                  -0.773484
# 1                                  -0.414987
#
#    D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                          -0.785903
# 1                                          -0.123679
#
#    5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                           0.139089
# 1                                           0.694833
#
#    Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                          -0.595674
# 1                                          -0.283143
#
#    Aminomalonic acid  \
# 0           0.092468
# 1          -1.244674
#
#    1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                          -0.566691
# 1                                          -1.158860
#
#    4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.51355
# 1                                           -1.13754
#
#    (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                           0.782017
# 1                                           1.324833
#
#    ...  Theaflavin-3-gallate  \
# 0  ...             -1.096945
# 1  ...             -0.718468
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -1.005623
# 1                                          -0.140096
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.422296
# 1                                          -1.169395
#
#    beta-casomorphin (1-6)  \
# 0               -1.051863
# 1               -0.016949
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.800063
# 1                                          -0.961986
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.169463             -0.37960             0.351128    -0.673232
# 1 -1.021791             -1.08276            -2.162031    -1.567756
#
#    dynorphin A 1-8
# 0         1.005828
# 1         0.621472
#
# [2 rows x 197 columns]

# %%
X.shape, y.shape
# Out:
# ((70, 197), (70,))

# %%
y.value_counts()
# Out:
# 1    35
# 0    35
# dtype: int64

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.20, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.shape, X_test.shape
# Out:
# ((56, 197), (14, 197))

# %%
y_train.value_counts(), y_test.value_counts()
# Out:
# (0    30
#  1    26
#  dtype: int64,
#  1    9
#  0    5
#  dtype: int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store the number of features being selected each run
num_features = []

#define the model
model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features.append(len(X_train.columns))
    
    #define the machine learning model and train it
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 64
# Number of features selected during iteration 1: 62
# Number of features selected during iteration 2: 65
# Number of features selected during iteration 3: 68
# Number of features selected during iteration 4: 66
# Number of features selected during iteration 5: 69
# Number of features selected during iteration 6: 65
# Number of features selected during iteration 7: 67
# Number of features selected during iteration 8: 69
# Number of features selected during iteration 9: 64
# Number of features selected during iteration 10: 66
# Number of features selected during iteration 11: 59
# Number of features selected during iteration 12: 61
# Number of features selected during iteration 13: 63
# Number of features selected during iteration 14: 66
# Number of features selected during iteration 15: 69
# Number of features selected during iteration 16: 61
# Number of features selected during iteration 17: 64
# Number of features selected during iteration 18: 67
# Number of features selected during iteration 19: 68
# Number of features selected during iteration 20: 59
# Number of features selected during iteration 21: 70
# Number of features selected during iteration 22: 62
# Number of features selected during iteration 23: 67
# Number of features selected during iteration 24: 64
# Number of features selected during iteration 25: 58
# Number of features selected during iteration 26: 76
# Number of features selected during iteration 27: 61
# Number of features selected during iteration 28: 72
# Number of features selected during iteration 29: 74
# Number of features selected during iteration 30: 69
# Number of features selected during iteration 31: 67
# Number of features selected during iteration 32: 66
# Number of features selected during iteration 33: 64
# Number of features selected during iteration 34: 66
# Number of features selected during iteration 35: 75
# Number of features selected during iteration 36: 65
# Number of features selected during iteration 37: 58
# Number of features selected during iteration 38: 81
# Number of features selected during iteration 39: 62
# Number of features selected during iteration 40: 65
# Number of features selected during iteration 41: 67
# Number of features selected during iteration 42: 62
# Number of features selected during iteration 43: 57
# Number of features selected during iteration 44: 65
# Number of features selected during iteration 45: 61
# Number of features selected during iteration 46: 71
# Number of features selected during iteration 47: 65
# Number of features selected during iteration 48: 57
# Number of features selected during iteration 49: 65
# Accuracy score: 0.7057142857142858, Standard deviation: 0.030772370326482876
# Recall score: 0.6599999999999998, Standard deviation: 0.026387426860084245
# Precision score: 0.8497619047619045, Standard deviation: 0.038383581382251064

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()
df1
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.335069
# 1                            -0.418394
# 2                             0.814190
# 3                            -1.583119
# 4                            -1.607771
# ..                                 ...
# 65                            0.394386
# 66                            1.152698
# 67                            1.385978
# 68                            0.966046
# 69                            0.171431
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.175246
# 1                                            0.552460
# 2                                            0.875324
# 3                                           -1.416693
# 4                                           -0.050089
# ..                                                ...
# 65                                           0.182843
# 66                                           2.314047
# 67                                          -1.123842
# 68                                           0.831669
# 69                                           0.055312
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.773484
# 1                                   -0.414987
# 2                                   -1.073910
# 3                                    0.945736
# 4                                   -0.428423
# ..                                        ...
# 65                                  -0.063008
# 66                                   0.287169
# 67                                  -1.016987
# 68                                   0.262422
# 69                                  -0.304562
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.785903
# 1                                           -0.123679
# 2                                           -0.405929
# 3                                            0.935829
# 4                                            0.389564
# ..                                                ...
# 65                                          -0.469521
# 66                                           0.357148
# 67                                          -0.855993
# 68                                          -0.747716
# 69                                          -0.345016
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.139089
# 1                                            0.694833
# 2                                            0.638411
# 3                                            1.241026
# 4                                           -1.355856
# ..                                                ...
# 65                                           0.995305
# 66                                          -0.772039
# 67                                           0.195308
# 68                                           1.222545
# 69                                           1.784311
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.595674
# 1                                           -0.283143
# 2                                           -0.721453
# 3                                           -0.480429
# 4                                           -0.716764
# ..                                                ...
# 65                                           0.065379
# 66                                           0.398651
# 67                                          -0.960894
# 68                                           0.706715
# 69                                           0.120420
#
#     Aminomalonic acid  \
# 0            0.092468
# 1           -1.244674
# 2            0.630525
# 3            0.186165
# 4           -0.922435
# ..                ...
# 65           1.083697
# 66           0.186237
# 67           0.078153
# 68           2.054378
# 69           0.234584
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.566691
# 1                                           -1.158860
# 2                                            0.563865
# 3                                            1.557750
# 4                                           -0.292056
# ..                                                ...
# 65                                           1.685504
# 66                                          -0.212666
# 67                                           0.021697
# 68                                           1.968299
# 69                                           0.655367
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513550
# 1                                           -1.137540
# 2                                            0.488543
# 3                                            1.558799
# 4                                           -0.618444
# ..                                                ...
# 65                                           2.026390
# 66                                          -0.399398
# 67                                           0.140395
# 68                                           2.557905
# 69                                           0.902784
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.782017
# 1                                            1.324833
# 2                                           -0.543079
# 3                                           -0.655081
# 4                                           -0.792376
# ..                                                ...
# 65                                          -0.553677
# 66                                           1.629203
# 67                                          -0.436489
# 68                                          -0.726947
# 69                                           0.114532
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 65  ...
# 66  ...
# 67  ...
# 68  ...
# 69  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.422296
# 1                                           -1.169395
# 2                                            0.026664
# 3                                           -0.148073
# 4                                           -1.259509
# ..                                                ...
# 65                                           1.922288
# 66                                          -0.060055
# 67                                          -0.204231
# 68                                           1.518950
# 69                                           2.074301
#
#     beta-casomorphin (1-6)  \
# 0                -1.051863
# 1                -0.016949
# 2                -0.926725
# 3                -0.280851
# 4                 0.207856
# ..                     ...
# 65                0.142148
# 66               -0.027100
# 67               -1.008629
# 68               -0.866717
# 69                0.361942
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.800063
# 1                                           -0.961986
# 2                                           -0.174573
# 3                                            0.307786
# 4                                           -1.687584
# ..                                                ...
# 65                                           1.308661
# 66                                          -0.011183
# 67                                           0.059236
# 68                                           1.695428
# 69                                           1.362042
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.169463            -0.379600             0.351128    -0.673232
# 1  -1.021791            -1.082760            -2.162031    -1.567756
# 2  -1.049051            -0.235390            -0.537226    -0.556728
# 3   0.335490            -0.327232            -0.820006     0.621733
# 4   1.305809            -2.023072            -0.653784    -1.081888
# ..       ...                  ...                  ...          ...
# 65  0.269229             1.028835             1.070380     1.645337
# 66 -0.232208             1.274394             0.150259    -0.437703
# 67 -1.069806            -0.318445             0.082432    -0.529445
# 68  0.363447             0.769900             1.039728     1.359550
# 69 -0.527161            -0.365125             1.815525     1.099147
#
#     dynorphin A 1-8  test_proba  target
# 0          1.005828         NaN     NaN
# 1          0.621472         NaN     NaN
# 2         -0.363640         NaN     NaN
# 3         -0.968829         NaN     NaN
# 4         -0.209693         NaN     NaN
# ..              ...         ...     ...
# 65         0.607542         NaN     NaN
# 66         0.347218         NaN     NaN
# 67         0.786336         NaN     NaN
# 68         1.294422         NaN     NaN
# 69        -0.266396         NaN     NaN
#
# [70 rows x 199 columns]

# %%
df1_main = df1.iloc[:51, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (2, 199)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store the number of features selected in each iteration
num_features2 = []

#define a list to store accuracy, precision and recall 
model2 = SVC(C=1, gamma=1, probability=True)
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = RandomForestClassifier(n_estimators=150, class_weight='balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.feature_importances_
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train-test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features2.append(len(X_train_new.columns))

    #define the SVM model and train it
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 65
# Features selected during iteration 1: 66
# Features selected during iteration 2: 67
# Features selected during iteration 3: 64
# Features selected during iteration 4: 69
# Features selected during iteration 5: 69
# Features selected during iteration 6: 65
# Features selected during iteration 7: 70
# Features selected during iteration 8: 59
# Features selected during iteration 9: 73
# Features selected during iteration 10: 63
# Features selected during iteration 11: 67
# Features selected during iteration 12: 64
# Features selected during iteration 13: 59
# Features selected during iteration 14: 63
# Features selected during iteration 15: 66
# Features selected during iteration 16: 70
# Features selected during iteration 17: 63
# Features selected during iteration 18: 61
# Features selected during iteration 19: 66
# Features selected during iteration 20: 68
# Features selected during iteration 21: 66
# Features selected during iteration 22: 75
# Features selected during iteration 23: 69
# Features selected during iteration 24: 66
# Features selected during iteration 25: 70
# Features selected during iteration 26: 68
# Features selected during iteration 27: 74
# Features selected during iteration 28: 71
# Features selected during iteration 29: 66
# Features selected during iteration 30: 70
# Features selected during iteration 31: 65
# Features selected during iteration 32: 65
# Features selected during iteration 33: 66
# Features selected during iteration 34: 65
# Features selected during iteration 35: 67
# Features selected during iteration 36: 65
# Features selected during iteration 37: 71
# Features selected during iteration 38: 66
# Features selected during iteration 39: 66
# Features selected during iteration 40: 64
# Features selected during iteration 41: 65
# Features selected during iteration 42: 63
# Features selected during iteration 43: 63
# Features selected during iteration 44: 69
# Features selected during iteration 45: 68
# Features selected during iteration 46: 63
# Features selected during iteration 47: 59
# Features selected during iteration 48: 64
# Features selected during iteration 49: 64
# Accuracy score: 0.48285714285714293, Standard deviation: 0.030505937862946614
# Recall score: 0.19555555555555554, Standard deviation: 0.04745368112013916
# Precision score: 1.0, Standard deviation: 0.0

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:51, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 40                           -0.714864
# 41                            0.090467
# 42                            0.838759
# 43                           -0.286201
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 40                                          -0.487352
# 41                                           0.071354
# 42                                           0.861129
# 43                                           0.162127
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 40                                   1.859451
# 41                                  -0.271936
# 42                                   0.440816
# 43                                   0.236046
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 40                                          -0.174378
# 41                                          -0.314340
# 42                                          -0.815753
# 43                                           0.923855
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 40                                          -1.963494
# 41                                           1.898782
# 42                                           1.224120
# 43                                           0.333812
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 40                                          -0.745601
# 41                                           0.170244
# 42                                           0.470248
# 43                                           0.530910
#
#     Aminomalonic acid  \
# 40           0.917598
# 41           0.244472
# 42           2.025136
# 43          -0.255825
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 40                                          -1.158797
# 41                                           0.740395
# 42                                           2.150245
# 43                                           0.622821
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 40                                          -1.156125
# 41                                           1.001330
# 42                                           2.808858
# 43                                           0.321231
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 40                                           0.059999
# 41                                           0.068090
# 42                                          -0.804740
# 43                                           3.073557
#
#     ...  \
# 40  ...
# 41  ...
# 42  ...
# 43  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 40                                          -0.966617
# 41                                           2.248008
# 42                                           1.698818
# 43                                          -0.053783
#
#     beta-casomorphin (1-6)  \
# 40                0.032804
# 41                0.460312
# 42               -0.862685
# 43               -0.267686
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 40                                          -1.451749
# 41                                           1.401143
# 42                                           1.711116
# 43                                           0.245744
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 40 -0.096613            -2.133894            -1.013511    -1.690201
# 41 -0.482471            -0.364118             1.917414     1.222465
# 42  0.163250             0.682240             1.091464     1.446582
# 43 -0.369307             0.508578             1.046396    -0.206740
#
#     dynorphin A 1-8  test_proba  target
# 40         0.568369    0.444612     1.0
# 41        -0.354915    0.648435     1.0
# 42         1.539025    0.557472     1.0
# 43         1.696935    0.443676     1.0
#
# [4 rows x 199 columns]

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store the number of features being selected in each iteration
num_features3 = []

#define the XGBoost model
model3 = XGBClassifier()

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier()
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features3.append(len(X_train_new.columns))

    #define XGBoost model and train it
    model3.fit(X_train_new, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test_new)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test_new))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 33
# Features selected during iteration 1: 33
# Features selected during iteration 2: 33
# Features selected during iteration 3: 33
# Features selected during iteration 4: 33
# Features selected during iteration 5: 33
# Features selected during iteration 6: 33
# Features selected during iteration 7: 33
# Features selected during iteration 8: 33
# Features selected during iteration 9: 33
# Features selected during iteration 10: 33
# Features selected during iteration 11: 33
# Features selected during iteration 12: 33
# Features selected during iteration 13: 33
# Features selected during iteration 14: 33
# Features selected during iteration 15: 33
# Features selected during iteration 16: 33
# Features selected during iteration 17: 33
# Features selected during iteration 18: 33
# Features selected during iteration 19: 33
# Features selected during iteration 20: 33
# Features selected during iteration 21: 33
# Features selected during iteration 22: 33
# Features selected during iteration 23: 33
# Features selected during iteration 24: 33
# Features selected during iteration 25: 33
# Features selected during iteration 26: 33
# Features selected during iteration 27: 33
# Features selected during iteration 28: 33
# Features selected during iteration 29: 33
# Features selected during iteration 30: 33
# Features selected during iteration 31: 33
# Features selected during iteration 32: 33
# Features selected during iteration 33: 33
# Features selected during iteration 34: 33
# Features selected during iteration 35: 33
# Features selected during iteration 36: 33
# Features selected during iteration 37: 33
# Features selected during iteration 38: 33
# Features selected during iteration 39: 33
# Features selected during iteration 40: 33
# Features selected during iteration 41: 33
# Features selected during iteration 42: 33
# Features selected during iteration 43: 33
# Features selected during iteration 44: 33
# Features selected during iteration 45: 33
# Features selected during iteration 46: 33
# Features selected during iteration 47: 33
# Features selected during iteration 48: 33
# Features selected during iteration 49: 33
# Accuracy score: 0.6428571428571429, Standard deviation: 0.0
# Recall score: 0.6666666666666665, Standard deviation: 1.1102230246251565e-16
# Precision score: 0.75, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.335069
# 1                            -0.418394
# 2                             0.814190
# 3                            -1.583119
# 4                            -1.607771
# ..                                 ...
# 65                            0.394386
# 66                            1.152698
# 67                            1.385978
# 68                            0.966046
# 69                            0.171431
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.175246
# 1                                            0.552460
# 2                                            0.875324
# 3                                           -1.416693
# 4                                           -0.050089
# ..                                                ...
# 65                                           0.182843
# 66                                           2.314047
# 67                                          -1.123842
# 68                                           0.831669
# 69                                           0.055312
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.773484
# 1                                   -0.414987
# 2                                   -1.073910
# 3                                    0.945736
# 4                                   -0.428423
# ..                                        ...
# 65                                  -0.063008
# 66                                   0.287169
# 67                                  -1.016987
# 68                                   0.262422
# 69                                  -0.304562
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.785903
# 1                                           -0.123679
# 2                                           -0.405929
# 3                                            0.935829
# 4                                            0.389564
# ..                                                ...
# 65                                          -0.469521
# 66                                           0.357148
# 67                                          -0.855993
# 68                                          -0.747716
# 69                                          -0.345016
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.139089
# 1                                            0.694833
# 2                                            0.638411
# 3                                            1.241026
# 4                                           -1.355856
# ..                                                ...
# 65                                           0.995305
# 66                                          -0.772039
# 67                                           0.195308
# 68                                           1.222545
# 69                                           1.784311
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.595674
# 1                                           -0.283143
# 2                                           -0.721453
# 3                                           -0.480429
# 4                                           -0.716764
# ..                                                ...
# 65                                           0.065379
# 66                                           0.398651
# 67                                          -0.960894
# 68                                           0.706715
# 69                                           0.120420
#
#     Aminomalonic acid  \
# 0            0.092468
# 1           -1.244674
# 2            0.630525
# 3            0.186165
# 4           -0.922435
# ..                ...
# 65           1.083697
# 66           0.186237
# 67           0.078153
# 68           2.054378
# 69           0.234584
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.566691
# 1                                           -1.158860
# 2                                            0.563865
# 3                                            1.557750
# 4                                           -0.292056
# ..                                                ...
# 65                                           1.685504
# 66                                          -0.212666
# 67                                           0.021697
# 68                                           1.968299
# 69                                           0.655367
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513550
# 1                                           -1.137540
# 2                                            0.488543
# 3                                            1.558799
# 4                                           -0.618444
# ..                                                ...
# 65                                           2.026390
# 66                                          -0.399398
# 67                                           0.140395
# 68                                           2.557905
# 69                                           0.902784
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.782017
# 1                                            1.324833
# 2                                           -0.543079
# 3                                           -0.655081
# 4                                           -0.792376
# ..                                                ...
# 65                                          -0.553677
# 66                                           1.629203
# 67                                          -0.436489
# 68                                          -0.726947
# 69                                           0.114532
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 65  ...
# 66  ...
# 67  ...
# 68  ...
# 69  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.422296
# 1                                           -1.169395
# 2                                            0.026664
# 3                                           -0.148073
# 4                                           -1.259509
# ..                                                ...
# 65                                           1.922288
# 66                                          -0.060055
# 67                                          -0.204231
# 68                                           1.518950
# 69                                           2.074301
#
#     beta-casomorphin (1-6)  \
# 0                -1.051863
# 1                -0.016949
# 2                -0.926725
# 3                -0.280851
# 4                 0.207856
# ..                     ...
# 65                0.142148
# 66               -0.027100
# 67               -1.008629
# 68               -0.866717
# 69                0.361942
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.800063
# 1                                           -0.961986
# 2                                           -0.174573
# 3                                            0.307786
# 4                                           -1.687584
# ..                                                ...
# 65                                           1.308661
# 66                                          -0.011183
# 67                                           0.059236
# 68                                           1.695428
# 69                                           1.362042
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.169463            -0.379600             0.351128    -0.673232
# 1  -1.021791            -1.082760            -2.162031    -1.567756
# 2  -1.049051            -0.235390            -0.537226    -0.556728
# 3   0.335490            -0.327232            -0.820006     0.621733
# 4   1.305809            -2.023072            -0.653784    -1.081888
# ..       ...                  ...                  ...          ...
# 65  0.269229             1.028835             1.070380     1.645337
# 66 -0.232208             1.274394             0.150259    -0.437703
# 67 -1.069806            -0.318445             0.082432    -0.529445
# 68  0.363447             0.769900             1.039728     1.359550
# 69 -0.527161            -0.365125             1.815525     1.099147
#
#     dynorphin A 1-8  test_proba  target
# 0          1.005828         NaN     NaN
# 1          0.621472         NaN     NaN
# 2         -0.363640         NaN     NaN
# 3         -0.968829         NaN     NaN
# 4         -0.209693         NaN     NaN
# ..              ...         ...     ...
# 65         0.607542         NaN     NaN
# 66         0.347218         NaN     NaN
# 67         0.786336         NaN     NaN
# 68         1.294422         NaN     NaN
# 69        -0.266396         NaN     NaN
#
# [70 rows x 199 columns]

# %%
df3_main = df3.iloc[:51, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 42                            0.838759
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 42                                           0.861129
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 42                                   0.440816
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 42                                          -0.815753
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 42                                            1.22412
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 42                                           0.470248
#
#     Aminomalonic acid  \
# 42           2.025136
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 42                                           2.150245
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 42                                           2.808858
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 42                                           -0.80474
#
#     ...  \
# 42  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 42                                           1.698818
#
#     beta-casomorphin (1-6)  \
# 42               -0.862685
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 42                                           1.711116
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 42  0.16325              0.68224             1.091464     1.446582
#
#     dynorphin A 1-8  test_proba  target
# 42         1.539025    0.961174     1.0
#
# [1 rows x 199 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {40, 41, 42, 43}

# %%
max(prediction[y_test == 0]), max(prediction2[y_test == 0]), max(prediction3[y_test == 0])
# Out:
# (0.5757333333333332, 0.44367562201630983, 0.81853753)

# %%
df1_main.shape[0], df2_main.shape[0], df3_main.shape[0]
# Out:
# (2, 4, 1)

# %%
df1_total = df1.loc[:51, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 31                            1.335070
# 40                           -0.714864
# 41                            0.090467
# 42                            0.838759
# 43                           -0.286201
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 31                                          -1.346766
# 40                                          -0.487352
# 41                                           0.071354
# 42                                           0.861129
# 43                                           0.162127
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 31                                   0.072132
# 40                                   1.859451
# 41                                  -0.271936
# 42                                   0.440816
# 43                                   0.236046
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 31                                          -0.703698
# 40                                          -0.174378
# 41                                          -0.314340
# 42                                          -0.815753
# 43                                           0.923855
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 31                                          -1.315265
# 40                                          -1.963494
# 41                                           1.898782
# 42                                           1.224120
# 43                                           0.333812
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 31                                          -0.540050
# 40                                          -0.745601
# 41                                           0.170244
# 42                                           0.470248
# 43                                           0.530910
#
#     Aminomalonic acid  \
# 31           1.899278
# 40           0.917598
# 41           0.244472
# 42           2.025136
# 43          -0.255825
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 31                                          -1.599761
# 40                                          -1.158797
# 41                                           0.740395
# 42                                           2.150245
# 43                                           0.622821
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 31                                          -1.335230
# 40                                          -1.156125
# 41                                           1.001330
# 42                                           2.808858
# 43                                           0.321231
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 31                                           1.037212
# 40                                           0.059999
# 41                                           0.068090
# 42                                          -0.804740
# 43                                           3.073557
#
#     ...  \
# 31  ...
# 40  ...
# 41  ...
# 42  ...
# 43  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 31                                          -0.530820
# 40                                          -0.966617
# 41                                           2.248008
# 42                                           1.698818
# 43                                          -0.053783
#
#     beta-casomorphin (1-6)  \
# 31                0.654611
# 40                0.032804
# 41                0.460312
# 42               -0.862685
# 43               -0.267686
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 31                                          -1.790595
# 40                                          -1.451749
# 41                                           1.401143
# 42                                           1.711116
# 43                                           0.245744
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 31  2.075032             0.190543            -0.705052    -0.777970
# 40 -0.096613            -2.133894            -1.013511    -1.690201
# 41 -0.482471            -0.364118             1.917414     1.222465
# 42  0.163250             0.682240             1.091464     1.446582
# 43 -0.369307             0.508578             1.046396    -0.206740
#
#     dynorphin A 1-8  test_proba  target
# 31        -3.052874    0.348267     1.0
# 40         0.568369    0.313467     1.0
# 41        -0.354915    0.622800     1.0
# 42         1.539025    0.807333     1.0
# 43         1.696935    0.570000     1.0
#
# [5 rows x 199 columns]

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
