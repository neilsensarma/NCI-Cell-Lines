# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
np.random.seed(42)

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\data\\Carboplatin_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  Carboplatin
# 0   BT549   BR:BT-549     0.611724
# 1  HS578T  BR:HS 578T     0.705000
#
# [2 rows x 2185 columns]

# %%
#drop the target drug column
drug = data.pop('Carboplatin')

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')

#select only the representative metabolites
X = X[rep_meta]

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
X.shape
# Out:
# (52, 197)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((52, 197), (52,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    39
# 1    13
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Isopropyl alcohol ; Propyl alcohol  \
# 0                            1.478482
# 1                           -0.326031
#
#    But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                          -0.288254
# 1                                           0.451966
#
#    2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                  -0.876061
# 1                                  -0.480567
#
#    D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                          -0.878128
# 1                                          -0.172004
#
#    5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                           0.057627
# 1                                           0.648200
#
#    Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                          -0.684360
# 1                                          -0.360677
#
#    Aminomalonic acid  \
# 0           0.203592
# 1          -1.177505
#
#    1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                          -0.576189
# 1                                          -1.178544
#
#    4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                          -0.513859
# 1                                          -1.184908
#
#    (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                           0.455643
# 1                                           0.953044
#
#    ...  Theaflavin-3-gallate  \
# 0  ...             -1.051322
# 1  ...             -0.628568
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -1.031412
# 1                                          -0.093726
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.374868
# 1                                          -1.143644
#
#    beta-casomorphin (1-6)  \
# 0               -1.214645
# 1                0.100907
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.893861
# 1                                          -0.983495
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.133688            -0.355474             0.348388    -0.715142
# 1 -0.980514            -1.095321            -2.039662    -1.648273
#
#    dynorphin A 1-8
# 0         0.917747
# 1         0.546335
#
# [2 rows x 197 columns]

# %%
X.shape, y.shape
# Out:
# ((78, 197), (78,))

# %%
y.value_counts()
# Out:
# 1    39
# 0    39
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.shape
# Out:
# (78, 197)

# %%
X.head(2)
# Out:
#    Isopropyl alcohol ; Propyl alcohol  \
# 0                            1.478482
# 1                           -0.326031
#
#    But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                          -0.288254
# 1                                           0.451966
#
#    2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                  -0.876061
# 1                                  -0.480567
#
#    D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                          -0.878128
# 1                                          -0.172004
#
#    5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                           0.057627
# 1                                           0.648200
#
#    Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                          -0.684360
# 1                                          -0.360677
#
#    Aminomalonic acid  \
# 0           0.203592
# 1          -1.177505
#
#    1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                          -0.576189
# 1                                          -1.178544
#
#    4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                          -0.513859
# 1                                          -1.184908
#
#    (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                           0.455643
# 1                                           0.953044
#
#    ...  Theaflavin-3-gallate  \
# 0  ...             -1.051322
# 1  ...             -0.628568
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -1.031412
# 1                                          -0.093726
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.374868
# 1                                          -1.143644
#
#    beta-casomorphin (1-6)  \
# 0               -1.214645
# 1                0.100907
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.893861
# 1                                          -0.983495
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.133688            -0.355474             0.348388    -0.715142
# 1 -0.980514            -1.095321            -2.039662    -1.648273
#
#    dynorphin A 1-8
# 0         0.917747
# 1         0.546335
#
# [2 rows x 197 columns]

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.20, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.shape, X_test.shape
# Out:
# ((62, 197), (16, 197))

# %%
y_train.value_counts(), y_test.value_counts()
# Out:
# (0    33
#  1    29
#  dtype: int64,
#  1    10
#  0     6
#  dtype: int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store the number of features being selected each run
num_features = []

#define the model
model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []


#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features.append(len(X_train.columns))
    
    #define the machine learning model and train it
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 64
# Number of features selected during iteration 1: 64
# Number of features selected during iteration 2: 69
# Number of features selected during iteration 3: 70
# Number of features selected during iteration 4: 64
# Number of features selected during iteration 5: 67
# Number of features selected during iteration 6: 59
# Number of features selected during iteration 7: 56
# Number of features selected during iteration 8: 69
# Number of features selected during iteration 9: 70
# Number of features selected during iteration 10: 68
# Number of features selected during iteration 11: 56
# Number of features selected during iteration 12: 60
# Number of features selected during iteration 13: 65
# Number of features selected during iteration 14: 62
# Number of features selected during iteration 15: 67
# Number of features selected during iteration 16: 62
# Number of features selected during iteration 17: 70
# Number of features selected during iteration 18: 67
# Number of features selected during iteration 19: 64
# Number of features selected during iteration 20: 65
# Number of features selected during iteration 21: 65
# Number of features selected during iteration 22: 68
# Number of features selected during iteration 23: 63
# Number of features selected during iteration 24: 68
# Number of features selected during iteration 25: 60
# Number of features selected during iteration 26: 58
# Number of features selected during iteration 27: 61
# Number of features selected during iteration 28: 66
# Number of features selected during iteration 29: 64
# Number of features selected during iteration 30: 63
# Number of features selected during iteration 31: 69
# Number of features selected during iteration 32: 64
# Number of features selected during iteration 33: 60
# Number of features selected during iteration 34: 62
# Number of features selected during iteration 35: 63
# Number of features selected during iteration 36: 67
# Number of features selected during iteration 37: 69
# Number of features selected during iteration 38: 68
# Number of features selected during iteration 39: 60
# Number of features selected during iteration 40: 60
# Number of features selected during iteration 41: 58
# Number of features selected during iteration 42: 67
# Number of features selected during iteration 43: 65
# Number of features selected during iteration 44: 63
# Number of features selected during iteration 45: 66
# Number of features selected during iteration 46: 62
# Number of features selected during iteration 47: 66
# Number of features selected during iteration 48: 60
# Number of features selected during iteration 49: 65
# Accuracy score: 0.8075, Standard deviation: 0.01695582495781317
# Recall score: 0.6920000000000002, Standard deviation: 0.02712931993250106
# Precision score: 1.0, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.478482
# 1                            -0.326031
# 2                             0.942438
# 3                            -1.524667
# 4                            -1.550036
# ..                                 ...
# 73                           -1.575049
# 74                            0.429424
# 75                           -0.473860
# 76                           -0.826081
# 77                           -0.304575
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.288254
# 1                                            0.451966
# 2                                            0.780383
# 3                                           -1.551050
# 4                                           -0.160944
# ..                                                ...
# 73                                          -0.814235
# 74                                           0.295581
# 75                                          -0.599552
# 76                                          -1.411605
# 77                                           0.389346
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876061
# 1                                   -0.480567
# 2                                   -1.207490
# 3                                    1.020583
# 4                                   -0.495389
# ..                                        ...
# 73                                   0.002034
# 74                                  -0.744181
# 75                                  -0.290169
# 76                                  -0.945078
# 77                                  -0.367292
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.878128
# 1                                           -0.172004
# 2                                           -0.472964
# 3                                            0.957741
# 4                                            0.375264
# ..                                                ...
# 73                                           0.072595
# 74                                          -0.175461
# 75                                           0.437649
# 76                                          -0.191828
# 77                                           0.004161
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.057627
# 1                                            0.648200
# 2                                            0.588242
# 3                                            1.228624
# 4                                           -1.531009
# ..                                                ...
# 73                                           0.862519
# 74                                           0.721404
# 75                                          -0.279688
# 76                                          -0.954968
# 77                                           0.587693
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.684360
# 1                                           -0.360677
# 2                                           -0.814626
# 3                                           -0.565003
# 4                                           -0.809771
# ..                                                ...
# 73                                          -0.572718
# 74                                          -0.762719
# 75                                          -0.000378
# 76                                          -0.599425
# 77                                          -0.227707
#
#     Aminomalonic acid  \
# 0            0.203592
# 1           -1.177505
# 2            0.759337
# 3            0.300370
# 4           -0.844673
# ..                ...
# 73          -0.653726
# 74           0.663899
# 75          -0.719738
# 76          -1.419025
# 77          -1.016422
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.576189
# 1                                           -1.178544
# 2                                            0.573815
# 3                                            1.584796
# 4                                           -0.296830
# ..                                                ...
# 73                                           1.655676
# 74                                           0.784040
# 75                                           0.437449
# 76                                           0.193840
# 77                                          -0.892712
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513859
# 1                                           -1.184908
# 2                                            0.563809
# 3                                            1.714780
# 4                                           -0.626663
# ..                                                ...
# 73                                           1.362594
# 74                                           0.803143
# 75                                           0.292331
# 76                                           0.178740
# 77                                          -0.937486
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.455643
# 1                                            0.953044
# 2                                           -0.758589
# 3                                           -0.861220
# 4                                           -0.987028
# ..                                                ...
# 73                                          -0.406270
# 74                                          -0.779930
# 75                                           1.140907
# 76                                          -0.614238
# 77                                           1.205770
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 73  ...
# 74  ...
# 75  ...
# 76  ...
# 77  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.374868
# 1                                           -1.143644
# 2                                            0.087119
# 3                                           -0.092688
# 4                                           -1.236372
# ..                                                ...
# 73                                           0.135424
# 74                                           0.049729
# 75                                          -0.238768
# 76                                          -0.540407
# 77                                          -0.962589
#
#     beta-casomorphin (1-6)  \
# 0                -1.214645
# 1                 0.100907
# 2                -1.055573
# 3                -0.234557
# 4                 0.386673
# ..                     ...
# 73                0.145342
# 74               -0.884850
# 75               -0.200126
# 76               -0.178169
# 77                0.050639
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.893861
# 1                                           -0.983495
# 2                                           -0.144555
# 3                                            0.369370
# 4                                           -1.756575
# ..                                                ...
# 73                                           0.260952
# 74                                          -0.037688
# 75                                          -0.132882
# 76                                          -0.674045
# 77                                          -0.780553
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.133688            -0.355474             0.348388    -0.715142
# 1  -0.980514            -1.095321            -2.039662    -1.648273
# 2  -1.008790            -0.203740            -0.495743    -0.593609
# 3   0.427341            -0.300374            -0.764445     0.635713
# 4   1.433815            -2.084695            -0.606498    -1.141435
# ..       ...                  ...                  ...          ...
# 73  0.355314            -0.266206             0.034540     1.013079
# 74 -0.710158            -0.223834            -0.551617    -0.337982
# 75 -0.384627             0.033676             0.596106    -0.280565
# 76 -0.485018            -0.643004             0.083741    -0.345147
# 77 -0.873773            -0.831248            -1.558835    -1.424356
#
#     dynorphin A 1-8  test_proba  target
# 0          0.917747    0.719467     1.0
# 1          0.546335         NaN     NaN
# 2         -0.405604         NaN     NaN
# 3         -0.990412         NaN     NaN
# 4         -0.256840         NaN     NaN
# ..              ...         ...     ...
# 73        -0.031460         NaN     NaN
# 74        -0.527210         NaN     NaN
# 75         0.922484    0.907333     1.0
# 76         0.099728         NaN     NaN
# 77         0.710240    0.940933     1.0
#
# [78 rows x 199 columns]

# %%
df1_main = df1.iloc[:51, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (3, 199)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([ 0, 42, 43], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store the number of features selected in each iteration
num_features2 = []

#define a list to store accuracy, precision and recall 
model2 = SVC(C=1, gamma=1, probability=True)
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = RandomForestClassifier(n_estimators=150, class_weight='balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.feature_importances_
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train-test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features2.append(len(X_train_new.columns))

    #define the SVM model and train it
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 74
# Features selected during iteration 1: 68
# Features selected during iteration 2: 66
# Features selected during iteration 3: 57
# Features selected during iteration 4: 68
# Features selected during iteration 5: 60
# Features selected during iteration 6: 60
# Features selected during iteration 7: 54
# Features selected during iteration 8: 65
# Features selected during iteration 9: 63
# Features selected during iteration 10: 64
# Features selected during iteration 11: 65
# Features selected during iteration 12: 61
# Features selected during iteration 13: 60
# Features selected during iteration 14: 56
# Features selected during iteration 15: 57
# Features selected during iteration 16: 67
# Features selected during iteration 17: 61
# Features selected during iteration 18: 64
# Features selected during iteration 19: 69
# Features selected during iteration 20: 65
# Features selected during iteration 21: 56
# Features selected during iteration 22: 68
# Features selected during iteration 23: 77
# Features selected during iteration 24: 55
# Features selected during iteration 25: 66
# Features selected during iteration 26: 59
# Features selected during iteration 27: 63
# Features selected during iteration 28: 62
# Features selected during iteration 29: 64
# Features selected during iteration 30: 60
# Features selected during iteration 31: 61
# Features selected during iteration 32: 60
# Features selected during iteration 33: 60
# Features selected during iteration 34: 63
# Features selected during iteration 35: 70
# Features selected during iteration 36: 62
# Features selected during iteration 37: 61
# Features selected during iteration 38: 66
# Features selected during iteration 39: 58
# Features selected during iteration 40: 65
# Features selected during iteration 41: 65
# Features selected during iteration 42: 66
# Features selected during iteration 43: 65
# Features selected during iteration 44: 57
# Features selected during iteration 45: 61
# Features selected during iteration 46: 63
# Features selected during iteration 47: 67
# Features selected during iteration 48: 62
# Features selected during iteration 49: 64
# Accuracy score: 0.52375, Standard deviation: 0.035111429762970346
# Recall score: 0.23800000000000002, Standard deviation: 0.05617828762075255
# Precision score: 1.0, Standard deviation: 0.0

# %%
print(f'Average number of features being selected: {np.mean(num_features2)}')
# Out:
# Average number of features being selected: 63.0

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:51, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.478482
# 41                            0.197645
# 42                            0.967723
# 43                           -0.189990
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.288254
# 41                                          -0.037413
# 42                                           0.765943
# 43                                           0.054920
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876061
# 41                                  -0.322753
# 42                                   0.463555
# 43                                   0.237653
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.878128
# 41                                          -0.375304
# 42                                          -0.909956
# 43                                           0.944974
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.057627
# 41                                           1.927602
# 42                                           1.210658
# 43                                           0.264553
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.684360
# 41                                           0.108888
# 42                                           0.419596
# 43                                           0.482423
#
#     Aminomalonic acid  \
# 0            0.203592
# 41           0.360594
# 42           2.199793
# 43          -0.156150
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.576189
# 41                                           0.753382
# 42                                           2.187483
# 43                                           0.633784
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513859
# 41                                           1.115268
# 42                                           3.059113
# 43                                           0.383879
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.455643
# 41                                          -0.198553
# 42                                          -0.998358
# 43                                           2.555461
#
#     ...  \
# 0   ...
# 41  ...
# 42  ...
# 43  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.374868
# 41                                           2.372916
# 42                                           1.807791
# 43                                           0.004338
#
#     beta-casomorphin (1-6)  \
# 0                -1.214645
# 41                0.707587
# 42               -0.974166
# 43               -0.217821
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.893861
# 41                                           1.534275
# 42                                           1.864532
# 43                                           0.303267
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.133688            -0.355474             0.348388    -0.715142
# 41 -0.421098            -0.339184             1.836702     1.262373
# 42  0.248684             0.761768             1.051869     1.496163
# 43 -0.303717             0.579045             1.009045    -0.228516
#
#     dynorphin A 1-8  test_proba  target
# 0          0.917747    0.854287     1.0
# 41        -0.397172    0.415158     1.0
# 42         1.432989    0.499337     1.0
# 43         1.585582    0.652382     1.0
#
# [4 rows x 199 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([ 0, 41, 42, 43], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store the number of features being selected in each iteration
num_features3 = []

#define the XGBoost model
model3 = XGBClassifier()

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier()
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features3.append(len(X_train_new.columns))

    #define XGBoost model and train it
    model3.fit(X_train_new, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test_new)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test_new))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 32
# Features selected during iteration 1: 32
# Features selected during iteration 2: 32
# Features selected during iteration 3: 32
# Features selected during iteration 4: 32
# Features selected during iteration 5: 32
# Features selected during iteration 6: 32
# Features selected during iteration 7: 32
# Features selected during iteration 8: 32
# Features selected during iteration 9: 32
# Features selected during iteration 10: 32
# Features selected during iteration 11: 32
# Features selected during iteration 12: 32
# Features selected during iteration 13: 32
# Features selected during iteration 14: 32
# Features selected during iteration 15: 32
# Features selected during iteration 16: 32
# Features selected during iteration 17: 32
# Features selected during iteration 18: 32
# Features selected during iteration 19: 32
# Features selected during iteration 20: 32
# Features selected during iteration 21: 32
# Features selected during iteration 22: 32
# Features selected during iteration 23: 32
# Features selected during iteration 24: 32
# Features selected during iteration 25: 32
# Features selected during iteration 26: 32
# Features selected during iteration 27: 32
# Features selected during iteration 28: 32
# Features selected during iteration 29: 32
# Features selected during iteration 30: 32
# Features selected during iteration 31: 32
# Features selected during iteration 32: 32
# Features selected during iteration 33: 32
# Features selected during iteration 34: 32
# Features selected during iteration 35: 32
# Features selected during iteration 36: 32
# Features selected during iteration 37: 32
# Features selected during iteration 38: 32
# Features selected during iteration 39: 32
# Features selected during iteration 40: 32
# Features selected during iteration 41: 32
# Features selected during iteration 42: 32
# Features selected during iteration 43: 32
# Features selected during iteration 44: 32
# Features selected during iteration 45: 32
# Features selected during iteration 46: 32
# Features selected during iteration 47: 32
# Features selected during iteration 48: 32
# Features selected during iteration 49: 32
# Accuracy score: 0.75, Standard deviation: 0.0
# Recall score: 0.7000000000000002, Standard deviation: 2.220446049250313e-16
# Precision score: 0.875, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.478482
# 1                            -0.326031
# 2                             0.942438
# 3                            -1.524667
# 4                            -1.550036
# ..                                 ...
# 73                           -1.575049
# 74                            0.429424
# 75                           -0.473860
# 76                           -0.826081
# 77                           -0.304575
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.288254
# 1                                            0.451966
# 2                                            0.780383
# 3                                           -1.551050
# 4                                           -0.160944
# ..                                                ...
# 73                                          -0.814235
# 74                                           0.295581
# 75                                          -0.599552
# 76                                          -1.411605
# 77                                           0.389346
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876061
# 1                                   -0.480567
# 2                                   -1.207490
# 3                                    1.020583
# 4                                   -0.495389
# ..                                        ...
# 73                                   0.002034
# 74                                  -0.744181
# 75                                  -0.290169
# 76                                  -0.945078
# 77                                  -0.367292
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.878128
# 1                                           -0.172004
# 2                                           -0.472964
# 3                                            0.957741
# 4                                            0.375264
# ..                                                ...
# 73                                           0.072595
# 74                                          -0.175461
# 75                                           0.437649
# 76                                          -0.191828
# 77                                           0.004161
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.057627
# 1                                            0.648200
# 2                                            0.588242
# 3                                            1.228624
# 4                                           -1.531009
# ..                                                ...
# 73                                           0.862519
# 74                                           0.721404
# 75                                          -0.279688
# 76                                          -0.954968
# 77                                           0.587693
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.684360
# 1                                           -0.360677
# 2                                           -0.814626
# 3                                           -0.565003
# 4                                           -0.809771
# ..                                                ...
# 73                                          -0.572718
# 74                                          -0.762719
# 75                                          -0.000378
# 76                                          -0.599425
# 77                                          -0.227707
#
#     Aminomalonic acid  \
# 0            0.203592
# 1           -1.177505
# 2            0.759337
# 3            0.300370
# 4           -0.844673
# ..                ...
# 73          -0.653726
# 74           0.663899
# 75          -0.719738
# 76          -1.419025
# 77          -1.016422
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.576189
# 1                                           -1.178544
# 2                                            0.573815
# 3                                            1.584796
# 4                                           -0.296830
# ..                                                ...
# 73                                           1.655676
# 74                                           0.784040
# 75                                           0.437449
# 76                                           0.193840
# 77                                          -0.892712
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513859
# 1                                           -1.184908
# 2                                            0.563809
# 3                                            1.714780
# 4                                           -0.626663
# ..                                                ...
# 73                                           1.362594
# 74                                           0.803143
# 75                                           0.292331
# 76                                           0.178740
# 77                                          -0.937486
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.455643
# 1                                            0.953044
# 2                                           -0.758589
# 3                                           -0.861220
# 4                                           -0.987028
# ..                                                ...
# 73                                          -0.406270
# 74                                          -0.779930
# 75                                           1.140907
# 76                                          -0.614238
# 77                                           1.205770
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 73  ...
# 74  ...
# 75  ...
# 76  ...
# 77  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.374868
# 1                                           -1.143644
# 2                                            0.087119
# 3                                           -0.092688
# 4                                           -1.236372
# ..                                                ...
# 73                                           0.135424
# 74                                           0.049729
# 75                                          -0.238768
# 76                                          -0.540407
# 77                                          -0.962589
#
#     beta-casomorphin (1-6)  \
# 0                -1.214645
# 1                 0.100907
# 2                -1.055573
# 3                -0.234557
# 4                 0.386673
# ..                     ...
# 73                0.145342
# 74               -0.884850
# 75               -0.200126
# 76               -0.178169
# 77                0.050639
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.893861
# 1                                           -0.983495
# 2                                           -0.144555
# 3                                            0.369370
# 4                                           -1.756575
# ..                                                ...
# 73                                           0.260952
# 74                                          -0.037688
# 75                                          -0.132882
# 76                                          -0.674045
# 77                                          -0.780553
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.133688            -0.355474             0.348388    -0.715142
# 1  -0.980514            -1.095321            -2.039662    -1.648273
# 2  -1.008790            -0.203740            -0.495743    -0.593609
# 3   0.427341            -0.300374            -0.764445     0.635713
# 4   1.433815            -2.084695            -0.606498    -1.141435
# ..       ...                  ...                  ...          ...
# 73  0.355314            -0.266206             0.034540     1.013079
# 74 -0.710158            -0.223834            -0.551617    -0.337982
# 75 -0.384627             0.033676             0.596106    -0.280565
# 76 -0.485018            -0.643004             0.083741    -0.345147
# 77 -0.873773            -0.831248            -1.558835    -1.424356
#
#     dynorphin A 1-8  test_proba  target
# 0          0.917747    0.834571     1.0
# 1          0.546335         NaN     NaN
# 2         -0.405604         NaN     NaN
# 3         -0.990412         NaN     NaN
# 4         -0.256840         NaN     NaN
# ..              ...         ...     ...
# 73        -0.031460         NaN     NaN
# 74        -0.527210         NaN     NaN
# 75         0.922484    0.968811     1.0
# 76         0.099728         NaN     NaN
# 77         0.710240    0.984877     1.0
#
# [78 rows x 199 columns]

# %%
df3_main = df3.iloc[:51, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.478482
# 43                           -0.189990
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.288254
# 43                                           0.054920
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876061
# 43                                   0.237653
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.878128
# 43                                           0.944974
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.057627
# 43                                           0.264553
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.684360
# 43                                           0.482423
#
#     Aminomalonic acid  \
# 0            0.203592
# 43          -0.156150
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.576189
# 43                                           0.633784
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513859
# 43                                           0.383879
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.455643
# 43                                           2.555461
#
#     ...  \
# 0   ...
# 43  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.374868
# 43                                           0.004338
#
#     beta-casomorphin (1-6)  \
# 0                -1.214645
# 43               -0.217821
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.893861
# 43                                           0.303267
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.133688            -0.355474             0.348388    -0.715142
# 43 -0.303717             0.579045             1.009045    -0.228516
#
#     dynorphin A 1-8  test_proba  target
# 0          0.917747    0.834571     1.0
# 43         1.585582    0.961472     1.0
#
# [2 rows x 199 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {0, 41, 42, 43}

# %%
df1_total = df1.loc[:51, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.478482
# 41                            0.197645
# 42                            0.967723
# 43                           -0.189990
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.288254
# 41                                          -0.037413
# 42                                           0.765943
# 43                                           0.054920
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876061
# 41                                  -0.322753
# 42                                   0.463555
# 43                                   0.237653
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.878128
# 41                                          -0.375304
# 42                                          -0.909956
# 43                                           0.944974
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.057627
# 41                                           1.927602
# 42                                           1.210658
# 43                                           0.264553
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.684360
# 41                                           0.108888
# 42                                           0.419596
# 43                                           0.482423
#
#     Aminomalonic acid  \
# 0            0.203592
# 41           0.360594
# 42           2.199793
# 43          -0.156150
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.576189
# 41                                           0.753382
# 42                                           2.187483
# 43                                           0.633784
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.513859
# 41                                           1.115268
# 42                                           3.059113
# 43                                           0.383879
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.455643
# 41                                          -0.198553
# 42                                          -0.998358
# 43                                           2.555461
#
#     ...  \
# 0   ...
# 41  ...
# 42  ...
# 43  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.374868
# 41                                           2.372916
# 42                                           1.807791
# 43                                           0.004338
#
#     beta-casomorphin (1-6)  \
# 0                -1.214645
# 41                0.707587
# 42               -0.974166
# 43               -0.217821
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.893861
# 41                                           1.534275
# 42                                           1.864532
# 43                                           0.303267
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.133688            -0.355474             0.348388    -0.715142
# 41 -0.421098            -0.339184             1.836702     1.262373
# 42  0.248684             0.761768             1.051869     1.496163
# 43 -0.303717             0.579045             1.009045    -0.228516
#
#     dynorphin A 1-8  test_proba  target
# 0          0.917747    0.719467     1.0
# 41        -0.397172    0.212400     1.0
# 42         1.432989    0.581867     1.0
# 43         1.585582    0.801867     1.0
#
# [4 rows x 199 columns]

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\master_list_metabolomics.txt', 'w') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\total_metabolomics.txt', 'w') as f:
    for i in l:
        f.write(f'{i}\n')
