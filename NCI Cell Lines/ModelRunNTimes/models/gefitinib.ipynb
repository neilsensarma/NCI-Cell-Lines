# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from warnings import filterwarnings
filterwarnings('ignore')

# %%
np.random.seed(42)

# %%
#read the input drug-metabolite data
data = pd.read_csv('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\data\\Gefitinib_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# 1                                           0.024981
#
#    LS tetrasaccharide d ; Sialyllacto-N-neotetraose c ; Sialyllacto-N-tetraose a ; Sialyllacto-N-tetraose b ; Sialyllacto-N-tetraose c  \
# 0                                           0.025836
# 1                                           0.013982
#
#    PIP2(16:0/18:0) ; PIP2(18:0/16:0)  \
# 0                           0.075427
# 1                           0.054200
#
#    TG(22:5(7Z,10Z,13Z,16Z,19Z)/20:5(5Z,8Z,11Z,14Z,17Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6] ; TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/20:4(5Z,8Z,11Z,14Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]  \
# 0                                           0.036502
# 1                                           0.029125
#
#    (2E)-Hexadecenoyl-CoA ; 2,7,10-hexadecatrienoylcoa ; 3,7,10-hexadecatrienoylcoa ; 3Z,7Z,10Z-hexadecatrienoyl-CoA ; 4,7,10-hexadecatrienoylcoa ; 4Z,7Z,10Z-hexadecatrienoyl-CoA ; 7,10,13-hexadecatrienoylcoa ; trans,cis,cis-2,7,10-hexadecatrienoyl-CoA  \
# 0                                           0.019935
# 1                                           0.010750
#
#    Lacto-N-difucohexaose ; Lacto-N-difucopentaose II  \
# 0                                           0.032820
# 1                                           0.015981
#
#    Galabiosylceramide (d18:1/26:1(17Z)) ; Lactosylceramide (d18:1/26:1(17Z))  \
# 0                                           0.039391
# 1                                           0.035154
#
#     cells  Cell names  Gefitinib
# 0   BT549   BR:BT-549   4.286667
# 1  HS578T  BR:HS 578T   5.173333
#
# [2 rows x 2185 columns]

# %%
#drop the target drug column
drug = data.pop('Gefitinib')

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\representative_metabolites.txt', 'r+') as f:
    rep_meta = f.read().strip().splitlines()

# %%
#select the input features, drop all metadata
X = data.select_dtypes('float64')
X = X[rep_meta]

#fill the NaNs with mean of each column
X.fillna(X.mean(), inplace=True)

# %%
import re

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X.columns.values]

# %%
#create empty list to store labels and take mean of the response values
#if response value is greater than mean then store 'NR' else store 'R'
#convert the list of labels into a Series

target, drug_mean = [], drug.mean()
for i in drug:
    if i > drug_mean:
        target.append('NR')
    else:
        target.append('R')
y = pd.Series(target)

# %%
X.shape, y.shape
# Out:
# ((52, 197), (52,))

# %%
#initialize the LabelEncoder instance
le = LabelEncoder()

#encode the labels into 0 and 1 for NR and R respectively
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 1    34
# 0    18
# dtype: int64

# %%
#initialize SMOTE instance
smote = SMOTE()

#use SMOTE to create synthetic samples to create a balanced set of data
X, y = smote.fit_resample(X, y)

# %%
#initialize StandardScaler for normalization of input features
scaler = StandardScaler()

#normalize the input dataframe
X = pd.DataFrame(data = scaler.fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    Isopropyl alcohol ; Propyl alcohol  \
# 0                            1.344593
# 1                           -0.377630
#
#    But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                          -0.299288
# 1                                           0.443797
#
#    2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                  -0.876632
# 1                                  -0.520636
#
#    D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                          -0.847398
# 1                                          -0.194524
#
#    5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                           0.165735
# 1                                           0.770214
#
#    Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                          -0.663114
# 1                                          -0.344514
#
#    Aminomalonic acid  \
# 0           0.178685
# 1          -1.177625
#
#    1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                          -0.463289
# 1                                          -1.090264
#
#    4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                          -0.403424
# 1                                          -1.094106
#
#    (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                           0.659334
# 1                                           1.169363
#
#    ...  Theaflavin-3-gallate  \
# 0  ...             -1.084864
# 1  ...             -0.712591
#
#    PC(14:0/18:4(6Z,9Z,12Z,15Z)) ; PC(14:1(9Z)/18:3(6Z,9Z,12Z)) ; PC(14:1(9Z)/18:3(9Z,12Z,15Z)) ; PC(18:3(6Z,9Z,12Z)/14:1(9Z)) ; PC(18:3(9Z,12Z,15Z)/14:1(9Z)) ; PC(18:4(6Z,9Z,12Z,15Z)/14:0) ; PE(15:0/20:4(5Z,8Z,11Z,14Z)) ; PE(15:0/20:4(8Z,11Z,14Z,17Z)) ; PE(20:4(5Z,8Z,11Z,14Z)/15:0) ; PE(20:4(8Z,11Z,14Z,17Z)/15:0)  \
# 0                                          -1.113913
# 1                                          -0.333573
#
#    Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                          -0.342574
# 1                                          -1.126063
#
#    beta-casomorphin (1-6)  \
# 0               -1.109744
# 1               -0.026052
#
#    TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                           0.959689
# 1                                          -0.894709
#
#      Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0 -1.167586            -0.402374             0.439984    -0.658141
# 1 -1.026190            -1.095112            -2.024400    -1.577550
#
#    dynorphin A 1-8
# 0         1.025558
# 1         0.663479
#
# [2 rows x 197 columns]

# %%
X.shape, y.shape
# Out:
# ((68, 197), (68,))

# %%
y.value_counts()
# Out:
# 1    34
# 0    34
# dtype: int64

# %% [raw]
# corr_matrix = X.corr().abs()
#
# # Create a mask for selecting highly correlated features
# mask = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#
# # Find the columns to drop based on the mask
# to_drop = [col for col in mask.columns if any(mask[col] > 0.8)]
#
# # Drop the highly correlated features
# X = X.drop(to_drop, axis=1)

# %%
X.shape
# Out:
# (68, 197)

# %%
#find the indices of the input dataset
indices = X.index.values

#split the dataset into train and test datasets
X_train, X_test, train_index, test_index = train_test_split(X, indices, test_size = 0.20, random_state = 43)
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction = []

#define a list to store accuracy, precision and recall 
acc_score, rec_score, pre_score = [], [], []

#define a list to store the number of features selected in each iteration
num_features = []

#define the model
model = RandomForestClassifier(n_estimators = 150, class_weight = 'balanced')

#run the feature selection and model training and evaluation N times
for i in range(N): 
    #define base estimator for feature selection and fit the training data to it
    base_estimator = model
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SelectFromModel to select features based on base estimator provided and use the mean of the feature importances
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train and test data using SFM
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X.columns[sfm.get_support(1)])
    
    print(f'Number of features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features.append(len(X_train_new.columns))

    #define the machine learning model and train it
    model.fit(X_train_new, y_train)
    
    #make predictions and other metrics
    y_pred = model.predict(X_test_new)
    acc_score.append(accuracy_score(y_test, y_pred))
    rec_score.append(recall_score(y_test, y_pred, pos_label=1))
    pre_score.append(precision_score(y_test, y_pred, pos_label=1))
    
    #store the probabilites of each run
    prediction.append(model.predict_proba(X_test_new))

    
acc_score = np.array(acc_score)
rec_score = np.array(rec_score)
pre_score = np.array(pre_score)
print(f'Accuracy score: {np.mean(acc_score)}, Standard deviation: {np.std(acc_score)}')
print(f'Recall score: {np.mean(rec_score)}, Standard deviation: {np.std(rec_score)}')
print(f'Precision score: {np.mean(pre_score)}, Standard deviation: {np.std(pre_score)}')

#indice = np.unique(np.array(indice))
prediction = np.array(prediction)
prediction = np.mean(prediction, axis=0)[:, 1]
# Out:
# Number of features selected during iteration 0: 64
# Number of features selected during iteration 1: 69
# Number of features selected during iteration 2: 74
# Number of features selected during iteration 3: 64
# Number of features selected during iteration 4: 71
# Number of features selected during iteration 5: 69
# Number of features selected during iteration 6: 66
# Number of features selected during iteration 7: 64
# Number of features selected during iteration 8: 70
# Number of features selected during iteration 9: 65
# Number of features selected during iteration 10: 77
# Number of features selected during iteration 11: 69
# Number of features selected during iteration 12: 71
# Number of features selected during iteration 13: 62
# Number of features selected during iteration 14: 60
# Number of features selected during iteration 15: 65
# Number of features selected during iteration 16: 62
# Number of features selected during iteration 17: 76
# Number of features selected during iteration 18: 63
# Number of features selected during iteration 19: 77
# Number of features selected during iteration 20: 67
# Number of features selected during iteration 21: 68
# Number of features selected during iteration 22: 65
# Number of features selected during iteration 23: 71
# Number of features selected during iteration 24: 70
# Number of features selected during iteration 25: 80
# Number of features selected during iteration 26: 69
# Number of features selected during iteration 27: 67
# Number of features selected during iteration 28: 77
# Number of features selected during iteration 29: 68
# Number of features selected during iteration 30: 67
# Number of features selected during iteration 31: 65
# Number of features selected during iteration 32: 66
# Number of features selected during iteration 33: 74
# Number of features selected during iteration 34: 58
# Number of features selected during iteration 35: 72
# Number of features selected during iteration 36: 67
# Number of features selected during iteration 37: 75
# Number of features selected during iteration 38: 79
# Number of features selected during iteration 39: 61
# Number of features selected during iteration 40: 73
# Number of features selected during iteration 41: 68
# Number of features selected during iteration 42: 61
# Number of features selected during iteration 43: 61
# Number of features selected during iteration 44: 70
# Number of features selected during iteration 45: 73
# Number of features selected during iteration 46: 73
# Number of features selected during iteration 47: 72
# Number of features selected during iteration 48: 74
# Number of features selected during iteration 49: 67
# Accuracy score: 0.8628571428571428, Standard deviation: 0.03736199094463436
# Recall score: 0.98, Standard deviation: 0.06782329983125268
# Precision score: 0.6845238095238093, Standard deviation: 0.060411007241382514

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders', alpha = 0.5, bins = 50)
plt.hist(prediction[y_test==1], label='Responders', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_rf_test = X_test.copy()
df_rf_test.loc[test_index, 'test_proba'] = prediction
df_rf_test.loc[test_index, 'target'] = y
df1 = pd.concat([X_train, df_rf_test], sort=False).sort_index()

# %%
df1
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.344593
# 1                            -0.377630
# 2                             0.832994
# 3                            -1.521605
# 4                            -1.545817
# ..                                 ...
# 63                            0.632407
# 64                            0.994657
# 65                           -0.810906
# 66                            1.579461
# 67                           -1.221487
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.299288
# 1                                            0.443797
# 2                                            0.773485
# 3                                           -1.566972
# 4                                           -0.171486
# ..                                                ...
# 63                                           0.680986
# 64                                           1.471709
# 65                                           0.595145
# 66                                           1.163994
# 67                                          -0.609419
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876632
# 1                                   -0.520636
# 2                                   -1.174961
# 3                                    0.830591
# 4                                   -0.533978
# ..                                        ...
# 63                                  -1.049099
# 64                                   0.255543
# 65                                   1.922029
# 66                                  -1.133972
# 67                                   0.117458
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.847398
# 1                                           -0.194524
# 2                                           -0.472789
# 3                                            0.850024
# 4                                            0.311472
# ..                                                ...
# 63                                          -1.221499
# 64                                           0.078017
# 65                                           0.081665
# 66                                          -1.068224
# 67                                           0.505940
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.165735
# 1                                            0.770214
# 2                                            0.708844
# 3                                            1.364304
# 4                                           -1.460306
# ..                                                ...
# 63                                          -0.110192
# 64                                           0.187569
# 65                                           0.605249
# 66                                           0.309543
# 67                                          -0.812058
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.663114
# 1                                           -0.344514
# 2                                           -0.791336
# 3                                           -0.545631
# 4                                           -0.786556
# ..                                                ...
# 63                                          -0.625046
# 64                                           0.885777
# 65                                          -0.499514
# 66                                          -0.555848
# 67                                          -0.175354
#
#     Aminomalonic acid  \
# 0            0.178685
# 1           -1.177625
# 2            0.724456
# 3            0.273726
# 4           -0.850767
# ..                ...
# 63          -1.214705
# 64           0.901623
# 65          -1.112408
# 66          -0.772194
# 67          -0.457819
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.463289
# 1                                           -1.090264
# 2                                            0.733719
# 3                                            1.786021
# 4                                           -0.172512
# ..                                                ...
# 63                                          -0.667476
# 64                                          -0.170404
# 65                                           0.148043
# 66                                          -0.110766
# 67                                          -0.984056
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.403424
# 1                                           -1.094106
# 2                                            0.705770
# 3                                            1.890414
# 4                                           -0.519529
# ..                                                ...
# 63                                          -0.457100
# 64                                          -0.342161
# 65                                           0.017152
# 66                                           0.089993
# 67                                          -0.131503
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.659334
# 1                                            1.169363
# 2                                           -0.585724
# 3                                           -0.690961
# 4                                           -0.819963
# ..                                                ...
# 63                                           1.361808
# 64                                           1.033406
# 65                                          -0.590055
# 66                                           0.824970
# 67                                          -1.260104
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 63  ...
# 64  ...
# 65  ...
# 66  ...
# 67  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.342574
# 1                                           -1.126063
# 2                                            0.128254
# 3                                           -0.054994
# 4                                           -1.220567
# ..                                                ...
# 63                                          -0.758798
# 64                                          -0.199912
# 65                                           0.525720
# 66                                          -0.766678
# 67                                          -1.330646
#
#     beta-casomorphin (1-6)  \
# 0                -1.109744
# 1                -0.026052
# 2                -0.978708
# 3                -0.302393
# 4                 0.209349
# ..                     ...
# 63               -0.369564
# 64               -0.481723
# 65               -0.014860
# 66               -0.227558
# 67                0.412804
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.959689
# 1                                           -0.894709
# 2                                           -0.066028
# 3                                            0.441612
# 4                                           -1.658335
# ..                                                ...
# 63                                          -0.555915
# 64                                          -0.019589
# 65                                          -0.940381
# 66                                          -0.323446
# 67                                          -0.693416
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.167586            -0.402374             0.439984    -0.658141
# 1  -1.026190            -1.095112            -2.024400    -1.577550
# 2  -1.052292            -0.260302            -0.431129    -0.538396
# 3   0.273413            -0.350783            -0.708421     0.672848
# 4   1.202499            -2.021486            -0.545425    -1.078166
# ..       ...                  ...                  ...          ...
# 63 -1.646426            -1.470625            -1.132975    -0.676892
# 64 -0.803172             0.238827            -0.192633     0.016049
# 65  0.161079            -0.040150             1.203536     0.893207
# 66 -2.034704            -1.708078            -1.020483    -0.488281
# 67  0.123078            -1.159489            -1.790353    -1.470068
#
#     dynorphin A 1-8  test_proba  target
# 0          1.025558         NaN     NaN
# 1          0.663479         NaN     NaN
# 2         -0.264535         NaN     NaN
# 3         -0.834646         NaN     NaN
# 4         -0.119510         NaN     NaN
# ..              ...         ...     ...
# 63        -0.944243         NaN     NaN
# 64         0.507816         NaN     NaN
# 65         1.312321         NaN     NaN
# 66        -0.416123      0.1624     0.0
# 67         0.944143         NaN     NaN
#
# [68 rows x 199 columns]

# %%
df1_main = df1.iloc[:51, ]
x = max(prediction[y_test == 0])
df1_main = df1_main.loc[(df1_main['test_proba'] > x)]
df1_main.shape
# Out:
# (3, 199)

# %%
df1_main.index.values #0 40 41 42
# Out:
# array([ 5,  6, 13], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction2 = []

#define a list to store the number of features selected at each iteration
num_features2 = []

#define the model
model2 = SVC(C=1, gamma=1, probability=True)

#define a list to store accuracy, precision and recall 
acc_score2, rec_score2, pre_score2 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define the base estimator for feature selection
    base_estimator = RandomForestClassifier(n_estimators=150, class_weight='balanced')
    base_estimator.fit(X_train, y_train)
    
    #compute the importances of each feature
    importances = base_estimator.feature_importances_
    
    #use SelectFromModel and mean importances to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform the train test data using important features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_train.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features2.append(len(X_train_new.columns))

    #define the SVM model and train it
    model2.fit(X_train_new, y_train)
    
    #comput predictions
    y_pred2 = model2.predict(X_test_new)
    acc_score2.append(accuracy_score(y_test, y_pred2))
    rec_score2.append(recall_score(y_test, y_pred2, pos_label=1))
    pre_score2.append(precision_score(y_test, y_pred2, pos_label=1))
    prediction2.append(model2.predict_proba(X_test_new))


acc_score2 = np.array(acc_score2)
rec_score2 = np.array(rec_score2)
pre_score2 = np.array(pre_score2)
print(f'Accuracy score: {np.mean(acc_score2)}, Standard deviation: {np.std(acc_score2)}')
print(f'Recall score: {np.mean(rec_score2)}, Standard deviation: {np.std(rec_score2)}')
print(f'Precision score: {np.mean(pre_score2)}, Standard deviation: {np.std(pre_score2)}')


prediction2 = np.array(prediction2)
prediction2 = np.mean(prediction2, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 68
# Features selected during iteration 1: 73
# Features selected during iteration 2: 74
# Features selected during iteration 3: 62
# Features selected during iteration 4: 69
# Features selected during iteration 5: 65
# Features selected during iteration 6: 67
# Features selected during iteration 7: 70
# Features selected during iteration 8: 73
# Features selected during iteration 9: 62
# Features selected during iteration 10: 73
# Features selected during iteration 11: 70
# Features selected during iteration 12: 71
# Features selected during iteration 13: 67
# Features selected during iteration 14: 69
# Features selected during iteration 15: 70
# Features selected during iteration 16: 70
# Features selected during iteration 17: 72
# Features selected during iteration 18: 65
# Features selected during iteration 19: 74
# Features selected during iteration 20: 74
# Features selected during iteration 21: 74
# Features selected during iteration 22: 69
# Features selected during iteration 23: 75
# Features selected during iteration 24: 72
# Features selected during iteration 25: 72
# Features selected during iteration 26: 73
# Features selected during iteration 27: 68
# Features selected during iteration 28: 74
# Features selected during iteration 29: 67
# Features selected during iteration 30: 69
# Features selected during iteration 31: 70
# Features selected during iteration 32: 68
# Features selected during iteration 33: 79
# Features selected during iteration 34: 60
# Features selected during iteration 35: 68
# Features selected during iteration 36: 68
# Features selected during iteration 37: 67
# Features selected during iteration 38: 61
# Features selected during iteration 39: 72
# Features selected during iteration 40: 68
# Features selected during iteration 41: 70
# Features selected during iteration 42: 66
# Features selected during iteration 43: 73
# Features selected during iteration 44: 68
# Features selected during iteration 45: 76
# Features selected during iteration 46: 64
# Features selected during iteration 47: 73
# Features selected during iteration 48: 67
# Features selected during iteration 49: 67
# Accuracy score: 0.2857142857142857, Standard deviation: 0.0
# Recall score: 1.0, Standard deviation: 0.0
# Precision score: 0.2857142857142857, Standard deviation: 0.0

# %%
plt.figure(figsize=(5,5))
plt.hist(prediction2[y_test==0], label='Negatives', alpha = 0.5, bins = 50)
plt.hist(prediction2[y_test==1], label='Positives', alpha=0.5, bins = 50, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_svm_test = X_test.copy()
df_svm_test.loc[test_index, 'test_proba'] = prediction2
df_svm_test.loc[test_index, 'target'] = y_test
df2 = pd.concat([X_train, df_svm_test], sort=False).sort_index()

# %%
df2_main = df2.iloc[:52, ]
df2_main = df2_main.loc[(df2_main['test_proba'] > max(prediction2[y_test == 0]))]
df2_main
# Out:
# Empty DataFrame
# Columns: [Isopropyl alcohol ; Propyl alcohol, But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one, 2-Aminoacrylic acid ; 2-aminoacrylic acid, D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal, 5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine, Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone, Aminomalonic acid, 1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid, 4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid, (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid, Glycyl-glycine ; HMDB12265 ; L-Asparagine ; L-asparagine ; N-carbamoyl-beta-alaninate ; Ureidopropionic acid, (5R)-5-Hydroxyhexanoic acid ; (R)-2-hydroxy-4-methylpentanoate ; (R)-3-Hydroxyhexanoic acid ; 2-Ethyl-2-Hydroxybutyric acid ; 2-Hydroxy-3-methylpentanoic acid ; 2-Hydroxycaproic acid ; 5-Hydroxyhexanoic acid ; D-Leucic acid ; Hydroxyisocaproic acid ; Leucinic acid, (R)-2,3-Dihydroxy-isovalerate ; 1-Deoxy-D-xylulose ; 2,3-Dihydroxyvaleric acid ; 2-deoxy-D-ribose ; Deoxyribose, 2-Aminobenzoic acid ; 3-Pyridylacetic acid ; anthranilate ; m-Aminobenzoic acid ; p-Aminobenzoic acid, 3-Ureidoisobutyrate ; Alanylglycine ; D-Glutamine ; Glycylsarcosine ; L-Glutamine ; L-glutamine ; Ureidoisobutyric acid, D-Glutamic acid ; HMDB02393 ; HMDB02931 ; L-4-Hydroxyglutamate semialdehyde ; L-4-hydroxyglutamic semialdehyde ; L-Glutamic acid ; L-glutamate(1-) ; O-Acetylserine, 3-Hydroxyglutaric acid ; Citramalic acid ; D-2-Hydroxyglutaric acid ; D-Xylono-1,5-lactone ; L-2-Hydroxyglutaric acid ; Ribonolactone, (R) 2,3-Dihydroxy-3-methylvalerate ; (R)-mevalonate ; Mevalonic acid, 2-Phenylglycine ; Acetaminophen ; Dopamine quinone ; leukoaminochrome, 2,5-dihydroxybenzoate ; 2-Pyrocatechuic acid ; Gentisic acid ; Protocatechuic acid, 2,4-Dihydroxy-nitrophenol ; 2-hydroxy-4-nitrophenolate ; 4-Nitrocatechol, 1,2-Dihydroxy-3-keto-5-methylthiopentene, 3-Methylsulfinylpropyl isothiocyanate, 3-Methyldioxyindole ; 4-(3-Pyridyl)-3-butenoic acid, 1-Methylguanine ; 3-Methylguanine ; 7-Methylguanine ; HMDB06040, Quinolinic acid ; quinolinate(2-), N-Trimethyl-2-aminoethylphosphonate, 3,4-Dihydroxybenzeneacetic acid ; 3,4-Dihydroxymandelaldehyde ; 3-Hydroxymandelic acid ; 5-Methoxysalicylic acid ; Homogentisic acid ; Vanillic acid ; p-Hydroxymandelic acid, 5-Hydroxydopamine ; 6-Hydroxydopamine ; HMDB00216 ; Norepinephrine ; Pyridoxine, D-Glyceraldehyde 3-phosphate ; Dihydroxyacetone phosphate ; Glyceraldehyde 3-phosphate, 2-Amino-3-oxoadipate ; HMDB00812 ; HMDB03470 ; N-acetyl-L-aspartate(2-), O-Ureidohomoserine, 4-Oxo-4-(3-pyridyl)-butanamide ; BOX A ; BOX B ; PHderiv_Pyruvate; Pyruvic acid; 2-Oxopropanoate; 2-Oxopropanoic acid; Pyroracemic acid, Fructosamine ; Glucosamine, 7-Aminomethyl-7-carbaguanine, HMDB03269 ; PHderiv_Oxalate; Oxalic acid; Ethanedioic acid, Epinephrine ; HMDB00819 ; Methylnoradrenaline, 5'-Hydroxycotinine ; Cotinine N-oxide ; HMDB01324 ; Hydroxycotinine ; Oxoamide ; PHderiv_2-Oxobutanoate; 2-Ketobutyric acid; 2-Oxobutyric acid; 2-Oxobutyrate; 2-Oxobutanoic acid; alpha-Ketobutyric acid; alpha-Ketobutyrate, 2-Methylhippuric acid ; Methylhippuric acid ; Phenylacetylglycine ; o-methylhippurate, (-)-Salsoline ; (R)-1,2-dimethyl-5,6-dihydroxy-tetrahydroisoquinoline ; N-methylsalsolinol, Isoferulic acid ; Monoethyl phthalate ; trans-Ferulic acid, Ecgonine methyl ester ; ecgoninium methyl ester(1+), Spermine ; spermine(4+), Cystathionine ketimine, Xanthurenic acid ; oxoxanthurenate, (2S,3R)-3-hydroxybutane-1,2,3-tricarboxylate ; 2-Methylcitric acid ; 2-methylcitrate(3-) ; Homocitric acid ; Methylisocitric acid, Lipoic acid ; lipoate, 4-(Methylnitrosamino)-1-(3-pyridyl)-1-buta ...
# Index: []
#
# [0 rows x 199 columns]

# %%
df2_main.index.values #40 41 42
# Out:
# array([], dtype=int64)

# %%
#define the number of iterations for model training and testing
N = 50

#define a list to store the probabilities
prediction3 = []

#define a list to store the number of features selected in each iteration
num_features3 = []

#define the model
model3 = XGBClassifier()

#define a list to store accuracy, precision and recall 
acc_score3, rec_score3, pre_score3 = [], [], []

#run a for loop N times and store the prediction probabilities of each run
for i in range(N):
    #define base estimator to compute feature importances
    base_estimator = XGBClassifier()
    base_estimator.fit(X_train, y_train)
    
    #compute feature importances
    importances = base_estimator.feature_importances_
    
    #define SFM model to select important features
    sfm = SelectFromModel(base_estimator, threshold = importances.mean())
    sfm.fit(X_train, y_train)
    
    #transform train and test sets using best features
    X_train_new = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(1)])
    X_test_new = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(1)])
    
    print(f'Features selected during iteration {i}: {len(X_train_new.columns)}')
    num_features3.append(len(X_train_new.columns))

    #define XGBoost model and train it
    model3.fit(X_train_new, y_train)
    
    #compute predictions
    y_pred3 = model3.predict(X_test_new)
    acc_score3.append(accuracy_score(y_test, y_pred3))
    rec_score3.append(recall_score(y_test, y_pred3, pos_label=1))
    pre_score3.append(precision_score(y_test, y_pred3, pos_label=1))
    prediction3.append(model3.predict_proba(X_test_new))


acc_score3 = np.array(acc_score3)
rec_score3 = np.array(rec_score3)
pre_score3 = np.array(pre_score3)
print(f'Accuracy score: {np.mean(acc_score3)}, Standard deviation: {np.std(acc_score3)}')
print(f'Recall score: {np.mean(rec_score3)}, Standard deviation: {np.std(rec_score3)}')
print(f'Precision score: {np.mean(pre_score3)}, Standard deviation: {np.std(pre_score3)}')


prediction3 = np.array(prediction3)
prediction3 = np.mean(prediction3, axis=0)[:, 1]
# Out:
# Features selected during iteration 0: 26
# Features selected during iteration 1: 26
# Features selected during iteration 2: 26
# Features selected during iteration 3: 26
# Features selected during iteration 4: 26
# Features selected during iteration 5: 26
# Features selected during iteration 6: 26
# Features selected during iteration 7: 26
# Features selected during iteration 8: 26
# Features selected during iteration 9: 26
# Features selected during iteration 10: 26
# Features selected during iteration 11: 26
# Features selected during iteration 12: 26
# Features selected during iteration 13: 26
# Features selected during iteration 14: 26
# Features selected during iteration 15: 26
# Features selected during iteration 16: 26
# Features selected during iteration 17: 26
# Features selected during iteration 18: 26
# Features selected during iteration 19: 26
# Features selected during iteration 20: 26
# Features selected during iteration 21: 26
# Features selected during iteration 22: 26
# Features selected during iteration 23: 26
# Features selected during iteration 24: 26
# Features selected during iteration 25: 26
# Features selected during iteration 26: 26
# Features selected during iteration 27: 26
# Features selected during iteration 28: 26
# Features selected during iteration 29: 26
# Features selected during iteration 30: 26
# Features selected during iteration 31: 26
# Features selected during iteration 32: 26
# Features selected during iteration 33: 26
# Features selected during iteration 34: 26
# Features selected during iteration 35: 26
# Features selected during iteration 36: 26
# Features selected during iteration 37: 26
# Features selected during iteration 38: 26
# Features selected during iteration 39: 26
# Features selected during iteration 40: 26
# Features selected during iteration 41: 26
# Features selected during iteration 42: 26
# Features selected during iteration 43: 26
# Features selected during iteration 44: 26
# Features selected during iteration 45: 26
# Features selected during iteration 46: 26
# Features selected during iteration 47: 26
# Features selected during iteration 48: 26
# Features selected during iteration 49: 26
# Accuracy score: 0.7142857142857143, Standard deviation: 0.0
# Recall score: 0.75, Standard deviation: 0.0
# Precision score: 0.5, Standard deviation: 0.0

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders', bins = 50, alpha = 0.5)
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.5, color='r', bins = 50)
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
df_xg = X_test.copy()
df_xg.loc[test_index, 'test_proba'] = prediction3
df_xg.loc[test_index, 'target'] = y_test
df3 = pd.concat([X_train, df_xg], sort=False).sort_index()
df3
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 0                             1.344593
# 1                            -0.377630
# 2                             0.832994
# 3                            -1.521605
# 4                            -1.545817
# ..                                 ...
# 63                            0.632407
# 64                            0.994657
# 65                           -0.810906
# 66                            1.579461
# 67                           -1.221487
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 0                                           -0.299288
# 1                                            0.443797
# 2                                            0.773485
# 3                                           -1.566972
# 4                                           -0.171486
# ..                                                ...
# 63                                           0.680986
# 64                                           1.471709
# 65                                           0.595145
# 66                                           1.163994
# 67                                          -0.609419
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 0                                   -0.876632
# 1                                   -0.520636
# 2                                   -1.174961
# 3                                    0.830591
# 4                                   -0.533978
# ..                                        ...
# 63                                  -1.049099
# 64                                   0.255543
# 65                                   1.922029
# 66                                  -1.133972
# 67                                   0.117458
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 0                                           -0.847398
# 1                                           -0.194524
# 2                                           -0.472789
# 3                                            0.850024
# 4                                            0.311472
# ..                                                ...
# 63                                          -1.221499
# 64                                           0.078017
# 65                                           0.081665
# 66                                          -1.068224
# 67                                           0.505940
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 0                                            0.165735
# 1                                            0.770214
# 2                                            0.708844
# 3                                            1.364304
# 4                                           -1.460306
# ..                                                ...
# 63                                          -0.110192
# 64                                           0.187569
# 65                                           0.605249
# 66                                           0.309543
# 67                                          -0.812058
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 0                                           -0.663114
# 1                                           -0.344514
# 2                                           -0.791336
# 3                                           -0.545631
# 4                                           -0.786556
# ..                                                ...
# 63                                          -0.625046
# 64                                           0.885777
# 65                                          -0.499514
# 66                                          -0.555848
# 67                                          -0.175354
#
#     Aminomalonic acid  \
# 0            0.178685
# 1           -1.177625
# 2            0.724456
# 3            0.273726
# 4           -0.850767
# ..                ...
# 63          -1.214705
# 64           0.901623
# 65          -1.112408
# 66          -0.772194
# 67          -0.457819
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 0                                           -0.463289
# 1                                           -1.090264
# 2                                            0.733719
# 3                                            1.786021
# 4                                           -0.172512
# ..                                                ...
# 63                                          -0.667476
# 64                                          -0.170404
# 65                                           0.148043
# 66                                          -0.110766
# 67                                          -0.984056
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 0                                           -0.403424
# 1                                           -1.094106
# 2                                            0.705770
# 3                                            1.890414
# 4                                           -0.519529
# ..                                                ...
# 63                                          -0.457100
# 64                                          -0.342161
# 65                                           0.017152
# 66                                           0.089993
# 67                                          -0.131503
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 0                                            0.659334
# 1                                            1.169363
# 2                                           -0.585724
# 3                                           -0.690961
# 4                                           -0.819963
# ..                                                ...
# 63                                           1.361808
# 64                                           1.033406
# 65                                          -0.590055
# 66                                           0.824970
# 67                                          -1.260104
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 63  ...
# 64  ...
# 65  ...
# 66  ...
# 67  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 0                                           -0.342574
# 1                                           -1.126063
# 2                                            0.128254
# 3                                           -0.054994
# 4                                           -1.220567
# ..                                                ...
# 63                                          -0.758798
# 64                                          -0.199912
# 65                                           0.525720
# 66                                          -0.766678
# 67                                          -1.330646
#
#     beta-casomorphin (1-6)  \
# 0                -1.109744
# 1                -0.026052
# 2                -0.978708
# 3                -0.302393
# 4                 0.209349
# ..                     ...
# 63               -0.369564
# 64               -0.481723
# 65               -0.014860
# 66               -0.227558
# 67                0.412804
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 0                                            0.959689
# 1                                           -0.894709
# 2                                           -0.066028
# 3                                            0.441612
# 4                                           -1.658335
# ..                                                ...
# 63                                          -0.555915
# 64                                          -0.019589
# 65                                          -0.940381
# 66                                          -0.323446
# 67                                          -0.693416
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 0  -1.167586            -0.402374             0.439984    -0.658141
# 1  -1.026190            -1.095112            -2.024400    -1.577550
# 2  -1.052292            -0.260302            -0.431129    -0.538396
# 3   0.273413            -0.350783            -0.708421     0.672848
# 4   1.202499            -2.021486            -0.545425    -1.078166
# ..       ...                  ...                  ...          ...
# 63 -1.646426            -1.470625            -1.132975    -0.676892
# 64 -0.803172             0.238827            -0.192633     0.016049
# 65  0.161079            -0.040150             1.203536     0.893207
# 66 -2.034704            -1.708078            -1.020483    -0.488281
# 67  0.123078            -1.159489            -1.790353    -1.470068
#
#     dynorphin A 1-8  test_proba  target
# 0          1.025558         NaN     NaN
# 1          0.663479         NaN     NaN
# 2         -0.264535         NaN     NaN
# 3         -0.834646         NaN     NaN
# 4         -0.119510         NaN     NaN
# ..              ...         ...     ...
# 63        -0.944243         NaN     NaN
# 64         0.507816         NaN     NaN
# 65         1.312321         NaN     NaN
# 66        -0.416123    0.073666     0.0
# 67         0.944143         NaN     NaN
#
# [68 rows x 199 columns]

# %%
df3_main = df3.iloc[:51, ]
df3_main = df3_main.loc[(df3_main['test_proba'] > max(prediction3[y_test == 0]))]
df3_main
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 5                            -0.221532
# 6                            -0.125941
# 13                           -0.513646
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 5                                           -0.171486
# 6                                           -1.772843
# 13                                           0.153624
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 5                                   -0.709537
# 6                                   -0.314687
# 13                                  -0.601609
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 5                                           -0.182290
# 6                                            0.457952
# 13                                           2.655150
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 5                                            0.023967
# 6                                           -0.551493
# 13                                          -0.025414
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 5                                           -0.424092
# 6                                           -0.161757
# 13                                          -0.418476
#
#     Aminomalonic acid  \
# 5            1.169383
# 6           -1.273674
# 13          -1.029513
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 5                                            0.846000
# 6                                           -0.679348
# 13                                          -0.007130
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 5                                            0.513314
# 6                                           -0.800154
# 13                                          -0.201497
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 5                                            1.599910
# 6                                            0.081808
# 13                                           0.108335
#
#     ...  \
# 5   ...
# 6   ...
# 13  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 5                                           -0.364071
# 6                                           -0.545804
# 13                                           0.840617
#
#     beta-casomorphin (1-6)  \
# 5                 0.427286
# 6                -0.868445
# 13                0.857635
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 5                                            0.149960
# 6                                           -0.327216
# 13                                           0.264922
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 5   0.749105            -1.387791             1.203665     0.711524
# 6   0.274048             0.164879            -0.734077    -0.365024
# 13 -0.018324             1.384695             0.129540     0.489283
#
#     dynorphin A 1-8  test_proba  target
# 5         -1.088241    0.932857     1.0
# 6          1.646963    0.945835     1.0
# 13        -0.926499    0.967767     1.0
#
# [3 rows x 199 columns]

# %%
common_list = []
common_list.extend(list(df1_main.index.values))
common_list.extend(list(df2_main.index.values))
common_list.extend(list(df3_main.index.values))

# %%
cl = set(common_list)
cl
# Out:
# {5, 6, 13}

# %%
df1_total = df1.loc[:51, ]
df1_total = df1_total.loc[(df1_total['target'] == 1.0)]
df1_total
# Out:
#     Isopropyl alcohol ; Propyl alcohol  \
# 5                            -0.221532
# 6                            -0.125941
# 13                           -0.513646
# 18                           -0.854370
#
#     But-2-enoic acid ; Diacetyl ; Gamma-Butyrolactone ; Oxolan-3-one  \
# 5                                           -0.171486
# 6                                           -1.772843
# 13                                           0.153624
# 18                                          -1.795987
#
#     2-Aminoacrylic acid ; 2-aminoacrylic acid  \
# 5                                   -0.709537
# 6                                   -0.314687
# 13                                  -0.601609
# 18                                   0.006757
#
#     D-Proline ; D-proline ; L-Proline ; L-proline ; acetamidopropanal  \
# 5                                           -0.182290
# 6                                            0.457952
# 13                                           2.655150
# 18                                          -0.281806
#
#     5-Aminopentanoic acid ; Betaine ; HMDB02141 ; L-Valine ; L-valine ; Vaporole ; glycine betaine  \
# 5                                            0.023967
# 6                                           -0.551493
# 13                                          -0.025414
# 18                                          -1.579736
#
#     Erythrono-1,4-lactone ; Methylmalonate ; Methylmalonic acid ; Succinate ; Succinic acid ; Threonolactone  \
# 5                                           -0.424092
# 6                                           -0.161757
# 13                                          -0.418476
# 18                                          -0.650155
#
#     Aminomalonic acid  \
# 5            1.169383
# 6           -1.273674
# 13          -1.029513
# 18           0.117642
#
#     1-Pyrroline-4-hydroxy-2-carboxylate ; 5-oxoprolinate ; HMDB01843 ; L-1-Pyrroline-3-hydroxy-5-carboxylate ; Pyroglutamic acid ; Pyrrolidonecarboxylic acid ; Pyrroline hydroxycarboxylic acid  \
# 5                                            0.846000
# 6                                           -0.679348
# 13                                          -0.007130
# 18                                          -0.962422
#
#     4-acetamidobutanal ; D-Pipecolic acid ; HMDB04226 ; L-Pipecolic acid ; L-pipecolic acid ; Pipecolic acid  \
# 5                                            0.513314
# 6                                           -0.800154
# 13                                          -0.201497
# 18                                          -0.987967
#
#     (S)-2-Acetolactate ; 2-Acetolactate ; Dimethylmalonic acid ; Ethylmalonic acid ; Glutaric acid ; Methylsuccinic acid ; Monoethyl malonic acid  \
# 5                                            1.599910
# 6                                            0.081808
# 13                                           0.108335
# 18                                          -0.997399
#
#     ...  \
# 5   ...
# 6   ...
# 13  ...
# 18  ...
#
#     Hexacarboxylporphyrin I ; Hexacarboxylporphyrin III ; Porphinehexacarboxylic acid  \
# 5                                           -0.364071
# 6                                           -0.545804
# 13                                           0.840617
# 18                                          -0.433452
#
#     beta-casomorphin (1-6)  \
# 5                 0.427286
# 6                -0.868445
# 13                0.857635
# 18                0.037550
#
#     TG(16:0/14:0/18:2(9Z,12Z))_iso6_ ; TG(16:0/16:1(9Z)/16:1(9Z))_iso3_ ; TG(16:1(9Z)/14:0/18:1(11Z))_iso6_ ; TG(16:1(9Z)/14:0/18:1(9Z))_iso6_  \
# 5                                            0.149960
# 6                                           -0.327216
# 13                                           0.264922
# 18                                           0.138416
#
#       Heme O  neuromedin B (4-10)  Hydroxymethylbilane  Sennoside B  \
# 5   0.749105            -1.387791             1.203665     0.711524
# 6   0.274048             0.164879            -0.734077    -0.365024
# 13 -0.018324             1.384695             0.129540     0.489283
# 18  1.036156            -0.106044            -0.270481    -0.848266
#
#     dynorphin A 1-8  test_proba  target
# 5         -1.088241    0.654800     1.0
# 6          1.646963    0.635333     1.0
# 13        -0.926499    0.792000     1.0
# 18         1.215810    0.572400     1.0
#
# [4 rows x 199 columns]

# %%
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\master_list_metabolomics.txt', 'a+') as f:
    for i in cl:
        f.write(f'{i}\n')

# %%
l = []
l.extend(df1_total.index.values)
with open('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\ModelRunNTimes\\outputs\\total_metabolomics.txt', 'a+') as f:
    for i in l:
        f.write(f'{i}\n')
