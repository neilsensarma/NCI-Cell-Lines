# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\nilav\\Desktop\\NCI Cell Lines\\NCI Cell Lines\\data\\Cactinomycin_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# ...

# %%
lineages = list(data['Cell Line'])
lineages
# Out:
# ['Breast_BT549',
#  'Breast_HS578T',
#  'Breast_MDAMB231',
#  'Breast_T47D',
#  'CNS_SF268',
#  'CNS_SF295',
#  'CNS_SF539',
#  'CNS_SNB19',
#  'CNS_SNB75',
#  'CNS_U251',
#  'Colon_COLO205',
#  'Colon_HCC2998',
#  'Colon_HCT116',
#  'Colon_HCT15',
#  'Colon_HT29',
#  'Colon_KM12',
#  'Colon_SW620',
#  'Lung_EKVX',
#  'Lung_HOP62',
#  'Lung_HOP92',
#  'Lung_NCIH226',
#  'Lung_NCIH23',
#  'Lung_NCIH322M',
#  'Lung_NCIH460',
#  'Lung_NCIH522',
#  'Melanoma_LOXIMVI',
#  'Melanoma_M14',
#  'Melanoma_MALME3M',
#  'Melanoma_MDAMB435',
#  'Melanoma_SKMEL2',
#  'Melanoma_SKMEL28',
#  'Melanoma_SKMEL5',
#  'Melanoma_UACC257',
#  'Melanoma_UACC62',
#  'Ovarian_IGROV1',
#  'Ovarian_OVCAR3',
#  'Ovarian_OVCAR4',
#  'Ovarian_OVCAR5',
#  'Ovarian_OVCAR8',
#  'Ovarian_SKOV3',
#  'Prostate_DU145',
#  'Prostate_PC3',
#  'Renal_A498',
#  'Renal_ACHN',
#  'Renal_CAKI1',
#  'Renal_RXF393',
#  'Renal_SN12C',
#  'Renal_TK10',
#  'Renal_UO31',
#  'Lung_A549',
#  'Ovarian_NCIADRRES',
#  'Renal_786O']

# %%
list(set([x.split('_')[0] for x in lineages]))
# Out:
# ['Melanoma', 'Lung', 'Renal', 'Colon', 'Prostate', 'CNS', 'Breast', 'Ovarian']
