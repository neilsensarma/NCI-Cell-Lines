# %%
import numpy as np
import pandas as pd

# %%
metadata = pd.read_excel('C:\\GaTech\\Ph. D\\Research\\Datasets\\New\\nci_metabolomic.xlsx', sheet_name = 'Cell_metadata')
metabolomic = pd.read_excel('C:\\GaTech\\Ph. D\\Research\\Datasets\\New\\nci_metabolomic.xlsx', sheet_name = 'Met_alpha')

# %%
metadata.head(2)
# Out:
#   Sheet 1: Cell line metadata Unnamed: 1           Unnamed: 2  \
# 0                         NaN        NaN                  NaN
# 1                   Cell line     Tissue  Doubling time, mean
#
#              Unnamed: 3       Unnamed: 4        Unnamed: 5  \
# 0                   NaN              NaN               NaN
# 1  Doubling time, stdev  Cell size, mean  Cell size, stdev
#
#                       Unnamed: 6
# 0                            NaN
# 1  Cell volume correction factor

# %%
metadata.columns[0]
# Out:
# 'Sheet 1: Cell line metadata'

# %%
metabolomic.head(10)
# Out:
#   Sheet 2: Relative metabolite abundances in 54 human cancer cell lines  \
# 0                                                NaN
# 1                                                NaN
# 2                                            Ion m/z
# 3                                            57.0343
# 4                                            58.0296
# 5                                            59.0133
# 6                                            59.0216
# 7                                            59.0495
# 8                                             60.993
# 9                                            61.0091
#
#    Unnamed: 1                          Unnamed: 2  \
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 2  Ionization                          Annotation
# 3       -H(+)        Acetone ; Propanal ; acetone
# 4       -H(+)      Acetaldehyde oxime ; HMDB01122
# 5       -H(+)                             acetate
# ...

# %%
metabolomic.columns = metabolomic.iloc[2]
metabolomic.head(3)
# Out:
# 2  Ion m/z  Ionization  Annotation  Annotation ID  Corr. PC1  Breast_BT549  \
# 0      NaN         NaN         NaN            NaN        NaN           NaN
# 1      NaN         NaN         NaN            NaN        NaN     Cell line
# 2  Ion m/z  Ionization  Annotation  Annotation ID  Corr. PC1  Breast_BT549
#
# 2  Breast_HS578T  Breast_MCF7  Breast_MDAMB231  Breast_T47D  ...  \
# 0            NaN          NaN              NaN          NaN  ...
# 1            NaN          NaN              NaN          NaN  ...
# 2  Breast_HS578T  Breast_MCF7  Breast_MDAMB231  Breast_T47D  ...
#
# 2  Prostate_DU145  Prostate_PC3  Renal_786O  Renal_A498  Renal_ACHN  \
# 0             NaN           NaN         NaN         NaN         NaN
# 1             NaN           NaN         NaN         NaN         NaN
# 2  Prostate_DU145  Prostate_PC3  Renal_786O  Renal_A498  Renal_ACHN
#
# 2  Renal_CAKI1  Renal_RXF393  Renal_SN12C  Renal_TK10  Renal_UO31
# ...

# %%
metabolomic = metabolomic.iloc[3:, :]
metabolomic.head(2)
# Out:
# 2  Ion m/z Ionization                      Annotation  \
# 3  57.0343      -H(+)    Acetone ; Propanal ; acetone
# 4  58.0296      -H(+)  Acetaldehyde oxime ; HMDB01122
#
# 2                   Annotation ID Corr. PC1 Breast_BT549 Breast_HS578T  \
# 3  HMDB01659 ; HMDB03366 ; C00207  0.537229     0.021811      0.010611
# 4           HMDB03656 ; HMDB01122  0.490435     0.006137      0.006815
#
# 2 Breast_MCF7 Breast_MDAMB231 Breast_T47D  ... Prostate_DU145 Prostate_PC3  \
# 3    0.021186        0.030946    0.008574  ...       0.018032     0.023178
# 4    0.019925        0.006278    0.005661  ...       0.015463     0.007496
#
# 2 Renal_786O Renal_A498 Renal_ACHN Renal_CAKI1 Renal_RXF393 Renal_SN12C  \
# 3    0.01716   0.032839   0.023075    0.017482     0.013196    0.043672
# 4   0.004693   0.005361     0.0094    0.007055     0.002906    0.007603
#
# 2 Renal_TK10 Renal_UO31
# 3   0.031219   0.019686
# 4   0.016136   0.005471
#
# [2 rows x 59 columns]

# %%
metabolomic.drop(columns = ['Annotation ID'], inplace=True)
metabolomic.head(2)
# Out:
# 2  Ion m/z Ionization                      Annotation Corr. PC1 Breast_BT549  \
# 3  57.0343      -H(+)    Acetone ; Propanal ; acetone  0.537229     0.021811
# 4  58.0296      -H(+)  Acetaldehyde oxime ; HMDB01122  0.490435     0.006137
#
# 2 Breast_HS578T Breast_MCF7 Breast_MDAMB231 Breast_T47D CNS_SF268  ...  \
# 3      0.010611    0.021186        0.030946    0.008574  0.012726  ...
# 4      0.006815    0.019925        0.006278    0.005661  0.003326  ...
#
# 2 Prostate_DU145 Prostate_PC3 Renal_786O Renal_A498 Renal_ACHN Renal_CAKI1  \
# 3       0.018032     0.023178    0.01716   0.032839   0.023075    0.017482
# 4       0.015463     0.007496   0.004693   0.005361     0.0094    0.007055
#
# 2 Renal_RXF393 Renal_SN12C Renal_TK10 Renal_UO31
# 3     0.013196    0.043672   0.031219   0.019686
# 4     0.002906    0.007603   0.016136   0.005471
#
# [2 rows x 58 columns]

# %%
metabolomic.drop(columns = ['Corr. PC1'], inplace = True)
metabolomic.head(2)
# Out:
# 2  Ion m/z Ionization                      Annotation Breast_BT549  \
# 3  57.0343      -H(+)    Acetone ; Propanal ; acetone     0.021811
# 4  58.0296      -H(+)  Acetaldehyde oxime ; HMDB01122     0.006137
#
# 2 Breast_HS578T Breast_MCF7 Breast_MDAMB231 Breast_T47D CNS_SF268 CNS_SF295  \
# 3      0.010611    0.021186        0.030946    0.008574  0.012726  0.011141
# 4      0.006815    0.019925        0.006278    0.005661  0.003326  0.009984
#
# 2  ... Prostate_DU145 Prostate_PC3 Renal_786O Renal_A498 Renal_ACHN  \
# 3  ...       0.018032     0.023178    0.01716   0.032839   0.023075
# 4  ...       0.015463     0.007496   0.004693   0.005361     0.0094
#
# 2 Renal_CAKI1 Renal_RXF393 Renal_SN12C Renal_TK10 Renal_UO31
# 3    0.017482     0.013196    0.043672   0.031219   0.019686
# 4    0.007055     0.002906    0.007603   0.016136   0.005471
#
# [2 rows x 57 columns]

# %%
metabolomic = metabolomic.iloc[:, 2:]
metabolomic.head(2)
# Out:
# 2                      Annotation Breast_BT549 Breast_HS578T Breast_MCF7  \
# 3    Acetone ; Propanal ; acetone     0.021811      0.010611    0.021186
# 4  Acetaldehyde oxime ; HMDB01122     0.006137      0.006815    0.019925
#
# 2 Breast_MDAMB231 Breast_T47D CNS_SF268 CNS_SF295 CNS_SF539 CNS_SNB19  ...  \
# 3        0.030946    0.008574  0.012726  0.011141  0.005588       NaN  ...
# 4        0.006278    0.005661  0.003326  0.009984  0.004644  0.010606  ...
#
# 2 Prostate_DU145 Prostate_PC3 Renal_786O Renal_A498 Renal_ACHN Renal_CAKI1  \
# 3       0.018032     0.023178    0.01716   0.032839   0.023075    0.017482
# 4       0.015463     0.007496   0.004693   0.005361     0.0094    0.007055
#
# 2 Renal_RXF393 Renal_SN12C Renal_TK10 Renal_UO31
# 3     0.013196    0.043672   0.031219   0.019686
# 4     0.002906    0.007603   0.016136   0.005471
#
# [2 rows x 55 columns]

# %%
metabolomic.reset_index(drop=True, inplace=True)
metabolomic.head(2)
# Out:
# 2                      Annotation Breast_BT549 Breast_HS578T Breast_MCF7  \
# 0    Acetone ; Propanal ; acetone     0.021811      0.010611    0.021186
# 1  Acetaldehyde oxime ; HMDB01122     0.006137      0.006815    0.019925
#
# 2 Breast_MDAMB231 Breast_T47D CNS_SF268 CNS_SF295 CNS_SF539 CNS_SNB19  ...  \
# 0        0.030946    0.008574  0.012726  0.011141  0.005588       NaN  ...
# 1        0.006278    0.005661  0.003326  0.009984  0.004644  0.010606  ...
#
# 2 Prostate_DU145 Prostate_PC3 Renal_786O Renal_A498 Renal_ACHN Renal_CAKI1  \
# 0       0.018032     0.023178    0.01716   0.032839   0.023075    0.017482
# 1       0.015463     0.007496   0.004693   0.005361     0.0094    0.007055
#
# 2 Renal_RXF393 Renal_SN12C Renal_TK10 Renal_UO31
# 0     0.013196    0.043672   0.031219   0.019686
# 1     0.002906    0.007603   0.016136   0.005471
#
# [2 rows x 55 columns]

# %%
metabolomic.columns
# Out:
# Index(['Annotation', 'Breast_BT549', 'Breast_HS578T', 'Breast_MCF7',
#        'Breast_MDAMB231', 'Breast_T47D', 'CNS_SF268', 'CNS_SF295', 'CNS_SF539',
#        'CNS_SNB19', 'CNS_SNB75', 'CNS_U251', 'Colon_COLO205', 'Colon_HCC2998',
#        'Colon_HCT116', 'Colon_HCT15', 'Colon_HT29', 'Colon_KM12',
#        'Colon_SW620', 'Lung_A549', 'Lung_EKVX', 'Lung_HOP62', 'Lung_HOP92',
#        'Lung_NCIH226', 'Lung_NCIH23', 'Lung_NCIH322M', 'Lung_NCIH460',
#        'Lung_NCIH522', 'Breast_MDAMB468', 'Melanoma_LOXIMVI', 'Melanoma_M14',
#        'Melanoma_MALME3M', 'Melanoma_MDAMB435', 'Melanoma_SKMEL2',
#        'Melanoma_SKMEL28', 'Melanoma_SKMEL5', 'Melanoma_UACC257',
#        'Melanoma_UACC62', 'Ovarian_IGROV1', 'Ovarian_NCIADRRES',
#        'Ovarian_OVCAR3', 'Ovarian_OVCAR4', 'Ovarian_OVCAR5', 'Ovarian_OVCAR8',
#        'Ovarian_SKOV3', 'Prostate_DU145', 'Prostate_PC3', 'Renal_786O',
#        'Renal_A498', 'Renal_ACHN', 'Renal_CAKI1', 'Renal_RXF393',
# ...

# %%
metabolomic.index.name = 'index'

# %%
metabolomic.head(2)
# Out:
# 2                          Annotation Breast_BT549 Breast_HS578T Breast_MCF7  \
# index
# 0        Acetone ; Propanal ; acetone     0.021811      0.010611    0.021186
# 1      Acetaldehyde oxime ; HMDB01122     0.006137      0.006815    0.019925
#
# 2     Breast_MDAMB231 Breast_T47D CNS_SF268 CNS_SF295 CNS_SF539 CNS_SNB19  \
# index
# 0            0.030946    0.008574  0.012726  0.011141  0.005588       NaN
# 1            0.006278    0.005661  0.003326  0.009984  0.004644  0.010606
#
# 2      ... Prostate_DU145 Prostate_PC3 Renal_786O Renal_A498 Renal_ACHN  \
# index  ...
# 0      ...       0.018032     0.023178    0.01716   0.032839   0.023075
# 1      ...       0.015463     0.007496   0.004693   0.005361     0.0094
#
# 2     Renal_CAKI1 Renal_RXF393 Renal_SN12C Renal_TK10 Renal_UO31
# index
# 0        0.017482     0.013196    0.043672   0.031219   0.019686
# 1        0.007055     0.002906    0.007603   0.016136   0.005471
#
# [2 rows x 55 columns]

# %%
df = metabolomic.T

# %%
df.head(2)
# Out:
# index                                 0                               1     \
# 2
# Annotation    Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122
# Breast_BT549                      0.021811                        0.006137
#
# index             2         3                                   4     \
# 2
# Annotation     acetate      Urea  Isopropyl alcohol ; Propyl alcohol
# Breast_BT549  1.801231  0.178675                            0.031762
#
# index                                     5                6             7     \
# 2
# Annotation    Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al
# Breast_BT549                          0.143416         0.004437      0.001118
#
# index                  8           9     ...  \
# 2                                        ...
# Annotation    1-pyrrolinium  Acrylamide  ...
# Breast_BT549       0.002353    0.013185  ...
#
# index                                                      2171  \
# 2
# ...

# %%
df.rename_axis('hello')
# Out:
# index                                      0     \
# hello
# Annotation         Acetone ; Propanal ; acetone
# Breast_BT549                           0.021811
# Breast_HS578T                          0.010611
# Breast_MCF7                            0.021186
# Breast_MDAMB231                        0.030946
# Breast_T47D                            0.008574
# CNS_SF268                              0.012726
# CNS_SF295                              0.011141
# CNS_SF539                              0.005588
# CNS_SNB19                                   NaN
# CNS_SNB75                               0.01964
# CNS_U251                               0.027977
# Colon_COLO205                          0.021179
# Colon_HCC2998                          0.010782
# Colon_HCT116                           0.033994
# Colon_HCT15                            0.033523
# Colon_HT29                             0.020936
# Colon_KM12                             0.007775
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head(2)
# Out:
# index         hello                             0  \
# 0        Annotation  Acetone ; Propanal ; acetone
# 1      Breast_BT549                      0.021811
#
# index                               1         2         3  \
# 0      Acetaldehyde oxime ; HMDB01122   acetate      Urea
# 1                            0.006137  1.801231  0.178675
#
# index                                   4                                 5  \
# 0      Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate
# 1                                0.031762                          0.143416
#
# index                6             7              8  ...  \
# 0      Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...
# 1             0.004437      0.001118       0.002353  ...
#
# index                                               2171  \
# 0      PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; P...
# 1                                               0.071269
#
# ...

# %%
df.columns = df.iloc[0]
df.head(2)
# Out:
# 0    Annotation  Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122  \
# 0    Annotation  Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122
# 1  Breast_BT549                      0.021811                        0.006137
#
# 0   acetate      Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0   acetate      Urea  Isopropyl alcohol ; Propyl alcohol
# 1  1.801231  0.178675                            0.031762
#
# 0  Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0  Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al
# 1                          0.143416         0.004437      0.001118
#
# 0  1-pyrrolinium  ...  \
# 0  1-pyrrolinium  ...
# 1       0.002353  ...
#
# 0 PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 0  PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; P...
# 1                                           0.071269
#
# ...

# %%
df = df.iloc[1:,]

# %%
df.head(2)
# Out:
# 0     Annotation Acetone ; Propanal ; acetone Acetaldehyde oxime ; HMDB01122  \
# 1   Breast_BT549                     0.021811                       0.006137
# 2  Breast_HS578T                     0.010611                       0.006815
#
# 0   acetate      Urea Isopropyl alcohol ; Propyl alcohol  \
# 1  1.801231  0.178675                           0.031762
# 2  0.884542   0.09339                           0.016027
#
# 0 Bicarbonate ; Hydrogen carbonate Dimethylsulfide 3-Butyn-1-al 1-pyrrolinium  \
# 1                         0.143416        0.004437     0.001118      0.002353
# 2                         0.037372             NaN     0.005778      0.003199
#
# 0  ...  \
# 1  ...
# 2  ...
#
# 0 PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 1                                           0.071269
# 2                                           0.059958
#
# ...

# %%
df.Annotation
# Out:
# 1          Breast_BT549
# 2         Breast_HS578T
# 3           Breast_MCF7
# 4       Breast_MDAMB231
# 5           Breast_T47D
# 6             CNS_SF268
# 7             CNS_SF295
# 8             CNS_SF539
# 9             CNS_SNB19
# 10            CNS_SNB75
# 11             CNS_U251
# 12        Colon_COLO205
# 13        Colon_HCC2998
# 14         Colon_HCT116
# 15          Colon_HCT15
# 16           Colon_HT29
# 17           Colon_KM12
# 18          Colon_SW620
# 19            Lung_A549
# 20            Lung_EKVX
# 21           Lung_HOP62
# 22           Lung_HOP92
# 23         Lung_NCIH226
# 24          Lung_NCIH23
# 25        Lung_NCIH322M
# 26         Lung_NCIH460
# 27         Lung_NCIH522
# 28      Breast_MDAMB468
# 29     Melanoma_LOXIMVI
# 30         Melanoma_M14
# 31     Melanoma_MALME3M
# 32    Melanoma_MDAMB435
# 33      Melanoma_SKMEL2
# 34     Melanoma_SKMEL28
# 35      Melanoma_SKMEL5
# 36     Melanoma_UACC257
# 37      Melanoma_UACC62
# 38       Ovarian_IGROV1
# ...

# %%
df.rename(columns = {'Annotation': 'Cell Line'}, inplace=True)
# Out:
# C:\Users\nilav\AppData\Local\Temp\ipykernel_17336\2979491249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'Annotation': 'Cell Line'}, inplace=True)

# %%
df
# Out:
# 0           Cell Line Acetone ; Propanal ; acetone  \
# 1        Breast_BT549                     0.021811
# 2       Breast_HS578T                     0.010611
# 3         Breast_MCF7                     0.021186
# 4     Breast_MDAMB231                     0.030946
# 5         Breast_T47D                     0.008574
# 6           CNS_SF268                     0.012726
# 7           CNS_SF295                     0.011141
# 8           CNS_SF539                     0.005588
# 9           CNS_SNB19                          NaN
# 10          CNS_SNB75                      0.01964
# 11           CNS_U251                     0.027977
# 12      Colon_COLO205                     0.021179
# 13      Colon_HCC2998                     0.010782
# 14       Colon_HCT116                     0.033994
# 15        Colon_HCT15                     0.033523
# 16         Colon_HT29                     0.020936
# 17         Colon_KM12                     0.007775
# ...

# %%
df.to_csv('metabolomics_clean.csv', sep=',')
