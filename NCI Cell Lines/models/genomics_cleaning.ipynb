# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:\\GaTech\\Ph. D\\Research\\Datasets\\data_NCI-60_exp.txt', sep='\t')

# %%
data.head(2)
# Out:
#   Probe id Gene name  Entrez gene id Chromosome  Start    End Cytoband  \
# 0   WASH7P    WASH7P          653635          1  14361  29370  1p36.33
# 1  FAM138F   FAM138F          641702          1  34610  77690  19p13.3
#
#   RefSeq(mRNA) RefSeq(protein)  BR:MCF7  ...  PR:PC-3  PR:DU-145  RE:786-0  \
# 0          NaN             NaN    0.499  ...    0.044      0.073    -0.117
# 1          NaN             NaN    1.863  ...    0.440      0.111    -0.183
#
#    RE:A498  RE:ACHN  RE:CAKI-1  RE:RXF 393  RE:SN12C  RE:TK-10  RE:UO-31
# 0   -1.384    0.061     -1.281      -0.749    -0.505     0.263    -0.315
# 1   -1.905   -0.793     -1.776      -1.883    -1.828    -1.163    -1.833
#
# [2 rows x 69 columns]

# %%
data.drop(columns = ['Probe id', 'Entrez gene id', 'Chromosome', 'Start', 'End', 'Cytoband', 'RefSeq(mRNA)', 'RefSeq(protein)'], inplace=True)
data.head(2)
# Out:
#   Gene name  BR:MCF7  BR:MDA-MB-231  BR:HS 578T  BR:BT-549  BR:T-47D  \
# 0    WASH7P    0.499         -0.386      -0.585     -0.580     0.370
# 1   FAM138F    1.863          0.786       0.021      0.572     1.485
#
#    CNS:SF-268  CNS:SF-295  CNS:SF-539  CNS:SNB-19  ...  PR:PC-3  PR:DU-145  \
# 0      -0.609      -0.428      -0.741      -0.161  ...    0.044      0.073
# 1      -0.498       0.777       1.033       0.763  ...    0.440      0.111
#
#    RE:786-0  RE:A498  RE:ACHN  RE:CAKI-1  RE:RXF 393  RE:SN12C  RE:TK-10  \
# 0    -0.117   -1.384    0.061     -1.281      -0.749    -0.505     0.263
# 1    -0.183   -1.905   -0.793     -1.776      -1.883    -1.828    -1.163
#
#    RE:UO-31
# 0    -0.315
# 1    -1.833
#
# [2 rows x 61 columns]

# %%
df = data.T.reset_index()

# %%
df.head(2)
# Out:
#        index       0        1          2          3      4      5  \
# 0  Gene name  WASH7P  FAM138F  LOC729737  RPL23AP21  CICP7  CICP3
# 1    BR:MCF7   0.499    1.863      1.137      0.095 -0.356 -0.368
#
#               6          7          8  ...  25030      25031    25032  \
# 0  LOC101060494  LINC00115  LINC01128  ...  MAFIP  LOC283788  KIR3DS1
# 1          0.12     -0.253     -0.449  ...  0.949     -0.028   -0.169
#
#           25033    25034         25035    25036     25037     25038     25039
# 0  LOC100507412  KIR2DS5  LOC100288966  KIR2DS1  MGC70870  HLA-DRB4  HLA-DRB3
# 1         0.935    0.168         0.892     0.09     0.474    -0.201    -0.761
#
# [2 rows x 25041 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:, :]

# %%
df.rename(columns = {'Gene name': 'Cell names'}, inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
df.head(2)
# Out:
# 0     Cell names WASH7P FAM138F LOC729737 RPL23AP21  CICP7  CICP3  \
# 0        BR:MCF7  0.499   1.863     1.137     0.095 -0.356 -0.368
# 1  BR:MDA-MB-231 -0.386   0.786     0.931    -0.086 -0.508  0.744
#
# 0 LOC101060494 LINC00115 LINC01128  ...  MAFIP LOC283788 KIR3DS1 LOC100507412  \
# 0         0.12    -0.253    -0.449  ...  0.949    -0.028  -0.169        0.935
# 1       -0.364     -0.51    -0.078  ... -1.306    -0.861  -0.169        0.246
#
# 0 KIR2DS5 LOC100288966 KIR2DS1 MGC70870 HLA-DRB4 HLA-DRB3
# 0   0.168        0.892    0.09    0.474   -0.201   -0.761
# 1  -0.207        0.701  -0.293   -0.145    0.185   -0.528
#
# [2 rows x 25041 columns]

# %%
df.isna().values.any()
# Out:
# True

# %%
df
# Out:
# 0       Cell names WASH7P FAM138F LOC729737 RPL23AP21  CICP7  CICP3  \
# 0          BR:MCF7  0.499   1.863     1.137     0.095 -0.356 -0.368
# 1    BR:MDA-MB-231 -0.386   0.786     0.931    -0.086 -0.508  0.744
# 2       BR:HS 578T -0.585   0.021    -0.801    -0.795 -0.499   0.72
# 3        BR:BT-549  -0.58   0.572    -1.425    -0.733   -0.6 -0.132
# 4         BR:T-47D   0.37   1.485     1.569    -0.505  1.018  0.577
# 5       CNS:SF-268 -0.609  -0.498    -0.313     0.593 -0.723  0.066
# 6       CNS:SF-295 -0.428   0.777    -0.914     0.725 -2.733 -0.627
# 7       CNS:SF-539 -0.741   1.033       NaN    -0.659  0.049    NaN
# 8       CNS:SNB-19 -0.161   0.763     -0.81    -0.012  0.838  0.639
# 9       CNS:SNB-75 -0.286  -0.132    -0.777      -2.4 -1.652  0.646
# 10        CNS:U251  0.264    0.78     -1.15    -0.379 -0.138  -1.86
# 11     CO:COLO 205  0.736  -1.561    -0.282     1.907  1.538 -1.519
# 12     CO:HCC-2998 -0.295   -0.16     0.571    -0.521 -0.643 -0.199
# ...

# %%
df = df.fillna(value='0.0')

# %%
#df.to_csv('nci_genomics.csv')

# %%
carbo = pd.read_csv('C:\\Users\\nilav\\NCI Cell Lines\\Carboplatin_metabolic_NCI.csv')

# %%
carbo
# Out:
#             Cell Line  Acetone ; Propanal ; acetone  \
# 0        Breast_BT549                      0.021811
# 1       Breast_HS578T                      0.010611
# 2     Breast_MDAMB231                      0.030946
# 3         Breast_T47D                      0.008574
# 4           CNS_SF268                      0.012726
# 5           CNS_SF295                      0.011141
# 6           CNS_SF539                      0.005588
# 7           CNS_SNB19                           NaN
# 8           CNS_SNB75                      0.019640
# 9            CNS_U251                      0.027977
# 10      Colon_COLO205                      0.021179
# 11      Colon_HCC2998                      0.010782
# 12       Colon_HCT116                      0.033994
# 13        Colon_HCT15                      0.033523
# 14         Colon_HT29                      0.020936
# 15         Colon_KM12                      0.007775
# 16        Colon_SW620                      0.024835
# ...

# %%
d1 = df.merge(carbo, on='Cell names')

# %%
d1.shape
# Out:
# (49, 27225)

# %%
d1.head(2)
# Out:
#       Cell names  WASH7P  FAM138F LOC729737  RPL23AP21  CICP7  CICP3  \
# 0  BR:MDA-MB-231  -0.386    0.786     0.931     -0.086 -0.508  0.744
# 1     BR:HS 578T  -0.585    0.021    -0.801     -0.795 -0.499   0.72
#
#   LOC101060494  LINC00115  LINC01128  ...  \
# 0       -0.364     -0.510     -0.078  ...
# 1       -1.207      0.098      0.823  ...
#
#    2,4,7,10-hexadecatetraenoylcoa ; 2,7,10,13-hexadecatetraenoylcoa ; 2E,4Z,7Z,10Z-hexadecatetraenoyl-CoA ; 3,7,10,13-hexadecatetraenoylcoa ; 4,7,10,13-hexadecatetraenoylcoa  \
# 0                                           0.026098
# 1                                           0.021282
#
#   O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.029986
# 1                                           0.024981
#
# ...

# %%
x = []
combined = list(d1['Cell names'])
total = list(df['Cell names'])
for i in total:
    if i not in combined:
        x.append(i)

# %%
len(x)
# Out:
# 11

# %%
x
# Out:
# ['BR:MCF7',
#  'LE:CCRF-CEM',
#  'LE:HL-60(TB)',
#  'LE:K-562',
#  'LE:MOLT-4',
#  'LE:RPMI-8226',
#  'LE:SR',
#  'ME:MDA-N',
#  'LC:A549/ATCC',
#  'OV:NCI/ADR-RES',
#  'RE:786-0']

# %%
d1.to_csv('carboplatin_integrated.csv', index=False)
