# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import RFE, RFECV
from sklearn.model_selection import StratifiedKFold, RepeatedStratifiedKFold
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
import seaborn as sns
from warnings import filterwarnings
import matplotlib.pyplot as plt
filterwarnings('ignore')

# %%
data = pd.read_csv('C:\\GaTech\\Ph. D\\Research\\Datasets\\metabolomic_data.csv')
drug_data = pd.read_csv('C:\\GaTech\\Ph. D\\Research\\Datasets\\sanger-dose-response.csv')
metadata = pd.read_csv('C:\\GaTech\\Ph. D\\Research\\Datasets\\sample_info.csv')

# %%
data.head(2)
# Out:
#                   CCLE_ID   DepMap_ID  2-aminoadipate  3-phosphoglycerate  \
# 0              DMS53_LUNG  ACH-000698        6.112727            6.034198
# 1  SW1116_LARGE_INTESTINE  ACH-000489        5.577413            5.727045
#
#    alpha-glycerophosphate  4-pyridoxate  aconitate   adenine   adipate  \
# 0                5.896896      6.000532   5.513618  5.868529  5.977177
# 1                5.111468      6.073250   5.802494  5.824473  5.888821
#
#    alpha-ketoglutarate  ...  C56:8 TAG  C56:7 TAG  C56:6 TAG  C56:5 TAG  \
# 0             5.693074  ...   6.070239   6.133433   6.091089   6.257711
# 1             5.768379  ...   6.248653   6.633575   6.378052   6.341043
#
#    C56:4 TAG  C56:3 TAG  C56:2 TAG  C58:8 TAG  C58:7 TAG  C58:6 TAG
# 0   6.372732   6.202511   5.939576   6.309821   6.115974   5.999436
# 1   6.360945   6.333540   6.137271   7.065858   6.832174   6.363064
#
# [2 rows x 227 columns]

# %%
drug_data.head(2)
# Out:
#   DATASET  COSMIC_ID  DRUG_ID  MIN_CONC  MAX_CONC  RMSE_PUBLISHED  \
# 0   GDSC1     683665        1  0.007813       2.0        0.022518
# 1   GDSC1     684055        1  0.007813       2.0        0.031831
#
#    Z_SCORE_PUBLISHED  IC50_PUBLISHED  AUC_PUBLISHED  ARXSPAN_ID  DRUG_NAME  \
# 0          -0.192056       10.977393       0.982116  ACH-002270  ERLOTINIB
# 1           0.505823       23.133991       0.984820  ACH-002104  ERLOTINIB
#
#         BROAD_ID  upper_limit      ec50     slope  lower_limit       auc  \
# 0  BRD-K70401845     0.992788  2.839376 -5.670993     0.514389  0.990834
# 1  BRD-K70401845     1.006405  0.028649 -0.186377     0.990054  0.997138
#
#    log2.ic50       mse        R2
# 0        NaN  0.000034  0.904675
# 1        NaN  0.000057  0.028903

# %%
metadata.head(2)
# Out:
#     DepMap_ID stripped_cell_line_name  \
# 0  ACH-000001               NIHOVCAR3
# 1  ACH-000002                    HL60
#
#                                  CCLE_Name   alias  COSMIC_ID lineage  \
# 0                          NIHOVCAR3_OVARY  OVCAR3   905933.0   ovary
# 1  HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     NaN   905938.0   blood
#
#         lineage_subtype lineage_sub_subtype lineage_molecular_subtype     sex  \
# 0  ovary_adenocarcinoma   high_grade_serous                       NaN  Female
# 1                   AML                  M3                       NaN  Female
#
#    ... culture_medium  cas9_activity       RRID  \
# 0  ...            NaN            NaN  CVCL_0465
# 1  ...            NaN            NaN  CVCL_0002
#
#                sample_collection_site primary_or_metastasis         disease  \
# 0                             ascites            Metastasis  Ovarian Cancer
# 1  haematopoietic_and_lymphoid_tissue               Primary        Leukemia
#
#                                      disease_subtype   age Sanger_model_ID  \
# 0                  Adenocarcinoma, high grade serous  60.0       SIDM00105
# 1  Acute Myelogenous Leukemia (AML), M3 (Promyelo...  35.0       SIDM00829
#
#   additional_info
# 0             NaN
# 1             NaN
#
# [2 rows x 24 columns]

# %%
drug_data.rename(columns = {'ARXSPAN_ID': 'DepMap_ID'}, inplace=True)
wd = data.merge(drug_data, on='DepMap_ID')
wd = wd.merge(metadata, on='DepMap_ID')
wd.head(2)
# Out:
#       CCLE_ID   DepMap_ID  2-aminoadipate  3-phosphoglycerate  \
# 0  DMS53_LUNG  ACH-000698        6.112727            6.034198
# 1  DMS53_LUNG  ACH-000698        6.112727            6.034198
#
#    alpha-glycerophosphate  4-pyridoxate  aconitate   adenine   adipate  \
# 0                5.896896      6.000532   5.513618  5.868529  5.977177
# 1                5.896896      6.000532   5.513618  5.868529  5.977177
#
#    alpha-ketoglutarate  ...  culture_medium  cas9_activity       RRID  \
# 0             5.693074  ...   RPMI; 10% FBS             25  CVCL_1177
# 1             5.693074  ...   RPMI; 10% FBS             25  CVCL_1177
#
#    sample_collection_site  primary_or_metastasis      disease  \
# 0                    lung                Primary  Lung Cancer
# 1                    lung                Primary  Lung Cancer
#
#                  disease_subtype   age  Sanger_model_ID  additional_info
# 0  Small Cell Lung Cancer (SCLC)  54.0        SIDM00523              NaN
# 1  Small Cell Lung Cancer (SCLC)  54.0        SIDM00523              NaN
#
# [2 rows x 269 columns]

# %%
wd.shape
# Out:
# (251886, 269)

# %%
wd = wd[(wd['DRUG_NAME'] == 'CISPLATIN') & (wd['DATASET'] == 'GDSC2')]
wd.reset_index(inplace=True, drop=True)
wd.head(2)
# Out:
#                   CCLE_ID   DepMap_ID  2-aminoadipate  3-phosphoglycerate  \
# 0              DMS53_LUNG  ACH-000698        6.112727            6.034198
# 1  SW1116_LARGE_INTESTINE  ACH-000489        5.577413            5.727045
#
#    alpha-glycerophosphate  4-pyridoxate  aconitate   adenine   adipate  \
# 0                5.896896      6.000532   5.513618  5.868529  5.977177
# 1                5.111468      6.073250   5.802494  5.824473  5.888821
#
#    alpha-ketoglutarate  ...  culture_medium  cas9_activity       RRID  \
# 0             5.693074  ...   RPMI; 10% FBS             25  CVCL_1177
# 1             5.768379  ...             NaN            NaN  CVCL_0544
#
#    sample_collection_site  primary_or_metastasis                  disease  \
# 0                    lung                Primary              Lung Cancer
# 1                   Colon                Primary  Colon/Colorectal Cancer
#
#                  disease_subtype   age  Sanger_model_ID  additional_info
# 0  Small Cell Lung Cancer (SCLC)  54.0        SIDM00523              NaN
# 1                 Adenocarcinoma  73.0        SIDM00835              NaN
#
# [2 rows x 269 columns]

# %%
y = wd.pop('IC50_PUBLISHED')
y
# Out:
# 0       41.668315
# 1      913.072239
# 2        5.096892
# 3       14.166911
# 4        7.541431
#           ...
# 521     62.657601
# 522    706.698412
# 523     12.359957
# 524      4.712530
# 525     34.238030
# Name: IC50_PUBLISHED, Length: 526, dtype: float64

# %%
y = pd.Series(y)

# %%
wd = wd[data.columns]

# %%
X = wd.select_dtypes('float64')
X.head(2)
# Out:
#    2-aminoadipate  3-phosphoglycerate  alpha-glycerophosphate  4-pyridoxate  \
# 0        6.112727            6.034198                5.896896      6.000532
# 1        5.577413            5.727045                5.111468      6.073250
#
#    aconitate   adenine   adipate  alpha-ketoglutarate       AMP   citrate  \
# 0   5.513618  5.868529  5.977177             5.693074  5.923737  5.641242
# 1   5.802494  5.824473  5.888821             5.768379  5.760784  5.914742
#
#    ...  C56:8 TAG  C56:7 TAG  C56:6 TAG  C56:5 TAG  C56:4 TAG  C56:3 TAG  \
# 0  ...   6.070239   6.133433   6.091089   6.257711   6.372732   6.202511
# 1  ...   6.248653   6.633575   6.378052   6.341043   6.360945   6.333540
#
#    C56:2 TAG  C58:8 TAG  C58:7 TAG  C58:6 TAG
# 0   5.939576   6.309821   6.115974   5.999436
# 1   6.137271   7.065858   6.832174   6.363064
#
# [2 rows x 225 columns]

# %%
X = pd.DataFrame(data = MinMaxScaler().fit_transform(X), columns = X.columns)
X.head(2)
# Out:
#    2-aminoadipate  3-phosphoglycerate  alpha-glycerophosphate  4-pyridoxate  \
# 0        0.495307            0.621262                0.510802      0.459783
# 1        0.270433            0.454296                0.237895      0.491937
#
#    aconitate   adenine   adipate  alpha-ketoglutarate       AMP   citrate  \
# 0   0.452734  0.380599  0.587679             0.438061  0.405262  0.488794
# 1   0.590912  0.363184  0.521658             0.473832  0.353421  0.633582
#
#    ...  C56:8 TAG  C56:7 TAG  C56:6 TAG  C56:5 TAG  C56:4 TAG  C56:3 TAG  \
# 0  ...   0.599608   0.527663   0.491753   0.599994   0.609317   0.650514
# 1  ...   0.680131   0.743575   0.626599   0.635141   0.604739   0.714077
#
#    C56:2 TAG  C58:8 TAG  C58:7 TAG  C58:6 TAG
# 0   0.463536   0.569028   0.516410   0.512918
# 1   0.558885   0.866371   0.742402   0.637727
#
# [2 rows x 225 columns]

# %%
labels = []
for i in list(y):
    if i > 8.00:
        labels.append('NR')
    else:
        labels.append('R')
y = pd.Series(labels)

# %%
y
# Out:
# 0      NR
# 1      NR
# 2       R
# 3      NR
# 4       R
#        ..
# 521    NR
# 522    NR
# 523    NR
# 524     R
# 525    NR
# Length: 526, dtype: object

# %%
y.value_counts()
# Out:
# NR    389
# R     137
# dtype: int64

# %%
y.shape, X.shape
# Out:
# ((526,), (526, 225))

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = pd.Series(le.fit_transform(y))
y.value_counts()
# Out:
# 0    389
# 1    137
# dtype: int64

# %%
from xgboost import plot_importance
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, stratify = y, random_state = 43)

model = RandomForestClassifier(class_weight = 'balanced', n_estimators = 150, random_state = 43)
model.fit(X_train, y_train)
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize = (10,10))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
        color="lightsalmon", align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report

sfm = SelectFromModel(model, threshold = 0.010)
sfm.fit(X_train, y_train)

X_train_transformed = pd.DataFrame(data = sfm.transform(X_train), columns = X_train.columns[sfm.get_support(0)])
X_test_transformed = pd.DataFrame(data = sfm.transform(X_test), columns = X_test.columns[sfm.get_support(0)])

model.fit(X_train_transformed, y_train)
prediction = model.predict_proba(X_test_transformed)[:, 1]
y_pred = model.predict(X_test_transformed)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.87       117
#            1       0.75      0.29      0.42        41
#
#     accuracy                           0.79       158
#    macro avg       0.77      0.63      0.65       158
# weighted avg       0.78      0.79      0.76       158

# %%
from sklearn.metrics import confusion_matrix

fig, ax = plt.subplots()
ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, xticklabels = ['N', 'R'], yticklabels = ['N', 'R'])
ax.set_title('Random Forest Cisplatin Model - CCLE Cell lines\nAccuracy 79%')
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction[y_test==0], label='Non-Responders')
plt.hist(prediction[y_test==1], label='Responders', alpha=0.7, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
len(X_train_transformed.columns)
# Out:
# 15

# %%
model2 = SVC(kernel = 'linear', C=1, gamma='auto')
model2.fit(X_train_transformed, y_train)
prediction2 = model2.predict_proba(X_test_transformed)[:, 1]
y_pred = model2.predict(X_test_transformed)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       117
#            1       0.72      0.32      0.44        41
#
#     accuracy                           0.79       158
#    macro avg       0.76      0.64      0.66       158
# weighted avg       0.78      0.79      0.76       158

# %%
fig, ax = plt.subplots()
ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, xticklabels = ['N', 'R'], yticklabels = ['N', 'R'])
ax.set_title('SVM Cisplatin Model - CCLE cell lines\nAccuracy: 79%')
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction2[y_test==0], label='Non-Responders')
plt.hist(prediction2[y_test==1], label='Responders', alpha=0.7, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
model3 = XGBClassifier()
model3.fit(X_train_transformed, y_train)
prediction3 = model3.predict_proba(X_test_transformed)[:,1]
y_pred = model3.predict(X_test_transformed)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86       117
#            1       0.65      0.32      0.43        41
#
#     accuracy                           0.78       158
#    macro avg       0.72      0.63      0.64       158
# weighted avg       0.76      0.78      0.75       158

# %%
fig, ax = plt.subplots()
ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot = True, xticklabels = ['N', 'R'], yticklabels = ['N', 'R'], fmt='.2f')
ax.set_title('XGB Classifer Cisplatin - CCLE cell lines\nAccuracy: 78%')
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5, 5))
plt.hist(prediction3[y_test==0], label='Non-Responders')
plt.hist(prediction3[y_test==1], label='Responders', alpha=0.7, color = 'r')
plt.xlabel('Probability of being Positive Class')
plt.ylabel('Number of records in each bucket')
plt.legend()
plt.tick_params(axis='both')
plt.show()

# %%
y_train.shape
# Out:
# (368,)

# %%
y_test.shape
# Out:
# (158,)

# %%
unique, counts = np.unique(y_train, return_counts=True)

# %%
dict(zip(unique, counts))
# Out:
# {0: 272, 1: 96}

# %%
unique, counts = np.unique(y_test, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 117, 1: 41}
