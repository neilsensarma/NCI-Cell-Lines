# %%
import numpy as np
import pandas as pd
import umap
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\nilav\\NCI Cell Lines\\Gemcitabine_metabolic_NCI.csv')
data.head(2)
# Out:
#        Cell Line  Acetone ; Propanal ; acetone  \
# 0   Breast_BT549                      0.021811
# 1  Breast_HS578T                      0.010611
#
#    Acetaldehyde oxime ; HMDB01122   acetate      Urea  \
# 0                        0.006137  1.801231  0.178675
# 1                        0.006815  0.884542  0.093390
#
#    Isopropyl alcohol ; Propyl alcohol  Bicarbonate ; Hydrogen carbonate  \
# 0                            0.031762                          0.143416
# 1                            0.016027                          0.037372
#
#    Dimethylsulfide  3-Butyn-1-al  1-pyrrolinium  ...  \
# 0         0.004437      0.001118       0.002353  ...
# 1              NaN      0.005778       0.003199  ...
#
#    O-b-D-glucopyranosyl-(1->3)-O-2-(acetylamino)-2-deoxy-b-D-glucopyranosyl-(1->3)-O-[6-deoxy-a-L-galactopyranosyl-(1->4)]-O-b-D-galactopyranosyl-(1->4)-O-[6-deoxy-a-L-galactopyranosyl-(1->3)]-D-Glucose  \
# 0                                           0.036367
# ...

# %%
drug = data.pop('Gemcitabine')
drug.head()
# Out:
# 0    4.794
# 1    5.600
# 2    5.888
# 3    6.273
# 4    6.937
# Name: Gemcitabine, dtype: float64

# %%
X = data.select_dtypes('float64')
X.head(2)
# Out:
#    Acetone ; Propanal ; acetone  Acetaldehyde oxime ; HMDB01122   acetate  \
# 0                      0.021811                        0.006137  1.801231
# 1                      0.010611                        0.006815  0.884542
#
#        Urea  Isopropyl alcohol ; Propyl alcohol  \
# 0  0.178675                            0.031762
# 1  0.093390                            0.016027
#
#    Bicarbonate ; Hydrogen carbonate  Dimethylsulfide  3-Butyn-1-al  \
# 0                          0.143416         0.004437      0.001118
# 1                          0.037372              NaN      0.005778
#
#    1-pyrrolinium  Acrylamide  ...  \
# 0       0.002353    0.013185  ...
# 1       0.003199    0.011203  ...
#
#    PIP2(16:0/18:1(11Z)) ; PIP2(16:0/18:1(9Z)) ; PIP2(16:1(9Z)/18:0) ; PIP2(18:0/16:1(9Z)) ; PIP2(18:1(11Z)/16:0) ; PIP2(18:1(9Z)/16:0)  \
# 0                                           0.071269
# 1                                           0.059958
#
# ...

# %%
X.fillna(0.0, inplace=True)

# %%
labels = []
drug_mean = drug.mean()
for i in drug:
    if i >= drug_mean:
        labels.append('N')
    else:
        labels.append('R')
y = pd.Series(labels)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_transformed = pd.DataFrame(pca.fit_transform(X))

# %%
X_transformed
# Out:
#             0          1
# 0   75.948428  20.975309
# 1   75.463396  48.163553
# 2   58.251029   5.678188
# 3   -1.845206  17.940824
# 4   -5.956409  -3.460507
# 5   -6.797491 -11.001406
# 6   33.063437  25.663462
# 7  -23.751385  46.706247
# 8   55.451309 -14.228585
# 9   19.827085  -9.665975
# 10 -34.285553 -53.417352
# 11 -82.087012  14.663555
# 12 -25.086098 -65.470768
# 13 -20.965699 -41.787892
# 14 -74.594331   8.926129
# 15 -14.936481 -25.192327
# 16 -26.257022 -35.983437
# 17  70.873294  -0.067500
# 18  -2.151828  13.092515
# 19  90.520290  19.681241
# 20  30.070882  -2.668844
# 21  -0.695048  17.499192
# 22 -78.191195  24.597691
# 23 -83.479486  31.670186
# 24  38.614715 -34.318142
# 25 -23.683944 -63.990060
# 26 -13.588206 -21.900404
# 27  33.877239 -46.930174
# 28 -23.236000 -15.632217
# 29 -32.149262  63.715258
# 30  31.619555 -20.291320
# 31 -58.192272   9.851985
# 32 -39.400909  18.676303
# 33 -44.793821  32.852480
# 34  -6.222379 -22.323784
# 35  20.864160  28.667926
# ...

# %%
fig, ax = plt.subplots(figsize = (5,5))
plt.scatter(x = X_transformed.iloc[:, :1], y = X_transformed.iloc[:, 1:2], c=y, cmap='Spectral', alpha = 1.0)
ax.set_title('Comparison of metabolite profiles for NCI cell lines in response to Gemcitabine')
ax.set_xlabel('Component 0')
ax.set_ylabel('Component 1')
ax.legend(y)
plt.show()
